# %% [markdown]
# Converts current lemmas into corpus files and trains a Huggingface BPE Tokenizer vocabulary model.

# %%
from IPython.display import JSON
import json

from featurizer import *
from theorybank import *
# Out:
# 615 9205

# %%
theorybank = gen_default_theorybank()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 615/615 [00:01<00:00, 345.37it/s]

# %%
OUTPUTS_DIR = Path("outputs")
OUTPUTS_DIR.mkdir(exist_ok=True, parents=True)

# %%
# Set up for training a vocabulary
# Assemble a corpus containing all of the lemmas, and then all of the sequents where the lemma requests are made
# NOTE: May want to save commands as bpe encoded tokens, given new commands may be coded up.

with open("lemma_requests.json", "r") as f:
    lemma_requests = json.load(f)

corpus_fpath = Path(OUTPUTS_DIR, "corpus.txt")
commands_fpath = Path(OUTPUTS_DIR, "commands.txt")
with open(corpus_fpath, 'w') as f:
    with open(commands_fpath, 'w') as cmd_f:
        for name, lemma_body in theorybank.all_lemmas.items():
            f.write(" ".join([str(x) for x in lemma_body]))
            f.write("\n")
        for lreq in lemma_requests:
            f.write(" ".join([str(x) for x in lreq['state']]))
            f.write("\n")
            cmd_f.write("{}\n".format(lreq['command']))

# %%
# Now train the vocabulary model

from pathlib import Path
from collections import Counter
from tokenizers import ByteLevelBPETokenizer

from coprover import RSC_ROOT

Path("outputs/nir_vocab").mkdir(exist_ok=True, parents=True)

# Special tokens used by sequent representation and for Roberta model
BOS_TOKEN = "<s>"
EOS_TOKEN = "</s>"
SEP_TOKEN = "<sep>"
CLS_TOKEN = "<cls>"
UNK_TOKEN = "<unk>"
PAD_TOKEN = "<pad>"
MASK_TOKEN = "<mask>"

SPEC_TOKS=[
    "antecedent",
    "consequent",
    "hidden",
    "null",
    BOS_TOKEN,
    EOS_TOKEN,
    SEP_TOKEN,
    CLS_TOKEN,
    UNK_TOKEN,
    PAD_TOKEN,
    MASK_TOKEN
    ]

corpus_files = [Path(OUTPUTS_DIR, "corpus.txt")]

# Get vocab histogram
tok_freq = Counter()
for fpath in corpus_files:
    with open(fpath, 'r') as f:
        for line in f:
            toks = line.strip().split()
            tok_freq.update(toks)

vocab_size = len(tok_freq)
tokenizer = ByteLevelBPETokenizer()
tokenizer.train(files=[str(x) for x in corpus_files], vocab_size=vocab_size, min_frequency=1, special_tokens=SPEC_TOKS)

# NOTE: Need to save_model and then save for all the necessary files.
tokenizer.save_model("outputs/nir_vocab")
tokenizer.save("outputs/nir_vocab/config.json")
# Out:
# Counter({'argument': 1202890,
#          'operator': 1169116,
#          'subtype': 382791,
#          'null': 338658,
#          'new?': 162318,
#          'formula': 162318,
#          'asserted?': 162318,
#          'integer-value': 161385,
#          'bindings': 120907,
#          'expression': 120009,
#          'booleans__NOT': 116591,
#          'equalities__equal': 102606,
#          'number_fields__times': 86352,
#          'number_fields__difference__1': 74974,
#          'functiontype': 73796,
#          '0': 71120,
#          '1': 68024,
#          'number_fields__plus': 65961,
#          'variableName': 64993,
#          'constantName': 47012,
#          'booleans__AND': 42226,
#          'booleans__IMPLIES': 38377,
#          'reals__lesseqp': 34782,
#          'exponentiation__caret': 33951,
#          'reals__lessp': 33901,
#          'field': 29236,
#          '2': 25480,
#          'real_defs__abs': 24351,
#          'sigma__sigma': 23456,
#          'polynomials__polynomial': 20313,
#          'current-goal': 20221,
#          'antecedents': 20221,
#          'consequents': 20221,
#          'hidden': 20221,
#          'number_fields__divide': 19535,
#          'reals__greaterp': 18711,
#          'test': 18164,
#          'then': 18164,
#          'else': 18164,
#          'recordtype': 16075,
#          'UnkType': 15188,
#          'seq': 13832,
#          'reals__greatereqp': 13769,
#          'booleans__OR': 8341,
#          'binomial__C': 7939,
#          'sq__sq': 7762,
#          'x': 7704,
#          'length': 6564,
#          'number_fields__difference__2': 6529,
#          'integerValue': 6523,
#          'booleans__IFF': 6308,
#          'series__series__1': 6141,
#          '-1': 6016,
#          'vectors_2D__norm': 5999,
#          'index': 5842,
#          'a': 5691,
#          'notequal__notequal__1': 5527,
#          'n': 4835,
#          'convergence_sequences__convergentp': 4689,
#          'sqrt__sqrt': 4365,
#          'f': 4243,
#          'y': 4086,
#          'vectors_2D__difference__2': 4084,
#          'sigma_countable__T': 4026,
#          'list_adt__list': 3825,
#          'b': 3501,
#          'factorial__factorial': 3333,
#          'i': 3262,
#          'function_props__oh': 3193,
#          'derivatives__deriv': 3093,
#          'product__product': 3032,
#          'finite_sets__card': 2911,
#          'vectors_3D__times__2': 2675,
#          'list_props__length': 2613,
#          'derivatives__derivablep': 2537,
#          'convergence_sequences__limit': 2483,
#          'vectors_2D__times__2': 2447,
#          'polynomials__poly_deriv': 2374,
#          'p': 2315,
#          'power_series_deriv_scaf__a!1': 2311,
#          'sigma_countable__sigma': 2309,
#          'polynomials__a': 2280,
#          'v': 2277,
#          'finite_bags__card': 2227,
#          'vectors_3D__times__1': 2131,
#          'restrict__restrict': 2124,
#          'integers__evenp': 2123,
#          'functions__bijectivep': 2115,
#          'finite_sets__is_finite': 2064,
#          'mod__mod': 2030,
#          'sets__union': 2010,
#          'vectors_2D__times__1': 1968,
#          'j': 1948,
#          'integral_def__integrablep': 1896,
#          'divides__divides__1': 1881,
#          'integers__oddp': 1880,
#          'vectors_3D__plus': 1845,
#          'more_polynomial_props__a': 1839,
#          'integral_def__Integrablep': 1785,
#          'real_fun_ops__difference__2': 1781,
#          'm': 1760,
#          'sign__sign_ext': 1755,
#          'sigma_countable__f!1': 1732,
#          'sets__subsetp': 1731,
#          'integral_def__integral': 1675,
#          'k': 1664,
#          'bag_filters__T': 1648,
#          'real_fun_ops__plus__2': 1605,
#          'tupletype': 1544,
#          'assignments': 1502,
#          'integral_def__Integral': 1500,
#          'real_defs__max': 1492,
#          'expr': 1476,
#          'vectors_2D__plus': 1462,
#          'real_fun_ops__difference__1': 1461,
#          'c': 1438,
#          'z': 1434,
#          'id': 1407,
#          'body': 1407,
#          '4': 1403,
#          'convergence_sequences__convergence': 1388,
#          'vectors_2D__sqv': 1332,
#          'vectors__difference__2': 1326,
#          'functions__injectivep': 1311,
#          'list_props__nth': 1300,
#          'vectors_3D__difference__2': 1290,
#          'sincos_def__cos': 1286,
#          'list_props__reverse': 1282,
#          'g': 1275,
#          'vectors_3D__norm': 1270,
#          'True': 1260,
#          'group__center': 1255,
#          'real_fun_ops__times__2': 1251,
#          's': 1210,
#          'lim_of_functions__convergence': 1183,
#          'declared-type': 1179,
#          '3': 1177,
#          'derivatives_def__deriv': 1165,
#          'quadratic__root': 1163,
#          'bags_to_sets__bag_to_set': 1139,
#          'quadratic__quadratic': 1122,
#          'ring_basic_properties__times': 1114,
#          'sigma_countable__X!1': 1095,
#          'vectors__norm': 1093,
#          'u': 1084,
#          'derivatives_def__NQ': 1079,
#          'continuous_functions__continuousp__2': 1059,
#          'bags__insert': 1053,
#          'integral_def__width': 1051,
#          'power_series__powerseries__1': 1050,
#          'polynomials__poly_n_deriv': 1048,
#          'derivatives_def__derivablep': 1045,
#          'vectors_3D__sqv': 1045,
#          'sets__emptyp': 1034,
#          'monad__order': 1034,
#          'rs_integral_def__g': 1032,
#          'rs_integral_def__f': 1014,
#          'exponentiation__expt': 1010,
#          'cantor_bernstein_schroeder__A': 988,
#          'cosets__times__1': 984,
#          'power_series__powerseq': 978,
#          'series__series__2': 978,
#          'big_ops_nat__big_ops_nat': 962,
#          'integral_def__Rie_sum': 955,
#          'series__abs': 941,
#          'r': 931,
#          'real_fun_ops__times__1': 924,
#          'more_polynomial_props__root_degree': 912,
#          'floor_ceil__floor': 910,
#          'list_props__append': 898,
#          'nvectors__times__1': 897,
#          'list_adt__cons': 894,
#          'list_props__member': 889,
#          'nth_derivatives__nderiv': 865,
#          'convergence_set__nonzero_elts': 864,
#          'real_defs__min': 858,
#          'denumerable_enumeration__denumerable_enumeration': 850,
#          'power_series_deriv__a!1': 848,
#          'step_fun_def__step_functionp': 845,
#          'l': 840,
#          'power_series_deriv_scaf__GET_tk': 835,
#          'primes__primep': 815,
#          'low': 812,
#          'power_series_conv__conv_powerseriesp__1': 811,
#          'vectors__times__2': 798,
#          'sincos_def__sin': 797,
#          'bernstein_polynomials__Bern_poly': 789,
#          'sets__nonemptyp': 787,
#          'gcd__gcd': 784,
#          'list_adt__cdr': 784,
#          'sort_fseq__strictly_sort': 762,
#          'power_series_derivseq__deriv_powerseq': 753,
#          'piecewise_continuous__P': 748,
#          'high': 747,
#          'polynomials__polynomial_prod': 736,
#          'ring_basic_properties__R_sigma': 724,
#          'sets__disjointp': 723,
#          'bern_seq': 720,
#          'vectors__times__1': 718,
#          'extend__extend': 707,
#          'cantor_bernstein_schroeder__Afun': 707,
#          'group__inv': 705,
#          'countable_convergence__convergentp': 699,
#          'bernstein_polynomials__Bern': 694,
#          'double_quadratic__quad': 690,
#          'vectors_4D__sqv': 689,
#          'quadratic__discr': 688,
#          'rs_partition__width': 685,
#          'sets__member': 675,
#          'vectors__sqv': 673,
#          'rs_integral_def__sig': 668,
#          'integral_step__val_in': 665,
#          'function_inverse_def__inversep__1': 637,
#          'series__inf_sum__2': 623,
#          'ring_one_generator__T': 615,
#          'integers__integer_pred': 605,
#          'sign__sign': 600,
#          'integral_prep__f!1': 595,
#          'rs_integral_def__Rie_sum': 592,
#          'vectors__plus': 588,
#          'group__caret': 576,
#          'nth_derivatives__derivable_n_timesp': 573,
#          'partitions_scaf__part2set': 565,
#          'l1': 564,
#          'sets__difference': 564,
#          'product_fseq_posnat__product': 563,
#          'minmax_orders__least': 559,
#          'nvectors__times__2': 553,
#          'product_perm_lems__swap': 550,
#          'sigma_2D__sigma': 547,
#          'sigma_3D__sigma': 547,
#          'more_polynomial_props__b': 539,
#          'distance_2D__dist': 538,
#          'sets__intersection': 531,
#          'foursquare__sum_four_squaresp': 526,
#          'countability__is_countable': 518,
#          'continuity_ms_def__continuousp__1': 516,
#          'ii': 515,
#          'w': 513,
#          'minmax_orders__greatest': 512,
#          'compactness__compactp': 499,
#          'sets__remove': 497,
#          'convex_functions__f': 495,
#          'weierstrass_approximation__f': 494,
#          'integral_split__f!1': 494,
#          'bag_filters__l_filter': 491,
#          'nvectors__sqv': 488,
#          'bag_filters__u_filter': 480,
#          'continuous_functions__continuousp__1': 479,
#          'set_as_list__list2set': 476,
#          'distance_3D__dist': 464,
#          'sets__complement': 460,
#          'taylors__f!1': 457,
#          'd': 454,
#          'card_comp_set__card_eq': 453,
#          'polynomials__pseq': 449,
#          'function_image__image__1': 445,
#          'big_ops_nat__T': 438,
#          'integral_prep__xis!1': 435,
#          'dep-binding': 435,
#          'polynomials__power_linear': 434,
#          'polynomials__taylor_poly': 430,
#          'absconv_series__absconvergentp': 428,
#          'ring_one_generator__F': 424,
#          'bags__union': 423,
#          'ring_one_generator__G': 421,
#          'rs_integral_def__integrablep': 418,
#          'log_nat__log_nat': 416,
#          'l2': 413,
#          'riesz_bounded_functionals__op_norm': 412,
#          'step_fun_def__step_function_onp': 410,
#          'vectors_4D__norm': 405,
#          'more_list_props__T': 405,
#          'fundamental_theorem__f!1': 405,
#          'q': 401,
#          'product__T_pred': 400,
#          'finite_bags__T': 398,
#          'integral_bounded__f!1': 396,
#          'base_repr__base_n': 393,
#          'convex_functions__h': 388,
#          'power_series_deriv__FG': 385,
#          'sigma__restrict': 380,
#          'QuotientDefinition__rep': 378,
#          'integral_step__stp_sect': 377,
#          'sigma__T_pred': 376,
#          'list_adt__car': 376,
#          'real_fun_ops__const_fun': 372,
#          'sets__choose': 370,
#          'sets__add': 368,
#          'prime_factorization__ordered_list_of_primesp': 367,
#          'sets__singleton': 366,
#          'riesz_representation__gg': 366,
#          'continuous_functions__continuous_onp': 365,
#          'product__F': 364,
#          'cantor_bernstein_schroeder__B': 361,
#          'finite_sets_sum__sum': 357,
#          'sets__rest': 356,
#          'big_ops_nat__F': 356,
#          'list_adt__nullp': 354,
#          'group_def__subgroupp': 354,
#          'bounded_variation__ff': 354,
#          'det_2D__det': 352,
#          'nvectors__difference__2': 352,
#          'h': 350,
#          'lim_of_functions__convergentp': 348,
#          'more_list_props__prefixp': 348,
#          'sigma_nat__F': 348,
#          '1/2': 346,
#          'polynomials__nseq': 346,
#          'f1': 345,
#          'rs_integral_def__integral': 345,
#          'bits__bit_decoding': 344,
#          'sigma__F': 338,
#          'real_facts__f': 337,
#          'sets__fullset': 336,
#          'integral_split_scaf__F1': 335,
#          'integral_split_scaf__F2': 335,
#          'real_fun_preds__increasingp': 332,
#          'functions__surjectivep': 331,
#          'cantor_bernstein_schroeder__Bfun': 331,
#          'cantor_bernstein_schroeder__Arel': 328,
#          'derivative_inverse__G': 325,
#          'f2': 322,
#          'bags__intersection': 321,
#          'more_list_props__suffixp': 319,
#          'cont_real_vect2__f!1': 317,
#          'p_groups__T': 317,
#          'traces__T': 317,
#          'set_as_list_props__T': 314,
#          'atan__atan': 313,
#          'fundamental_theorem__F!1': 311,
#          'quad_minmax__quad_min_le_D_int': 308,
#          'right_left_cosets__divide': 308,
#          'ring_one_generator__F!1': 308,
#          'ring_one_generator__G!1': 308,
#          'convergence_functions__convergence': 307,
#          'integral_def__Rie_sum_alt': 306,
#          'riesz_interval_funs__fun_norm': 305,
#          'polynomials__Ffun': 303,
#          'set_as_list__T': 301,
#          'function_inverse__inverse': 300,
#          'more_polynomial_props__f': 300,
#          'log_int__log_int': 295,
#          'more_polynomial_props__poly_coeff_bound': 295,
#          'vect2_cont_dot__vr': 289,
#          'rs_partition__partition_union': 288,
#          'r1': 286,
#          'sigma_set__sigma': 285,
#          'harmonic_polynomials__F3': 282,
#          'lagrange__T': 282,
#          'polynomials__nseqa': 281,
#          'polynomials__nseqb': 281,
#          'vectors_4D__times__2': 279,
#          'prelude_sets_aux__P!1': 279,
#          'integral_pulse__f!1': 278,
#          'series__a!1': 277,
#          'power_series_integ__a!1': 276,
#          'metric_spaces__ball': 275,
#          'bits__bounding_bits': 274,
#          'gcd__rel_prime': 273,
#          '-2': 272,
#          'cross_metric_real_fun__f!1': 272,
#          'perpendicular_2D__perpL': 271,
#          'riesz_representation__LB': 271,
#          'sigma_nat__G': 269,
#          'integral_def__Rie_sec': 268,
#          'QuotientDefinition__EquivClass': 266,
#          'vect2_cont_dot__rr': 265,
#          'bounded_reals__sup': 264,
#          'integral_def__integralp': 262,
#          'integral_prep__Intv': 260,
#          'Lop': 259,
#          'cosets__times__2': 257,
#          'omega__T': 257,
#          'finite_sequences__finseq_appl': 256,
#          'integral_split_fun__split_fun2': 256,
#          'four_vects_2D_continuity__ggvc': 256,
#          'vect2_cont_dot__vv': 255,
#          'p_groups__p_groupp': 254,
#          'doubletons__T': 254,
#          'power_series_deriv_scaf__A2seq': 253,
#          'real_metric_space__real_dist': 251,
#          'vectors_4D__times__1': 251,
#          'polynomials__poly_shift': 250,
#          'p1': 248,
#          'termination__T': 245,
#          'distance__dist': 243,
#          'integral_cont__f!1': 242,
#          'minmax_orders__has_leastp__1': 241,
#          'integral_split_fun__split_fun': 241,
#          'sort_fseq__strictly_increasingp': 241,
#          'bernstein_polynomials__Bernstein_polynomial': 240,
#          'partitions_scaf__set2part': 240,
#          'vect_vect_2D_continuity__ggvc': 240,
#          'relation_iterate__iterate': 239,
#          'exp2__exp2': 238,
#          'complementary_lattices__dual': 236,
#          'r2': 235,
#          'vect2_cont_dot__rv': 234,
#          'four_vects_2D_continuity__ffvc': 234,
#          'lim_of_functions__lim': 233,
#          'sigma_nat__sig': 232,
#          'base_repr__F': 231,
#          'integral_split_scaf__f!1': 231,
#          'deriv_sigma__h!1': 229,
#          'declaredType': 228,
#          'riesz_representation__ff': 227,
#          'more_polynomial_props__max_linear_div_powerp': 225,
#          'space': 225,
#          'derivative_props__f': 225,
#          'stirling__S1_recur': 223,
#          'rs_integral_def__pum': 222,
#          'fs': 221,
#          'nvectors__norm': 218,
#          'p2': 218,
#          'convex_function_props__f': 217,
#          'xx': 216,
#          'angles_2D__v_from__2': 216,
#          'mucalculus__lesseqp': 216,
#          'vect_vect_2D_continuity__ffvc': 216,
#          'metric_spaces__openp': 214,
#          'polynomials__b': 212,
#          'polynomials__fk': 211,
#          'bits__bit_encoding': 210,
#          'polynomials__power_fs': 208,
#          'rel': 207,
#          'bernstein_polynomials__a': 206,
#          'bounded_orders__lub': 205,
#          'bags__purge': 205,
#          'real_facts__seq': 205,
#          'power_series_derivseq__derivseq': 203,
#          'exists1__uniquep': 203,
#          'bags__subbagp': 203,
#          'deriv_real_vect_def__deriv': 202,
#          'base_repr__upper_index': 202,
#          'cantor_bernstein_schroeder__ABrel': 202,
#          'stirling__S2_recur': 201,
#          'integral_cont_scaf__fmin': 201,
#          'bounded_orders__glb': 200,
#          'jj': 199,
#          'double_quadratic__quad_min_y_to_x': 199,
#          'bounded_reals__inf': 198,
#          'sigma_countable__PHI': 198,
#          'rs_integral_prep__g!1': 198,
#          'nat_indexed_sets__B!1': 198,
#          'bags__extract': 197,
#          'integral_cont_scaf__fmax': 197,
#          'bounded_variation__f': 197,
#          'minmax_orders__has_greatestp__1': 196,
#          'more_list_props__no_repetitionsp': 196,
#          'bounded_variation__total_variation': 196,
#          'riesz_representation__char_fun': 196,
#          'harmonic_polynomials__F2': 196,
#          'closure_ops__reflexive_closure': 195,
#          'basis_3D__orthogonalp': 193,
#          'power_series_conv__Inf_sum__1': 193,
#          'primes_sum_squares__sum_of_two_squaresp': 193,
#          'double_quadratic__rev_disc': 192,
#          'sort_seq__sort': 191,
#          'partitions_scaf__set2seq': 191,
#          'complementary_orders__C!1': 191,
#          'vectors_4D__difference__2': 190,
#          's1': 190,
#          'convergence_set__convergentp': 190,
#          'bernstein_polynomials__Bern_poly_inverse': 190,
#          'integral_prep__FF': 190,
#          'cont_vect3_real__continuous_vrp__1': 189,
#          'bounded_variation__variation_on': 189,
#          't1': 188,
#          'for_iterate__f': 188,
#          'derivative_props__f!1': 188,
#          'v1': 187,
#          'sqrt_approx__sqrt_newton_interv': 187,
#          'distance_2D__sq_dist': 187,
#          'cantor_bernstein_schroeder__f': 187,
#          'sigma_R_below__R_sigma_below': 186,
#          'distance__sq_dist': 184,
#          'div__div': 184,
#          'sort_fseq__sort': 184,
#          'piecewise_continuous__H': 184,
#          'convex_functions__convexp': 182,
#          'right_left_cosets__left_cosets': 182,
#          'more_list_props__caret__2': 182,
#          'power_series_deriv_scaf__Gseq': 180,
#          'step_fun_props__UUPart': 180,
#          'power_series_derivseq__a!1': 179,
#          'bernstein_polynomials__F': 179,
#          'polynomial_deriv__a': 178,
#          'foursquare__min_mult_sum_four_squaresp': 177,
#          'right_left_cosets__index': 177,
#          'countable_props__f!2': 175,
#          'reals__real_pred': 174,
#          'rs_integral_cont__gg': 174,
#          'vect_deriv_2D__V': 173,
#          'vect_cont_2D__vr1': 173,
#          'more_polynomial_props__bb': 173,
#          'rs_integral_cont__f': 173,
#          'e': 172,
#          'integral_pulse__xis!1': 172,
#          'cantor_bernstein_schroeder__g': 172,
#          'sets__Intersection': 171,
#          'indexed_sets__IUnion': 171,
#          'Maybe__val': 171,
#          'absconv_series__f!1': 170,
#          'sigma_nat__FF': 170,
#          'harmonic_polynomials__F1': 170,
#          'bounded_orders__least_upper_boundp__1': 169,
#          'pn': 168,
#          'cont_vect2_real__continuous_vrp__2': 167,
#          'bags__emptyp': 167,
#          'bounded_orders__upper_boundp__1': 167,
#          'vect_cont_2D__vr2': 167,
#          'uniform_continuity__f!1': 167,
#          'piecewise_continuous__f!1': 167,
#          'vectors_4D__plus': 166,
#          'countability__is_countably_infinite': 166,
#          'bounded_orders__greatest_lower_boundp__1': 166,
#          'real_fun_on_compact_sets__f!1': 165,
#          '<=': 164,
#          'cross_metric_real_fun__T1': 164,
#          'nn': 163,
#          'swap_counting__swap_count': 163,
#          'polynomials__psqueaka': 163,
#          'polynomials__psqueakb': 163,
#          'integral_bounded__MAXj': 162,
#          'polynomials__eventzero': 162,
#          'metric_space_real_fun__f!1': 162,
#          'infinite_nat_def__GG': 162,
#          'series__conv_seriesp__2': 161,
#          'integral_bounded__MINj': 161,
#          'uniform_continuity__uniformly_continuousp': 159,
#          'card_comp_set__card_le': 159,
#          'polynomials__Fdfun': 159,
#          'doubletons__dbl': 158,
#          'distance_3D__sq_dist': 157,
#          'more_polynomial_props__only_root_betweenp': 157,
#          's2': 156,
#          'inv': 156,
#          'finite_enumeration__finite_enumeration': 155,
#          'finite_sets_minmax__max': 155,
#          'sigma_3D__T_pred': 154,
#          'sign3__sign3': 154,
#          'limit_vect3_real__convergence': 154,
#          'epsilons__epsilon': 153,
#          'integral_step__f!1': 153,
#          'sets__Union': 152,
#          'nat_indexed_sets__IUnion': 152,
#          'limit_vect2_real__convergence': 152,
#          'more_polynomial_props__aa': 152,
#          'integral_chg_var__phi!1': 152,
#          'perpendicular_2D__perpR': 151,
#          'sigma_countable__DX': 151,
#          'ring_one_generator__R': 151,
#          'nzv': 150,
#          '10': 150,
#          'list_adt__every__1': 150,
#          'four_vects_2D_continuity__ffrc': 150,
#          'sigma_2D__T_pred': 150,
#          'for_iterate__T': 150,
#          'quad_minmax__quad_min_int': 149,
#          'card_comp_set__card_lt': 149,
#          'base_repr__numseq': 149,
#          'x1': 148,
#          'concat_arrays__oh': 148,
#          'pointwise_orders__R': 148,
#          'complementary_orders__T': 148,
#          'bounded_variation__ssm': 148,
#          'group_def__groupp': 147,
#          'bounded_orders__least_bounded_abovep__1': 147,
#          'function_image__inverse_image__1': 147,
#          'riesz_representation__fun_to_op': 147,
#          'cont_vect2_real__continuous_vrp__1': 147,
#          'vectors_2D__difference__1': 146,
#          'continuous_functions_props__g!1': 146,
#          'real_fun_ops__divide__2': 145,
#          'vect_vect_2D_continuity__gg': 145,
#          'rationals__rational_pred': 144,
#          'group_def__finite_groupp': 144,
#          'Maybe__somep': 144,
#          'seq_extras__rest': 144,
#          'real_fun_supinf__sup': 144,
#          'limit_vect_real__convergence': 144,
#          'power_series_integ__integseq': 143,
#          'compactness__open_coverp': 143,
#          'four_vects_2D_continuity__gg': 143,
#          'vectors_2D__VS': 143,
#          'lift_adt__lift': 143,
#          'riesz_hahn_banach__constchoose': 143,
#          'nat_indexed_sets__A!1': 143,
#          'nnx': 141,
#          'p_groups__G!1': 141,
#          'normalizer_centralizer__normalizer': 140,
#          'rs_integral_prep__f!1': 140,
#          'operator_defs__commutativep': 139,
#          'bernstein_polynomials__aa': 139,
#          'ff': 138,
#          'deriv_real_vect2__derivable_rvp': 138,
#          'deriv_real_vect2__deriv': 138,
#          'fseqs__oh': 138,
#          'bags__member': 138,
#          'more_polynomial_props__poly_continuity_const': 137,
#          'polynomials__gg': 135,
#          'metric_space_real_fun__g!1': 135,
#          'product__restrict': 134,
#          'cardinal__cardinal': 134,
#          'vect_vect_2D_continuity__ffrc': 134,
#          'v2': 133,
#          'D': 133,
#          'numbers__number': 133,
#          'metric_spaces_def__metric_spacep': 132,
#          'e1': 132,
#          'mucalculus__mu': 132,
#          'normalizer_centralizer__CLs_nc': 132,
#          'continuity_interval__f!1': 132,
#          'fseqs__caret': 131,
#          'real_fun_ops__caret': 130,
#          'sort_fseq__strictly_sort_map': 129,
#          'derivative_inverse__f': 129,
#          'derivative_inverse__psi!1': 129,
#          'integral_cont_scaf__f!1': 129,
#          'cosets_def__plus__1': 127,
#          'finite_sets_minmax__min': 127,
#          'integral_def__eq_partition': 127,
#          'big_ops_nat__sig': 127,
#          'weierstrass_approximation__BNf': 127,
#          'cross_metric_uniform_continuity__seq!1': 127,
#          'real_fun_ops__divide__1': 126,
#          'vectors_2D__caret': 125,
#          'convergence_sequences__u!1': 125,
#          'mucalculus__nu': 124,
#          'step_fun_scaf__UnionPart': 124,
#          'convergence_functions__adh': 124,
#          'series_aux__a!1': 124,
#          'series_lems__a!1': 124,
#          'continuous_lambda__f1': 124,
#          'eps': 123,
#          '8': 123,
#          'more_polynomial_props__h': 123,
#          'delta': 122,
#          '<': 122,
#          'card_comp_set__card_ge': 122,
#          'riesz_hahn_banach__funchoose': 122,
#          'finite_bags__is_finite': 121,
#          'real_defs__sgn': 120,
#          'normal_subgroups__normal_subgroupp': 120,
#          'lift_adt__down': 120,
#          'set_as_list__reduce_sl': 120,
#          'power_series_derivseq__BS': 120,
#          'homomorphisms__T1': 120,
#          'closure_ops__T': 120,
#          'limit_real_vect2__f!1': 119,
#          'middle_value_select__T': 119,
#          'group_action__Fix': 118,
#          'bounded_orders__lower_boundp__1': 118,
#          'traces__reachable': 118,
#          'card_comp_set__card_gt': 118,
#          'continuous_lambda__f2': 118,
#          't0': 117,
#          'homomorphisms__phi!1': 117,
#          'cont_real_vect2__continuous_rvp__1': 116,
#          'finite_sequences__oh': 116,
#          'omega__gt_n': 116,
#          'sigma_countable__DY': 116,
#          'real_facts__sub': 116,
#          'new_mucalculus_prop__F!1': 116,
#          'sequence_props__subseq': 115,
#          'min_nat__min': 115,
#          'deriv_real_vect2__f1!1': 115,
#          'deriv_real_vect2__f2!1': 115,
#          'convex_functions__strictly_convexp': 114,
#          'relations__TC': 114,
#          'vectors_2D__ns': 114,
#          'bounded_real_defs__lub': 113,
#          'riesz_representation__step_approx': 113,
#          'sigma_2D__F': 113,
#          'sigma_3D__F': 113,
#          'more_polynomial_props__g': 113,
#          'big_ops_nat__FF': 112,
#          'bounded_orders__greatest_bounded_belowp__1': 111,
#          'integral_diff_doms__U_pred': 111,
#          'interm_value_thm__f!1': 111,
#          'derivative_props__T_pred': 111,
#          'relations_extra__T': 110,
#          'e2': 109,
#          'ring_one_generator__F_one_gen': 109,
#          'fseqs__member': 109,
#          'fault_masking_vote__T': 109,
#          'sort_fseq__increasingp': 108,
#          'booleans__TRUE': 107,
#          'trackAngles_2D__track': 107,
#          'integral_diff_doms__T_pred': 107,
#          'integral_split_scaf__find_P_sec': 107,
#          'tsplit1': 106,
#          'cantor_bernstein_schroeder__Brel': 106,
#          'real_fun_supinf__inf': 105,
#          'swap_counting__seq': 105,
#          'nvectors__plus': 104,
#          'init': 104,
#          'Maybe__nonep': 104,
#          'more_polynomial_props__inz': 104,
#          'riesz_representation__f': 104,
#          'modulo_arithmetic__rem': 103,
#          'p_groups__alt': 103,
#          'tt': 101,
#          'list_adt__consp': 101,
#          'relations__antisymmetricp': 101,
#          'tsplit2': 101,
#          'polynomials__pseqa': 101,
#          'polynomials__pseqb': 101,
#          'new_mucalculus_prop__C!1': 101,
#          'finite_pointwise_orders__D': 101,
#          'cont_real_vect2__continuous_rvp__2': 100,
#          'max_bounded_posnat__max': 100,
#          'ramsey_graph__Ramsey_edge_fun': 100,
#          'permutations_list__count': 100,
#          'unif_cont_fun__uniformly_continuousp': 100,
#          'real_facts__g': 100,
#          'more_polynomial_props__rootseq': 100,
#          'infinite_pigeonhole__R': 100,
#          'exists1__exists1': 99,
#          'list2set__list2set': 99,
#          'convergence_sequences__cauchy': 99,
#          'traces__tr': 99,
#          'x0': 98,
#          'phi': 98,
#          'real_metric_space__seq_intv_scaf': 98,
#          'series_aux__MM': 98,
#          'series_lems__MM': 98,
#          'vectors_2D__orthogonalp': 97,
#          'cardinal__lesseqp': 97,
#          'permutations_list__T': 97,
#          'more_polynomial_props__pp': 96,
#          'rs_integral_prep__f': 96,
#          'cross_metric_cont__uniformly_continuous_in_firstp': 95,
#          'relation_defs__converse': 95,
#          'vectors__u!1': 95,
#          'cross_3D__cross': 94,
#          'ak': 94,
#          'compactness__T': 94,
#          'bernstein_polynomials__Bern_subdiv_l': 93,
#          'y1': 92,
#          'series__geometric': 92,
#          'finite_sequences__caret': 92,
#          'cosets_def__divide': 92,
#          'finite_below__nth': 92,
#          'riesz_interval_funs__bounded_on_intp': 92,
#          'complementary_lattices__C!1': 92,
#          'a1': 91,
#          'sqrt_approx__sqrt_newton_interv_lower': 91,
#          'ring_def__commutative_ringp': 91,
#          'aa': 90,
#          'a2': 90,
#          'set_as_list__equal_sl': 90,
#          'vect2_cont_dot__vv1': 90,
#          'derivative_props__g!1': 90,
#          'metric_spaces__open_inp': 89,
#          'deriv_real_vect2__f!1': 89,
#          'chinese_remainder__mseq': 89,
#          'sigma_bijection__phi!1': 89,
#          'root__f': 89,
#          'p0': 88,
#          'trig_fun__sin': 88,
#          'pointwise_orders__pointwise': 88,
#          'set_as_list__v': 88,
#          'tdiv__tdiv': 87,
#          'real_fun_preds__strict_increasingp': 87,
#          'relations__transitivep': 87,
#          'integer_enumerations__enum': 87,
#          'integral_split_fun__in_orderp__1': 87,
#          'cardinal__lessp': 87,
#          'linear_transformations_2D__F': 87,
#          'sigma_swap__F': 87,
#          'root__g': 87,
#          'polynomials__GG': 87,
#          'seq_extras__delete': 86,
#          'for_iterate__ext2int__2': 86,
#          'unif_cont_fun__f!1': 86,
#          'deriv_domain_def__not_one_elementp': 85,
#          'angles_2D__angle': 85,
#          'epsil': 85,
#          'vectors_2D__nnss': 84,
#          'F': 84,
#          'polynomials__aa': 84,
#          'polynomials__poly_integral': 84,
#          'polynomials__P': 83,
#          'metric_spaces__T': 83,
#          'deriv_real_vect_def__derivablep': 82,
#          'double_quadratic__quad_min_y': 82,
#          'vect2_cont_dot__rv1': 82,
#          'countable_convergence__DY': 82,
#          'big_ops_nat__G': 82,
#          'cont_vect__continuous_vvp__1': 81,
#          'real_fun_ops__abs': 81,
#          'seq_extras__add_first': 81,
#          'bounded_variation__bounded_variationp': 81,
#          'integral_step__sumof': 81,
#          'bounded_real_defs__upper_boundp__1': 81,
#          'limit_vect__convergence': 81,
#          'polynomials__bb': 81,
#          'vectors__difference__1': 80,
#          'bags__disjointp': 80,
#          'function_image__image__2': 80,
#          'closest_approach__s': 80,
#          'fseq2set__T': 80,
#          'riesz_representation__LC': 80,
#          'v3': 79,
#          'more_list_props__rdc': 79,
#          'cardinal__greatereqp': 79,
#          'limit_vect_real__f!1': 79,
#          'limit_vect__f': 79,
#          'series__b!1': 79,
#          'fs1': 78,
#          'real_fun_preds__bounded_abovep': 78,
#          'product__G!1': 78,
#          '1000': 78,
#          'ring_with_one_prime_ideal__T': 78,
#          'finite_pointwise_orders__seq!1': 78,
#          'finite_bags_inductions__pb!1': 78,
#          'uniform_continuity__S': 78,
#          'closest_approach__time_closest__1': 77,
#          'termination__terminating': 77,
#          'ordered_list__ordered_listp': 77,
#          'cardinal__greaterp': 77,
#          'polynomial_deriv__b': 77,
#          'bounded_reals__min': 76,
#          'tuple2nat__tuple2nat2': 76,
#          'polynomials__fn1': 76,
#          'sort_fseq__T': 76,
#          'bounded_reals__below_bounded': 75,
#          'epsilon': 75,
#          'relation_iterate__iterate_n': 75,
#          'tr': 75,
#          'traces__length': 75,
#          'pair': 75,
#          'vectors_4D__difference__1': 74,
#          'xl': 74,
#          'group_def__abelian_groupp': 74,
#          'ordered_subset__below': 74,
#          'finite_sets__Card': 74,
#          'vect_vect_2D_continuity__ggrc': 74,
#          'four_vects_2D_continuity__ggrc': 74,
#          'countable_convergence__DX': 74,
#          'lifted_orders__T': 74,
#          'pointwise_orders__D': 74,
#          'chain_rule__f!1': 74,
#          'four_vects_2D_continuity__continuous_vvrp': 73,
#          't2': 73,
#          'bernstein_polynomials__Bern_sweep': 73,
#          'N': 73,
#          'fx': 72,
#          'best_rational__frac_nn_int': 72,
#          'closest_approach__w': 72,
#          'power_series_deriv__FA': 72,
#          'bounded_variation__g': 72,
#          'rs_integral_prep__h!1': 72,
#          'countable_props__x!2': 72,
#          'linear_transformations_2D__linear_functionalp': 71,
#          'product_seq__product': 71,
#          'foursquare__sum_four_squares_intp': 71,
#          'real_fun_preds__decreasingp': 71,
#          'ring_ideal_def__idealp': 71,
#          'more_list_props__take': 71,
#          'linear_transformations_2D__L': 71,
#          'sigma_bijection__F!1': 71,
#          'polynomials__FF': 71,
#          'integral_split__f2!1': 71,
#          'integral_split__f1!1': 71,
#          'deriv_domain_def__deriv_domainp': 70,
#          'trig_fun__cos': 70,
#          'indefinite_integral__integral': 70,
#          'n0': 70,
#          'rrel': 70,
#          'vect2_cont_dot__vv2': 70,
#          'sigma_swap__G': 70,
#          'complementary_orders__rel!1': 70,
#          'big_ops_nat__times': 70,
#          'cont_vect2_vect2__continuous_vvp__2': 69,
#          'div_nat__div': 69,
#          'orders__partial_orderp': 69,
#          'set_as_list__subset_slp': 69,
#          'integral_split_fun__split_fun3': 69,
#          'limit_vect2_real__convergentp': 69,
#          'limit_vect3_real__convergentp': 69,
#          'sigma__G': 69,
#          'derivative_inverse__F': 69,
#          'vectors_2D__zero': 68,
#          'polynomials__polynomial_int': 68,
#          'bernstein_polynomials__Bern_subdiv_left': 68,
#          'real_fun_preds__bounded_belowp': 68,
#          'lift_adt__upp': 68,
#          'function_inverse_def__left_inversep__1': 68,
#          'function_inverse_def__right_inversep__1': 68,
#          'convergence_sequences__accumulation': 68,
#          'rs_integral_def__integralp': 68,
#          'integral_split__xisa!1': 68,
#          'list_adt__null': 67,
#          'integration_by_parts__v!1': 67,
#          'fk': 66,
#          'fn1': 66,
#          'lift_adt__up': 66,
#          'closest_approach_2D__divergentp': 65,
#          'bb': 65,
#          'r3': 65,
#          'for_iterate__for_def': 65,
#          's3': 65,
#          'limit_vect_real__convergentp': 65,
#          'closest_approach_2D__time_closest': 65,
#          'ramsey_graph__F': 65,
#          'majority_array__A!1': 65,
#          'quad_minmax__is_minimump': 64,
#          '5': 64,
#          'fs2': 64,
#          'eq_mod__eq_mod': 64,
#          'orders__total_orderp': 64,
#          'closure_ops__preorder_closure': 64,
#          'more_polynomial_props__BBR': 64,
#          'more_polynomial_props__negsign': 64,
#          'finite_bags__A!1': 64,
#          'set2seq__set2seq': 64,
#          'convergence_ops__s1!1': 64,
#          'vectors_3D__difference__1': 63,
#          'tmod__mod': 63,
#          'ee': 63,
#          'limit_vect3_real__f!1': 63,
#          'limit_vect2_real__f!1': 63,
#          'continuous_linear__f!1': 63,
#          'real_fun_on_compact_sets__T': 63,
#          'countable_props__T': 63,
#          'bounded_reals__ext': 62,
#          'cont_vect3_real__continuous_vrp__2': 62,
#          'double_quadratic__quad_min_x': 62,
#          'monotone_sequences__descendingp': 62,
#          'max_seq__max': 62,
#          'riesz_function_sets__bounded_linear_subspacep': 62,
#          'vect2_cont_dot__rv2': 62,
#          'series_aux__nna!1': 62,
#          'series_lems__nna!1': 62,
#          'ring_with_one_prime_ideal__P!1': 62,
#          'traces__rel': 62,
#          'derivatives_def__g!1': 62,
#          'integral_split__xisb!1': 62,
#          'kk': 61,
#          'best_rational__frac_nn_meas': 61,
#          'orders__well_foundedp': 61,
#          'lt': 61,
#          'relations__reflexivep': 61,
#          'sets__fullp': 61,
#          'drel': 61,
#          'for_iterate__iterate_left_def': 61,
#          'for_iterate__iterate_right_def': 61,
#          'metric_spaces__closedp': 61,
#          'closest_approach_3D__time_closest__1': 61,
#          'sigma_nat__GG': 61,
#          'group__generated_by': 61,
#          'q0': 60,
#          'relations__equivalencep': 60,
#          'nat_list_enum__double_nat_enum': 60,
#          'finite_below__index': 60,
#          'cayleys__x!1': 60,
#          'termination__fseq': 60,
#          'complementary_lattices__T': 60,
#          'Shroeder_Bernstein__B': 60,
#          'power_series_conv__simple': 59,
#          'bounded_real_defs__bounded_abovep': 59,
#          'fixed_points__prefixed_pointp': 59,
#          'majority_vote__majp': 59,
#          'for_iterate__for': 59,
#          'integral_bounded__bounded_on_allp': 59,
#          'more_polynomial_props__Bh': 59,
#          'normalizer_centralizer__centralizer': 59,
#          'minmax_seq2set__T': 59,
#          'integral_split__T_pred': 59,
#          'bags__plus': 58,
#          'vect_3D_2D__vect2': 58,
#          'lines_2D__on_linep': 58,
#          'a_n': 58,
#          'product__G': 58,
#          'finite_bags__B!1': 58,
#          'integral_split_scaf__XPP': 58,
#          'integral_split_scaf__XP': 58,
#          'integration_by_parts__u!1': 58,
#          'convergence_functions__E!1': 58,
#          'countable_props__Q!1': 58,
#          'real_fun_preds__boundedp': 57,
#          'bounded_orders__bounded_belowp__1': 57,
#          'vect_vect_2D_continuity__continuous_vvrp': 57,
#          'taylor_series__a!1': 57,
#          'more_polynomial_props__Bhnew': 57,
#          'more_polynomial_props__Pnew': 57,
#          'matrices__times__3': 56,
#          'nna': 56,
#          'set_as_list__strict_subset_slp': 56,
#          'compactness__ball_covering': 56,
#          'limit_vect2_vect2__f!1': 56,
#          'product_nat__F!1': 56,
#          'more_polynomial_props__IG': 56,
#          '10/3': 56,
#          'finite_pointwise_orders__g!1': 56,
#          'integral_step__xis!1': 56,
#          'deriv_real_vect__derivablep': 55,
#          'taylor_series__nderivseq': 55,
#          'fseqs__fseq1': 55,
#          'minmax_orders__leastp__1': 55,
#          'gg': 54,
#          'vectors_3D__orthogonalp': 54,
#          'relation_props__oh': 54,
#          'sigma_2D__restrict': 54,
#          'sigma_3D__restrict': 54,
#          'countable_convergence__a!1': 54,
#          'convex_functions__newquad': 54,
#          'homomorphisms__G!1': 54,
#          'lower_semilattices__T': 54,
#          'similarity_props__D': 54,
#          'upper_semilattices__T': 54,
#          'integral_diff_doms__xis!1': 54,
#          'cont_vect2_vect2__continuous_vvp__1': 53,
#          'permutations_fseq__permutationp': 53,
#          'bounded_real_defs__glb': 53,
#          'quadratic_2b__discr2b': 53,
#          'for_iterate__iterate_left': 53,
#          'tsplit3': 53,
#          'compactness__finite_coverp': 53,
#          'riesz_interval_funs__f!1': 53,
#          'mod_nat__nmod': 52,
#          'bernstein_polynomials__Bern_coeff': 52,
#          'cosets_def__cosetp': 52,
#          'rs_partition__partition_union_map': 52,
#          'vectors__v': 52,
#          'for_iterate__inv': 52,
#          'integral_prep__gxis': 52,
#          'countable_props__x!1': 52,
#          'closest_approach__divergentp': 51,
#          'power_series_integ__integ_powerseq': 51,
#          '6': 51,
#          'bounded_reals__above_bounded': 51,
#          'bounded_orders__bounded_abovep__1': 51,
#          'termination__normal': 51,
#          'continuous_linear__T_pred': 51,
#          'limit_real_vect2__convergence': 51,
#          'polynomials__fp': 51,
#          'partitions_scaf__S!1': 51,
#          'taylors__FF!1': 51,
#          'compactness__seq!1': 51,
#          'between_2D__betweenp': 50,
#          'l0': 50,
#          'trig_fun__altsign': 50,
#          'polynomials__neg_power_fs': 50,
#          'bounded_real_defs__bounded_belowp': 50,
#          'function_inverse_alt__inverse_alt': 50,
#          'xis': 50,
#          'product_nat__F': 50,
#          'sigma_R_below__F!1': 50,
#          'pointwise_orders__ff!1': 50,
#          'count_functions__v': 50,
#          'bag_filters__B!1': 50,
#          'uniform_continuity__A!1': 50,
#          'nvectors__zero': 49,
#          'taylors__Taylor_rem': 49,
#          'primes_sum_squares__fermat_prime_sos_set': 49,
#          'ma': 49,
#          'o': 49,
#          'limit_vect2_vect2__convergence': 49,
#          'sets__emptyset': 48,
#          'bags_aux__filter': 48,
#          'set_as_list__card_sl': 48,
#          'interval_minmax__min_x': 48,
#          'interval_minmax__max_x': 48,
#          'vect3_Heine__f!1': 48,
#          'vect2_Heine__f!1': 48,
#          'bounded_real_defs__least_upper_boundp__1': 48,
#          'absconv_series__a!1': 48,
#          'absconv_series_aux__aa!1': 48,
#          'lagrange__G!1': 48,
#          'complementary_lattices__H!1': 48,
#          'rs_integral_prep__gg': 48,
#          'cross_metric_uniform_continuity__f!1': 48,
#          'continuity_ms_def__continuousp__2': 47,
#          'taylor_series__T_pred': 47,
#          'power_series_deriv_scaf__T_pred': 47,
#          'xu': 47,
#          'dirvars': 47,
#          'sort_array__sortedp': 47,
#          'continuity_ms_def__continuous_atp__1': 47,
#          'countable_indexed_sets__XS!1': 47,
#          'cross_3D__linearly_dependentp': 46,
#          'mm': 46,
#          'fy': 46,
#          'sets_lemmas__Complement': 46,
#          'max_fseq__max': 46,
#          'permutations_list__permutation_list': 46,
#          'tsplit': 46,
#          'integral_split_fun__in_orderp__2': 46,
#          'pattern': 46,
#          'backquote': 46,
#          'apply': 46,
#          'continuous_linear__f1!1': 46,
#          'unif_cont_fun__XX!1': 46,
#          'integral_split_fun__r1': 46,
#          'CI': 46,
#          'x2': 45,
#          'n1': 45,
#          'four_vects_2D_continuity__continuous_vvvp': 45,
#          'product_seq_scaf__product_rec': 45,
#          'monotone_sequences__ascendingp': 45,
#          'lower_semilattices__glb': 45,
#          'integral_bounded__bounded_onp': 45,
#          'ys': 45,
#          'indexed_sets_aux__disjointp': 45,
#          'power_series__a!1': 45,
#          'normalizer_centralizer__CL': 45,
#          'integral_diff_doms__f!1': 45,
#          'integral_diff_doms__g!1': 45,
#          'b2': 44,
#          'tuple2nat__nat2tuple': 44,
#          'rn': 44,
#          'ring_prime_ideal_def__prime_idealp': 44,
#          'product_coset_def__product': 44,
#          'monad_def__monadp': 44,
#          'group_action__group_actionp': 44,
#          'ordered_subset__suffixp__1': 44,
#          'subrange_list__make_srl': 44,
#          'indexed_list__first': 44,
#          'sigma_2D__G': 44,
#          'sigma_3D__G': 44,
#          'ramsey_graph__II': 44,
#          'fermats_little_theorem__FF': 44,
#          'sigma_countable__CXY': 44,
#          'base_repr__G': 44,
#          'integral_split_fun__r2': 44,
#          'riesz_hahn_banach__ch': 44,
#          'countable_indexed_sets__YS!1': 44,
#          'y2': 43,
#          'nvectors__difference__1': 43,
#          'series__conv_seriesp__1': 43,
#          'nny': 43,
#          'product_orders__times': 43,
#          'indexed_sets__IIntersection': 43,
#          'more_list_props__rac': 43,
#          'rs_partition__partition_union_map_inv': 43,
#          'best_rational__F': 43,
#          'more_polynomial_props__Bb': 43,
#          'more_polynomial_props__Ba': 43,
#          'integral_prep__SS': 43,
#          'sig': 42,
#          'more_polynomial_props__Knuth_poly_pos_root_bound': 42,
#          'orders__dichotomousp': 42,
#          'closure_ops__transitive_closure': 42,
#          'min_fseq__min': 42,
#          'deriv_dot_prod__f1!1': 42,
#          'deriv_dot_prod__f2!1': 42,
#          'new_mucalculus_prop__T': 42,
#          'for_iterate__oh': 42,
#          'nzu': 41,
#          'taylors__inf_deriv_funp': 41,
#          'sets__strict_subsetp': 41,
#          'upper_semilattices__lub': 41,
#          'functions__preserves__1': 41,
#          'lifted_orders__lift': 41,
#          'xs': 41,
#          'S1': 41,
#          'S2': 41,
#          'derivatives_alt__fp!1': 41,
#          'vect_fun_ops_rv__times__2': 40,
#          'vectors_4D__zero': 40,
#          'tdiv__sgn': 40,
#          'xyz': 40,
#          'sqrt_approx__sqrt_newton_step': 40,
#          'harmonic_polynomials__harmonic_poly_imag': 40,
#          'r_1': 40,
#          'closure_ops__irreflexive_kernel': 40,
#          'count_functions__update': 40,
#          'funsplit': 40,
#          'domsplit': 40,
#          'sigma_countable__DXY': 40,
#          'traces__rn': 40,
#          'inverse_continuous_functions__g!1': 40,
#          'countable_props__f!1': 40,
#          'deriv_real_vect__deriv': 39,
#          'lines_3D__vel_from_tm': 39,
#          'linear_transformations_2D__linear_transformp': 39,
#          'bound_defs__upper_bound': 39,
#          'cosets__right_coset': 39,
#          'function_image__inverse_image__2': 39,
#          'ordered_subset__upto': 39,
#          'sigma_countable__phi!1': 39,
#          'p_groups__H!1': 39,
#          'integral_prep__g!1': 39,
#          'ns': 38,
#          'rem__rem': 38,
#          'ec': 38,
#          'nat_list_enum__nat_pair_to_list_length': 38,
#          'traces__finite_tracep': 38,
#          'ol': 38,
#          'set_as_list__difference_sl': 38,
#          'sort_inversions__inversions': 38,
#          'seq_extras__first': 38,
#          'piecewise_continuous__piecewise_continuousp__2': 38,
#          'limit_vect__convergentp': 38,
#          'primes_sum_squares__invol!1': 38,
#          'more_polynomial_props__AA': 38,
#          'lagrange__H!1': 38,
#          'cayleys__G!1': 38,
#          'traces__init': 38,
#          'Shroeder_Bernstein__comp_n': 38,
#          'Shroeder_Bernstein__psinv': 38,
#          'continuous_linear__f2!1': 38,
#          'cross_metric_real_fun__Y!1': 38,
#          'countable_indexed_sets__f!1': 38,
#          'vectors_3D__zero': 37,
#          '7': 37,
#          'polynomials__poly_translate_inf_pos': 37,
#          'real_fun_preds__constantp': 37,
#          'ordered_subset__prefixp__1': 37,
#          'rs_partition__partjoin': 37,
#          'lifted_orders__r!1': 37,
#          'piecewise_continuous__f': 37,
#          'integral_split__f2!2': 37,
#          'integral_split__f1!2': 37,
#          'real_fun_on_compact_sets__seq': 37,
#          'four_vects_2D_continuity__dot_vvv': 36,
#          'reals_mod__mod': 36,
#          'restrict_sigma__T_pred': 36,
#          'root__root_pos': 36,
#          'bernstein_polynomials__Bern_subdiv_r': 36,
#          'harmonic_polynomials__harmonic_poly_real': 36,
#          'orders__strict_total_orderp': 36,
#          'ord': 36,
#          'count_functions__listrep': 36,
#          'primes_sum_squares__g': 36,
#          'real_fun_ops_aux__f!1': 36,
#          'unif_cont_fun__YY!1': 36,
#          'taylors__PHI': 36,
#          'root__root_real': 35,
#          'ch': 35,
#          'permutations_seq__permutationp': 35,
#          'bags__delete': 35,
#          'set_as_list__set_list_eq': 35,
#          'for_iterate__iterate_right': 35,
#          'piecewise_continuous__piecewise_continuousp__3': 35,
#          'series_aux__phi!1': 35,
#          'series_lems__phi!1': 35,
#          'sigma_countable__PSI': 35,
#          'more_polynomial_props__newb': 35,
#          'lifted_orders__rel!1': 35,
#          'fault_masking_vote__A!1': 35,
#          'rs_integral_prep__SS': 35,
#          'b1': 34,
#          'cross_3D__specialbrackets': 34,
#          'xp': 34,
#          'nat_list_enum__double_nat_enum_inv': 34,
#          'restrict_product__T_pred': 34,
#          'minpt': 34,
#          'r4': 34,
#          'tlow': 34,
#          'orders__preorderp': 34,
#          'caret_arrays__caret': 34,
#          'bags__singleton_bag': 34,
#          'more_list_props__last': 34,
#          'more_list_props__takeFromRight': 34,
#          'limit_real_vect2__f': 34,
#          'vect_vect_2D_continuity__dot_vvv': 34,
#          'bounded_real_defs__greatest_lower_boundp__1': 34,
#          'mucalculus_prop__F!1': 34,
#          'more_list_props__x!1': 34,
#          'derivatives_lam__f!1': 34,
#          'convergence_functions__f!1': 34,
#          'vect_vect_2D_continuity__continuous_vvvp': 33,
#          'a3': 33,
#          'indefinite_integral__integrablep': 33,
#          'taylor_series__GET_C': 33,
#          'sqrt_approx__sqrt_lb': 33,
#          'nat_list_enum__nat_pair_to_list_length_inv': 33,
#          'real_fun_preds__strict_decreasingp': 33,
#          'dom': 33,
#          'more_list_props__sublistp': 33,
#          'array2list__list2array': 33,
#          'fseq2set__set2seq': 33,
#          'compactness__idxCover': 33,
#          'pq': 33,
#          'atan2__atan2': 33,
#          'closest_approach_3D__divergentp': 33,
#          'primes_sum_squares__FF': 33,
#          'partial_order_lift__T': 33,
#          'Shroeder_Bernstein__f': 33,
#          'Shroeder_Bernstein__A': 33,
#          'real_fun_on_compact_sets__S!1': 33,
#          'rs_partition__xx!1': 33,
#          'nat_surjection__F': 33,
#          'len': 32,
#          'series__inf_sum__1': 32,
#          'deriv_domain_def__connectedp': 32,
#          'cc': 32,
#          'real_orders__neg_rel': 32,
#          'nnz': 32,
#          'minmax_orders__greatestp__1': 32,
#          'omega__Omega': 32,
#          'sss': 32,
# ...
#          'matrices__sol_eqs': 2,
#          'cr': 2,
#          'vectors_dot_alt__dot': 2,
#          'cs': 2,
#          'power_series_conv__Inf_sum__2': 2,
#          'cnz': 2,
#          'power_series__series_convergent_only_at_0': 2,
#          'power_series__series_convergent_within': 2,
#          'sigma_below__n': 2,
#          'abstract_max__p': 2,
#          'abstract_min__p': 2,
#          'abstract_min__min': 2,
#          'abstract_min__size': 2,
#          'ngi2': 2,
#          'mk': 2,
#          'ai': 2,
#          'ms': 2,
#          'infinite_primes__Primes': 2,
#          'aseq': 2,
#          'polynomials__poly_scal': 2,
#          'eventzero': 2,
#          'ar': 2,
#          'nseq': 2,
#          'pseq': 2,
#          'uu': 2,
#          'quad_minmax__is_maximump': 2,
#          'my': 2,
#          'unk': 2,
#          '52': 2,
#          'reals_safe_ops__div_safe': 2,
#          'reals_safe_ops__sqrt_safe': 2,
#          'reals_safe_ops__pow_safe': 2,
#          '101': 2,
#          'base_repr__base_to_array': 2,
#          'relreal': 2,
#          'sqrt__ge__1': 2,
#          'sqrt__le__1': 2,
#          'sqrt__ge__2': 2,
#          'sqrt__le__2': 2,
#          'fs_nnr': 2,
#          'fs_npr': 2,
#          'fpr': 2,
#          'get_inf': 2,
#          'get_real': 2,
#          'inf?_var': 2,
#          'inf?_var2': 2,
#          'RealInt__infp': 2,
#          'RealInt__ninfp': 2,
#          'RealInt__openp': 2,
#          'RealInt__specialbrackets__2': 2,
#          'RealInt__specialbrackets__1': 2,
#          'fnpr': 2,
#          'fposreal': 2,
#          'frat': 2,
#          'fint': 2,
#          'floor_ceil__fractional': 2,
#          'ring_unit_def__times': 2,
#          'ring_unit_def__one': 2,
#          'homomorphisms__one1': 2,
#          'fsz': 2,
#          'cartesian_product_finite__cartesian_product_one': 2,
#          'ring_one_generator__plus': 2,
#          'zp_group__n': 2,
#          'integral_domain_with_one_def__integral_domain_w_onep': 2,
#          'homomorphisms__isomorphicp': 2,
#          'sequences__suffix': 2,
#          'lex2_more__lt': 2,
#          'lta': 2,
#          'ltb': 2,
#          'lex2_generic__lt_lex2': 2,
#          'wf1': 2,
#          'wf2': 2,
#          'lex2_more__wf_lex2': 2,
#          'ls': 2,
#          'us': 2,
#          'range__open_closed_range__1': 2,
#          'range__open_closed_range__2': 2,
#          'range__closed_open_range__1': 2,
#          'range__closed_open_range__2': 2,
#          'bounded_order_props__abovep': 2,
#          'bounded_order_props__belowp': 2,
#          'closure_ops__equivalence_closure': 2,
#          'integer_enumerations__strictly_monotonep': 2,
#          'set_dichotomous__injection_order': 2,
#          'converse_zorn__lesseqp': 2,
#          'range__no_least': 2,
#          'range__no_greatest': 2,
#          'mucalculus__gfpp__2': 2,
#          'runs__invariant': 2,
#          'trel': 2,
#          'traces__normal_form': 2,
#          'directed_orders__chain_complete_partial_orderp': 2,
#          'tb2': 2,
#          'mucalculus__fixpointp__1': 2,
#          'ordinals__ordinalp': 2,
#          'ordstruct_adt__zero': 2,
#          'wf': 2,
#          'directed_order_props__lesseqp': 2,
#          'b_1': 2,
#          'Unit_adt__Unit_ord': 2,
#          'Unit_adt__unit': 2,
#          'Unit_adt__unitp': 2,
#          'ordered_list__cons_ol': 2,
#          'min_array_def__greatereqp': 2,
#          'for_examples__sum_array': 2,
#          'fseqs_def__singletonp': 2,
#          'fseqs_def__singleton': 2,
#          'fseqs_def__fseq1': 2,
#          'count_functions__collect_funs': 2,
#          'count_functions__isasol': 2,
#          'max_seq__Imax': 2,
#          'set_as_list__emptyset_sl': 2,
#          'set_as_list__disjoint_slp': 2,
#          'set_as_list__symmetric_difference_sl': 2,
#          'sets__symmetric_difference': 2,
#          'branch_and_bound__emptyDirVars': 2,
#          'stack__top': 2,
#          'stack__push': 2,
#          'branch_and_bound__nonemptyp': 2,
#          'stack__pop': 2,
#          'fseqs_ops__add': 2,
#          'fseqs_ops__first': 2,
#          'fseqs_ops__rest': 2,
#          'fseqs_ops__some__2': 2,
#          'seq_pigeon__s': 2,
#          'doubletons__doubletonp': 2,
#          'majority_fseq__in_seq': 2,
#          'max_array__imax': 2,
#          'fun_preds_partial__strict_increasingp': 2,
#          'fun_preds_partial__strict_decreasingp': 2,
#          'branch_and_bound__b_and_b_id': 2,
#          'middle_value_select__mid_val': 2,
#          'empty_array_def__empty_array': 2,
#          'm_': 2,
#          'n_': 2,
#          'val': 2,
#          'none?_var': 2,
#          'none?_var2': 2,
#          'array2list__array2list_it': 2,
#          'fseq2set__lesseqp': 2,
#          'bags__eqmult': 2,
#          'ordered_list__cdr_ol': 2,
#          'listn__normalize_fseq': 2,
#          'nzk': 2,
#          'fn': 2,
#          'endx': 2,
#          'xis1': 2,
#          'step_fun_def__step_funp': 2,
#          'continuous_linear__continuous_inp': 2,
#          'continuous_linear__piecewise_linearp': 2,
#          'restriction_cont_fun__restrict2': 2,
#          'xisp': 2,
#          'bounded_real_defs__boundedp': 2,
#          'restriction_continuous2__restrict2': 2,
#          'infinite_limits__inf_limit_at': 2,
#          'derivatives_def__T_pred': 2,
#          'rs_integral_def__Rie_sum_alt': 2,
#          'yy': 2,
#          'delj': 2,
#          'xpp': 2,
#          'open_sets__open_ball': 2,
#          'open_sets__closedp': 2,
#          'az': 2,
#          'finite_to_infinite__ref6': 2,
#          'finite_to_infinite__g6': 2,
#          'finite_to_infinite__e6': 2,
#          'relation_extension__extended_equiv_classT': 2,
#          'relation_extension__extended_equiv_classU': 2,
#          'n0fs': 2,
#          'relation_inverse_extension__l_T': 2,
#          'relation_inverse_extension__l_U': 2,
#          'gfm': 2,
#          'relation_inverse_extension__rel_inv_extension2': 2,
#          'fne1': 2,
#          'fne2': 2,
#          'fnne': 2,
#          'fne': 2,
#          'relational_choice__conditional_relational_choice': 2,
#          'count1': 2,
#          'count2': 2,
#          'nat_indexed_sets__increasing_indexedp': 2,
#          'KernelDefinition__EquivalenceKernel': 2,
#          'singleton_example__T0_ord': 2,
#          'singleton_example__t': 2,
#          'singleton_example__tp': 2,
#          'singleton_example__U0_ord': 2,
#          'singleton_example__u': 2,
#          'singleton_example__up': 2,
#          'infinite_to_finite_finite_equival_finite_equival_classes__zero': 2,
#          'infinite_to_finite_finite_equival_finite_equival_classes__one': 2,
#          'infinite_to_finite_finite_equival_finite_equival_classes__zerop': 2,
#          'infinite_to_finite_finite_equival_finite_equival_classes__onep': 2,
#          'cantor_bernstein_schroeder__BArel': 2,
#          'an': 2,
#          'bn': 2,
#          'hab': 2,
#          'cont_real_vect2__h!1': 2,
#          'vect_vect_2D_continuity__scal_vvr': 2,
#          'vect_vect_2D_continuity__sum_vvr': 2,
#          'vect_vect_2D_continuity__scal_vvv': 2,
#          'vect_cont_2D__rv1': 2,
#          'vect_cont_2D__rv2': 2,
#          'vect_cont_2D__vv1': 2,
#          'vect_cont_2D__vv2': 2,
#          'cont_vect__h!1': 2,
#          'cont_vect2_vect2__f!1': 2,
#          'DELTA': 2,
#          'perpendicular_3D__dist': 2,
#          'ramsey_graph__v': 2,
#          'product__FF': 2,
#          'sigma_countable__SERIES': 2,
#          'polynomials__g': 2,
#          'bernstein_polynomials__Aleft': 2,
#          'more_polynomial_props__G': 2,
#          'sigma__Fnnr!1': 2,
#          'sigma__FF': 2,
#          'log_nat__log_nat_itaux': 2,
#          'sigma_R_below__I!1': 2,
#          'general_properties__only_power_p': 2,
#          'cayleys__T': 2,
#          'cartesian_product_finite__A!1': 2,
#          'ring_ideal_def__left_swallowp': 2,
#          'ring_ideal_def__right_idealp': 2,
#          'closure_ops__R!1': 2,
#          'well_ordered_props__seg!1': 2,
#          'omega__ns': 2,
#          'pointwise_orders__f!1': 2,
#          'pointwise_orders__nff!1': 2,
#          'termination__termination_by_wf': 2,
#          'directed_orders__X!1': 2,
#          'directed_orders__lesseqp!1': 2,
#          'total_lattices__G1!1': 2,
#          'total_lattices__G2!1': 2,
#          'total_lattices__L1!1': 2,
#          'total_lattices__L2!1': 2,
#          'bounded_orders__S!1': 2,
#          'converse_zorn__T': 2,
#          'bounded_integers__x!1': 2,
#          'similarity_props__f!1': 2,
#          'isomorphism__f!1': 2,
#          'product_orders__r2!1': 2,
#          'product_orders__r1!1': 2,
#          'monotone_sequences__fseq': 2,
#          'monotone_sequences__seq!1': 2,
#          'max_array_def__Imax': 2,
#          'fseq2set__F': 2,
#          'fseq2set__S': 2,
#          'set_as_list_props__s2': 2,
#          'set_as_list_props__s1': 2,
#          'branch_and_bound_X__presound_evaluatep': 2,
#          'branch_and_bound_X__sound_evaluatep': 2,
#          'branch_and_bound_X__sound_subdividep': 2,
#          'branch_and_bound_X__sound_branchp': 2,
#          'branch_and_bound_X__presound_combinep': 2,
#          'branch_and_bound_X__sound_combinep': 2,
#          'FL': 2,
#          'array2list__a!1': 2,
#          'majority_array__maj_exists': 2,
#          'set2seq__SS!1': 2,
#          'map_with_index__T': 2,
#          'for_iterate__v': 2,
#          'doubletons__D!1': 2,
#          'for_examples__A': 2,
#          'continuity_ms__T2': 2,
#          'inverse_fun_ms_continuous__X': 2,
#          'metric_spaces__a!1': 2,
#          'metric_spaces__Y': 2,
#          'integral_split_fun__r2!1': 2,
#          'integral_split_fun__r3!1': 2,
#          'sequence_props__f!2': 2,
#          'integral_prep__GG': 2,
#          'riesz_hahn_banach__Extop': 2,
#          'cont_if_fun__P': 2,
#          'restrict2_deriv__T1_pred': 2,
#          'restriction_cont_fun__T2_pred': 2,
#          'finite_sets_aux__T': 2,
#          'sqrt_derivative_lam__T_pred': 2,
#          'partitions_scaf__SS!1': 2,
#          'infinite_limits__f': 2,
#          'infinite_limits__g': 2,
#          'integral_pulse__T_pred': 2,
#          'bounded_variation__hh': 2,
#          'bounded_variation__h': 2,
#          'composition_continuous__g!1': 2,
#          'continuous_functions_more__cn!1': 2,
#          'riesz_bounded_functionals__L': 2,
#          'chain_rule__phi!1': 2,
#          'chain_rule__phi!2': 2,
#          'chain_rule__f': 2,
#          'compactness__ysenum': 2,
#          'fundamental_theorem__T_pred': 2,
#          'real_metric_space__YS!2': 2,
#          'derivative_inverse__f!1': 2,
#          'derivative_inverse__G!1': 2,
#          'derivatives__ff2!1': 2,
#          'derivatives__ff1!1': 2,
#          'derivatives__fp!1': 2,
#          'derivatives__ff!1': 2,
#          'cross_metric_cont__X!1': 2,
#          'prelude_sets_aux__a!1': 2,
#          'derivative_props__gg!1': 2,
#          'piecewise_continuous__H!1': 2,
#          'piecewise_continuous__T_pred': 2,
#          'rs_partition__xx': 2,
#          'rs_partition__T_pred': 2,
#          'continuous_lambda__pf': 2,
#          'K_conversion__K_conversion': 2,
#          'integral_mean_value__T_pred': 2,
#          'integral_mean_value__F!1': 2,
#          'fun_below_props__x2!1': 2,
#          'fun_below_props__x1!1': 2,
#          'fun_below_props__h!1': 2,
#          'card_comp_props__T1': 2,
#          'infinite_nat_def__X!1': 2,
#          'infinite_nat_def__f!2': 2,
#          'set_of_functions__f!2': 2,
#          'cardinal__T': 2,
#          'card_function__D': 2,
#          'card_sets_lemmas__T': 2,
#          'countable_props__Y!1': 2,
#          'rr1': 1,
#          'rr2': 1,
#          'vectors__n': 1,
#          'vectors_4D__iv': 1,
#          'vectors_4D__jv': 1,
#          'vectors_4D__kv': 1,
#          'vectors_4D__lv': 1,
#          'ki': 1,
#          'product_below__n': 1,
#          'abstract_max__max_f': 1,
#          'abstract_max__max': 1,
#          '9921997352295461495916968083046817497847888441': 1,
#          'fseqs__empty_seq': 1,
#          'real_topology__reals': 1,
#          'RealInt__doublelessp': 1,
#          'homomorphisms__times': 1,
#          'ring_one_generator__zero': 1,
#          'ring_with_one_prime_ideal__one': 1,
#          'chain__chain_order': 1,
#          'complete_lattices__lesseqp': 1,
#          'complete_upper_semilattices__lesseqp': 1,
#          'rnn': 1,
#          'complete_lower_semilattices__lesseqp': 1,
#          'le__lt': 1,
#          'Unit_adt__doublelessp': 1,
#          'arrays_into_lists__represents': 1,
#          'min_array_def__n': 1,
#          '1024': 1,
#          '3628800': 1,
#          'count_functions__isaperm5': 1,
#          '120': 1,
#          '92': 1,
#          'max_array_def__lesseqp': 1,
#          'sort_fseq__lesseqp': 1,
#          'majority_vote__no_majority': 1,
#          'Maybe__doublelessp': 1,
#          'yv': 1,
#          'continuous_functions__T_pred': 1,
#          'cross_metric_uniform_continuity__d2': 1,
#          'cross_metric_uniform_continuity__d3': 1,
#          'total_m': 1,
#          'compactness__d': 1,
#          'relational_choice__proof_irrelevance': 1,
#          'relational_choice__independence_of_premises': 1,
#          'singleton_example__doublelessp__1': 1,
#          'singleton_example__doublelessp__2': 1,
#          'infinite_to_finite_finite_equival_finite_equival_classes__doublelessp': 1,
#          'power_sets__B': 1,
#          'countable_set__int_to_nat': 1,
#          'countable_set__nat_to_int': 1,
#          'countable_set__intset_to_natset': 1,
#          'limit_vect_real__x!1': 1,
#          'limit_vect_real__a!1': 1,
#          'series_aux__f!1': 1,
#          'series_lems__f!1': 1,
#          'absconv_series__phi!1': 1,
#          'absconv_series__x!2': 1,
#          'ramsey_graph__e2v_color': 1,
#          'J': 1,
#          'ramsey_graph__Ramsey_edge_color': 1,
#          'max_finite_set_nat__maximump': 1,
#          'max_finite_set_nat__max': 1,
#          'min_nat__minimump': 1,
#          'max_upto__S!1': 1,
#          'max_below__S!1': 1,
#          'foursquare__B': 1,
#          'countable_convergence__PHI': 1,
#          'countable_convergence__PSI': 1,
#          'countable_convergence__f!1': 1,
#          'sigma_countable__phi!2': 1,
#          'sigma_countable__Y!1': 1,
#          'sigma_nat__G!1': 1,
#          'binomial_identities__F': 1,
#          'polynomials__fbseq': 1,
#          'real_facts__F1': 1,
#          'real_facts__F2': 1,
#          'real_facts__F3': 1,
#          'real_facts__F4': 1,
#          'real_facts__A': 1,
#          'bernstein_polynomials__EE': 1,
#          'bernstein_polynomials__FF': 1,
#          'more_polynomial_props__ps': 1,
#          'sigma__Frat!1': 1,
#          'sigma__Fint!1': 1,
#          'sigma_R_below__G!1': 1,
#          'lagrange_scaf__partitionp': 1,
#          'ring_one_generator__R!1': 1,
#          'integral_domain_def__integral_domainp': 1,
#          'ordered_subset__U!1': 1,
#          'zorn__r!1': 1,
#          'lifted_orders__S!1': 1,
#          'bounded_nats__x!1': 1,
#          'ordered_nat__suf!1': 1,
#          'ordered_nat__pre!1': 1,
#          'ordered_nat__pre2!1': 1,
#          'well_nat__F!1': 1,
#          'well_nat__p!1': 1,
#          'well_ordered_finite__p!1': 1,
#          'lex2_more__p': 1,
#          'finite_below__v!1': 1,
#          'isomorphism__x!1': 1,
#          'monotone_sequences__lt!1': 1,
#          'fseq2set__f!1': 1,
#          'set_as_list_props__A': 1,
#          'more_list_props__P': 1,
#          'matroids__f!1': 1,
#          '12': 1,
#          'function_props_aux__f2!1': 1,
#          'function_image_bis__surj!1': 1,
#          'uniform_continuity__aenum': 1,
#          'step_fun_props__g!1': 1,
#          'inverse_fun_ms_continuous__Y!1': 1,
#          'inverse_fun_ms_continuous__f': 1,
#          'step_fun_def__T_pred': 1,
#          'lim_of_functions__T_pred': 1,
#          'finite_sets_aux__g!1': 1,
#          'chain_rule__g': 1,
#          'real_metric_space__XS!3': 1,
#          'real_metric_space__XS!2': 1,
#          'derivatives_alt__T_pred': 1,
#          'derivatives_alt__HH!1': 1,
#          'cross_metric_cont__Y!1': 1,
#          'prelude_sets_aux__A!2': 1,
#          'rs_integral_def__T_pred': 1,
#          'riesz_linear_functionals__additive_opp': 1,
#          'inverse_continuous_functions__T1_pred': 1,
#          'bytestrings__unit': 1,
#          'rs_partition__pum': 1,
#          'countable_indexed_sets__a!1': 1,
#          'nat_surjection__HH': 1,
#          'cardinal__S!1': 1,
#          'card_sets_lemmas__S!1': 1})
