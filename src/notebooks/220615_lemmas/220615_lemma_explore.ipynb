# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd
from pathlib import Path
from pprint import pprint
from sklearn.model_selection import train_test_split
from IPython.display import JSON
from tqdm import tqdm
import json
from coprover import PROJ_ROOT, RSC_ROOT, PVSLIB_ROOT

from coprover.feats.featurize_cmdpred import *

DATA_ROOT = Path(PROJ_ROOT, "data", "pvs", "prelude")
json_files = list(DATA_ROOT.rglob("*.json"))

# %%
json_fpath = Path(PVSLIB_ROOT, "algebra", "cartesian_product_finite-proofs", "cartesian_product_n_add_is_union.json")
with open(json_fpath, 'r') as f:
    json_root = json.load(f)

step = json_root['proof'][8]
tagform = convert_dict2tags(step)
state_str = format_state(tagform)

# %%
state_str
# Out:
# '<ANT> <CONS> s-formula apply constant type-actual getfield constant integer s-formula apply constant type-actual apply constant apply constant type-actual constant constant apply constant constant apply constant constant <HID> '

# %%
def bfs_flatten(iterable):
    ret = []
    for x in iterable:
        if isinstance(x, list):
            ret.extend(bfs_flatten(x))
        elif x is None:
            continue
        else:
            ret.append(x)
    return ret

# %%
# Type specific converters

TAG = "tag"
TUPLE = "tuple"
LABEL = "label"
SEQUENT = "sequent"
CURRENT_GOAL = "current-goal"
ANTECEDENTS = "antecedents"
CONSEQUENTS = "consequents"
PROOFSTATE = "proofstate"

ACTUALS = "actuals"
ARGUMENT = "argument"
APPLY = "apply"
ASSERTED = "asserted?"
CONSTANT = "constant"
CONSTANT_NAME = "constant-name"
EXPRESSION = "expression"
FIELD = "field"
FORALL = "forall"
FOREACH = "foreach"
GETFIELD = "getfield"
INTEGER = "integer"
INTEGER_VALUE = "integer-value"
VARIABLE_NAME = "variable-name"

FORMULA = "formula"
SFORMULA = "s-formula"

OPERATOR = "operator"
TYPE = "type"

TRUE = "True"
FALSE = "False"
IS_ASSERTED = "isasserted"
NOT_ASSERTED = "notasserted"

INTEGER_PLACEHOLDER = "INT"

CURRENT_RULE = "current-rule"
CURRENT_INPUT = "current-input"

def get_operator(elt):
    if elt[TAG] == CONSTANT:
        return [elt[CONSTANT_NAME]]
    else:
        return process(elt)

def get_const(elt):
    """ Given a reference to a constant, returns the featurized form.
    Note: The numeric type requires we pull this from the type lookup
    """
    assert elt[TAG] == CONSTANT
    # For now, return a generic placeholder of None
    return [None]

def get_integer(elt):
    assert elt[TAG] == INTEGER
    return [elt[INTEGER_VALUE]]


import pdb
def process(elt):
    if isinstance(elt, list):
        # Special case for removing tuple indicator
        if len(elt) == 2:
            if elt[0] == TAG and elt[1] == TUPLE:
                return [None]
        return [process(item) for item in elt]
    elif isinstance(elt, str):
        return [elt]
    elif isinstance(elt, dict):
        accum = []
        tag = elt[TAG]
        if tag == PROOFSTATE:
            ants = elt[CURRENT_GOAL][ANTECEDENTS]
            cons = elt[CURRENT_GOAL][CONSEQUENTS]
            if ants is not None:
                ants = process(ants)
            if cons is not None:
                cons = process(cons)
            return [ANTECEDENTS, ants, CONSEQUENTS, cons]
        if tag == APPLY:
            accum.extend(get_operator(elt[OPERATOR]))
            accum.extend(process(elt[ARGUMENT]))
        elif tag == FORALL:
            # TODO: Get bindings with type
            accum.append(FORALL)
            accum.extend(process(elt[EXPRESSION]))
        elif tag == GETFIELD:
            accum.append(elt[FIELD])
            accum.extend(process(elt[ARGUMENT]))
        elif tag == CONSTANT:
            return get_const(elt)
        elif tag == INTEGER:
            return get_integer(elt)
        elif tag == SFORMULA:
            is_asserted = elt[ASSERTED]
            if is_asserted:
                asserted_val = IS_ASSERTED
            else:
                asserted_val = NOT_ASSERTED
            accum.extend([SFORMULA, asserted_val])
            accum.extend(process(elt[FORMULA]))
        elif isinstance(tag, list):
            # If the tag is a list, likely of item for a getfield access
            # For first pass, return empty
            return [None]
        else:
            raise Exception("Unhandled tag = {}".format(tag))
        #if accum is not None and any(["cartesian" in x for x in accum if isinstance(x, str)]):
        #    pdb.set_trace()
        return accum

# %%
prf = json_root['proof'][2]
print(bfs_flatten(process(prf)))
JSON(prf)
# Out:
# ['antecedents', 'consequents', 's-formula', 'notasserted', 'forall', 'booleans__IMPLIES', 'notequal__notequal__1', 'length', 0, 'equalities__equal', 'cartesian_product_finite__cartesian_product_n', 'seq_extras__add_first', 'cartesian_product_finite__cartesian_product_set', 'cartesian_product_finite__cartesian_product_n']

# %%
JSON(json_root)

# %%
PROOF_SESSION = "proof-session"
PROOF = "proof"
TYPE_HASH = "type-hash"

from collections import Counter

tok_counter = Counter()

for json_fpath in tqdm(json_files):
    with open(json_fpath, 'r') as f:
        json_root_obj = json.load(f)
        if PROOF in json_root_obj:
            proof_seq = json_root_obj[PROOF]
            for idx in range(0, len(proof_seq), 2):
                state_toks = bfs_flatten(process(proof_seq[idx]))
                tok_counter.update(state_toks)
# Out:
#  10%|███████▎                                                               | 199/1920 [00:00<00:01, 1351.24it/s]
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Input In [157], in <cell line: 9>()
#      13 proof_seq = json_root_obj[PROOF]
#      14 for idx in range(0, len(proof_seq), 2):
# ---> 15     state_toks = bfs_flatten(process(proof_seq[idx]))
#      16     tok_counter.update(state_toks)
#
# Input In [154], in process(elt)
#      74         ants = process(ants)
#      75     if cons is not None:
# ---> 76         cons = process(cons)
#      77     return [ANTECEDENTS, ants, CONSEQUENTS, cons]
#      78 if tag == APPLY:
#
# Input In [154], in process(elt)
#      62         if elt[0] == TAG and elt[1] == TUPLE:
#      63             return [None]
# ---> 64     return [process(item) for item in elt]
#      65 elif isinstance(elt, str):
#      66     return [elt]
#
# Input In [154], in <listcomp>(.0)
#      62         if elt[0] == TAG and elt[1] == TUPLE:
#      63             return [None]
# ---> 64     return [process(item) for item in elt]
#      65 elif isinstance(elt, str):
#      66     return [elt]
#
# Input In [154], in process(elt)
#      97         asserted_val = NOT_ASSERTED
#      98     accum.extend([SFORMULA, asserted_val])
# ---> 99     accum.extend(process(elt[FORMULA]))
#     100 elif isinstance(tag, list):
#     101     # If the tag is a list, likely of item for a getfield access
#     102     # For first pass, return empty
#     103     return [None]
#
# Input In [154], in process(elt)
#      78 if tag == APPLY:
#      79     accum.extend(get_operator(elt[OPERATOR]))
# ---> 80     accum.extend(process(elt[ARGUMENT]))
#      81 elif tag == FORALL:
#      82     # TODO: Get bindings with type
#      83     accum.append(FORALL)
#
# Input In [154], in process(elt)
#      62         if elt[0] == TAG and elt[1] == TUPLE:
#      63             return [None]
# ---> 64     return [process(item) for item in elt]
#      65 elif isinstance(elt, str):
#      66     return [elt]
#
# Input In [154], in <listcomp>(.0)
#      62         if elt[0] == TAG and elt[1] == TUPLE:
#      63             return [None]
# ---> 64     return [process(item) for item in elt]
#      65 elif isinstance(elt, str):
#      66     return [elt]
#
# Input In [154], in process(elt)
#      78 if tag == APPLY:
#      79     accum.extend(get_operator(elt[OPERATOR]))
# ---> 80     accum.extend(process(elt[ARGUMENT]))
#      81 elif tag == FORALL:
#      82     # TODO: Get bindings with type
#      83     accum.append(FORALL)
#
# Input In [154], in process(elt)
#      62         if elt[0] == TAG and elt[1] == TUPLE:
#      63             return [None]
# ---> 64     return [process(item) for item in elt]
#      65 elif isinstance(elt, str):
#      66     return [elt]
#
# Input In [154], in <listcomp>(.0)
#      62         if elt[0] == TAG and elt[1] == TUPLE:
#      63             return [None]
# ---> 64     return [process(item) for item in elt]
#      65 elif isinstance(elt, str):
#      66     return [elt]
#
# Input In [154], in process(elt)
#     103     return [None]
#     104 else:
# --> 105     raise Exception("Unhandled tag = {}".format(tag))
#     106 #if accum is not None and any(["cartesian" in x for x in accum if isinstance(x, str)]):
#     107 #    pdb.set_trace()
#     108 return accum
#
# Exception: Unhandled tag = if

# %%
# Try again, this time using a strict traversal collecting tags

TABU_TAGS = set([ACTUALS, CONSTANT_NAME, LABEL,
                 TAG, TYPE, VARIABLE_NAME, CURRENT_RULE, CURRENT_INPUT])

def process2(elt, parent_key=None):
    """
    Collect all tags.  If this is a constant, check the context
    and if is an operator, collect the constant name
    """
    accum = []
    if isinstance(elt, list):
        return [process2(x) for x in elt]
    elif isinstance(elt, str):
        return [elt]
    elif isinstance(elt, int):
        return [elt]
    elif isinstance(elt, dict):
        if TAG in elt:
            accum.append(elt[TAG])
            if elt[TAG] == CONSTANT and parent_key == OPERATOR:
                accum.extend(process2(elt[CONSTANT_NAME]))
            for k, v in elt.items():
                if k not in TABU_TAGS:
                    accum.append(k)
                    accum.extend(process2(v, k))
    #if accum is not None and any([x == 'PartialFunctionDefinitions__f!1' for x in accum]):
    #    pdb.set_trace()
    return accum

# %%
PROOF_SESSION = "proof-session"
PROOF = "proof"
TYPE_HASH = "type-hash"

from collections import Counter

tok_counter = Counter()
to_examine_json = []

for json_fpath in tqdm(json_files):
    with open(json_fpath, 'r') as f:
        json_root_obj = json.load(f)
        if json_root_obj[TAG] == PROOF_SESSION and PROOF in json_root_obj:
            proof_seq = json_root_obj[PROOF]
            if proof_seq is not None:
                for idx in range(0, len(proof_seq), 2):
                    proof_step = proof_seq[idx]
                    state_toks = bfs_flatten(process2(proof_step))
                    #if any([x == "PartialFunctionDefinitions__f!1" for x in state_toks]):
                    #    to_examine_json.append(proof_step)
                    tok_counter.update(state_toks)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████| 1920/1920 [00:07<00:00, 265.60it/s]

# %%
# Examine inputs
for json_fpath in tqdm(json_files):
    with open(json_fpath, 'r') as f:
        json_root_obj = json.load(f)
        if PROOF in json_root_obj:
            proof_seq = json_root_obj[PROOF]
            if proof_seq is not None:
                print("- - - - -")
                for idx in range(1, len(proof_seq), 2):
                    input_step = proof_seq[idx]
                    print(idx, input_step)
# Out:
#   7%|█████▏                                                                 | 139/1920 [00:00<00:01, 1384.69it/s]
# - - - - -
# 1 ['input', 'subtype-tcc']
# - - - - -
# 1 ['input', 'skosimp*']
# 3 ['input', 'apply-extensionality', 'hide?', 't']
# 5 ['input', 'grind']
# - - - - -
# 1 ['input', 'subtype-tcc']
# - - - - -
# 1 ['input', 'skosimp*']
# 3 ['input', 'apply-extensionality', 'hide?', 't']
# 5 ['input', 'apply-extensionality', 'hide?', 't']
# 7 ['input', 'grind']
# 9 ['input', 'apply-extensionality', 'hide?', 't']
# 11 ['input', 'grind']
# 13 ['input', 'typepred', {'tag': 'constant', 'constant-name': 'PartialFunctionComposition__x!1', 'actuals': None, 'type': 1942522179}]
# 15 ['input', 'grind']
# - - - - -
# 1 ['input', 'skolem', '1', ['l!1', 'p!1', 'x!1', 'y!1']]
# 3 ['input', 'skolem!', '*', 'keep-underscore?', None, 'skolem-typepreds?', None, 'dont-simplify?', None]
# 5 ['input', 'skosimp']
# 7 ['input', 'replace', '-1']
# 9 ['input', 'expand', 'length', '2', '2']
# 11 ['input', 'simplify', '*', 't', 't', 'rewrite-flag', None, 'flush?', None, 'linear?', None, 'cases-rewrite?', None, 'type-constraints?', 't', 'ignore-prover-output?', None, 'let-reduce?', 't', 'quant-simp?', None, 'implicit-typepreds?', None, 'ignore-typepreds?', None]
# 13 ['input', 'assert']
# - - - - -
# 1 ['input', 'tcc', 'defs', '!']
# - - - - -
# 1 ['input', 'subtype-tcc']
# - - - - -
# 1 ['input', 'lemma', 'neg_div_le']
# 3 ['input', 'skolem', '1', ['n0y!1', 'x!1']]
# 5 ['input', 'skolem!', '*', 'keep-underscore?', None, 'skolem-typepreds?', None, 'dont-simplify?', None]
# 7 ['input', 'skosimp']
# 9 ['input', 'instantiate', '-1', [{'tag': 'constant', 'constant-name': 'real_props__n0y!1', 'actuals': None, 'type': 4204262761}, {'tag': 'constant', 'constant-name': 'real_props__x!1', 'actuals': None, 'type': 4227483815}]]
# 11 ['input', 'inst?']
# 13 ['input', 'grind']
# - - - - -
# 1 ['input', 'grind']
# - - - - -
# 1 ['input', 'skosimp*']
# 3 ['input', 'lemma', 'quotient_pos_lt']
# 5 ['input', 'inst', '-1', '-n0x!1']
# 7 ['input', 'simplify', '*', 't', 't', 'rewrite-flag', None, 'flush?', None, 'linear?', None, 'cases-rewrite?', None, 'type-constraints?', 't', 'ignore-prover-output?', None, 'let-reduce?', 't', 'quant-simp?', None, 'implicit-typepreds?', None, 'ignore-typepreds?', None]
# 9 ['input', 'assert']
# 11 ['input', 'grind']
# - - - - -
# 1 ['input', 'lemma', 'lt_times_lt_neg1']
# 3 ['input', 'skolem', '1', ['npz!1', 'nx!1', 'w!1', 'y!1']]
# 5 ['input', 'skolem!', '*', 'keep-underscore?', None, 'skolem-typepreds?', None, 'dont-simplify?', None]
# 7 ['input', 'skosimp']
# 9 ['input', 'inst', '-1', 'npz!1', 'nx!1', 'y!1', 'w!1']
# 11 ['input', 'grind']
# - - - - -
# 1 ['input', 'grind']
# - - - - -
# 1 ['input', 'grind']
# - - - - -
# 1 ['input', 'lemma', 'pos_div_le']
# 3 ['input', 'skolem', '1', ['n0y!1', 'x!1']]
# 5 ['input', 'skolem!', '*', 'keep-underscore?', None, 'skolem-typepreds?', None, 'dont-simplify?', None]
# 7 ['input', 'skosimp']
# 9 ['input', 'instantiate', '-1', [{'tag': 'constant', 'constant-name': 'real_props__n0y!1', 'actuals': None, 'type': 4204262761}, {'tag': 'constant', 'constant-name': 'real_props__x!1', 'actuals': None, 'type': 4227483815}]]
# 11 ['input', 'inst?']
# 13 ['input', 'grind']
# - - - - -
# 1 ['input', 'skosimp*']
# 3 ['input', 'expand', 'abs']
# - - - - -
# 1 ['input', 'grind']
# 3 ['input', 'lemma', 'posreal_mult_closed']
# 5 ['input', 'case', {'tag': 'apply', 'operator': {'tag': 'constant', 'constant-name': 'equalities__equal', 'actuals': [{'tag': 'type-actual', 'type': 2910104866}], 'type': 2895152588}, 'argument': [['tag', 'tuple'], {'tag': 'constant', 'constant-name': 'real_props__x!1', 'actuals': None, 'type': 4227483815}, {'tag': 'integer', 'integer-value': 0}]}]
# 7 ['input', 'simplify', '*', 't', 't', 'rewrite-flag', None, 'flush?', None, 'linear?', None, 'cases-rewrite?', None, 'type-constraints?', 't', 'ignore-prover-output?', None, 'let-reduce?', 't', 'quant-simp?', None, 'implicit-typepreds?', None, 'ignore-typepreds?', None]
# 9 ['input', 'assert']
# 11 ['input', 'case', {'tag': 'apply', 'operator': {'tag': 'constant', 'constant-name': 'equalities__equal', 'actuals': [{'tag': 'type-actual', 'type': 2910104866}], 'type': 2895152588}, 'argument': [['tag', 'tuple'], {'tag': 'constant', 'constant-name': 'real_props__y!1', 'actuals': None, 'type': 4227483815}, {'tag': 'integer', 'integer-value': 0}]}]
# 13 ['input', 'simplify', '*', 't', 't', 'rewrite-flag', None, 'flush?', None, 'linear?', None, 'cases-rewrite?', None, 'type-constraints?', 't', 'ignore-prover-output?', None, 'let-reduce?', 't', 'quant-simp?', None, 'implicit-typepreds?', None, 'ignore-typepreds?', None]
# 15 ['input', 'assert']
# 17 ['input', 'inst', '-1', 'x!1', '-y!1']
# 19 ['input', 'simplify', '*', 't', 't', 'rewrite-flag', None, 'flush?', None, 'linear?', None, 'cases-rewrite?', None, 'type-constraints?', 't', 'ignore-prover-output?', None, 'let-reduce?', 't', 'quant-simp?', None, 'implicit-typepreds?', None, 'ignore-typepreds?', None]
# 21 ['input', 'assert']
# 23 ['input', 'case', {'tag': 'apply', 'operator': {'tag': 'constant', 'constant-name': 'equalities__equal', 'actuals': [{'tag': 'type-actual', 'type': 2910104866}], 'type': 2895152588}, 'argument': [['tag', 'tuple'], {'tag': 'constant', 'constant-name': 'real_props__x!1', 'actuals': None, 'type': 4227483815}, {'tag': 'integer', 'integer-value': 0}]}]
# 25 ['input', 'simplify', '*', 't', 't', 'rewrite-flag', None, 'flush?', None, 'linear?', None, 'cases-rewrite?', None, 'type-constraints?', 't', 'ignore-prover-output?', None, 'let-reduce?', 't', 'quant-simp?', None, 'implicit-typepreds?', None, 'ignore-typepreds?', None]
# 27 ['input', 'assert']
# 29 ['input', 'case', {'tag': 'apply', 'operator': {'tag': 'constant', 'constant-name': 'equalities__equal', 'actuals': [{'tag': 'type-actual', 'type': 2910104866}], 'type': 2895152588}, 'argument': [['tag', 'tuple'], {'tag': 'constant', 'constant-name': 'real_props__y!1', 'actuals': None, 'type': 4227483815}, {'tag': 'integer', 'integer-value': 0}]}]
# 31 ['input', 'simplify', '*', 't', 't', 'rewrite-flag', None, 'flush?', None, 'linear?', None, 'cases-rewrite?', None, 'type-constraints?', 't', 'ignore-prover-output?', None, 'let-reduce?', 't', 'quant-simp?', None, 'implicit-typepreds?', None, 'ignore-typepreds?', None]
# 33 ['input', 'assert']
# 35 ['input', 'lemma', 'posreal_mult_closed']
# 37 ['input', 'inst', '-1', '-x!1', 'y!1']
# 39 ['input', 'simplify', '*', 't', 't', 'rewrite-flag', None, 'flush?', None, 'linear?', None, 'cases-rewrite?', None, 'type-constraints?', 't', 'ignore-prover-output?', None, 'let-reduce?', 't', 'quant-simp?', None, 'implicit-typepreds?', None, 'ignore-typepreds?', None]
# 41 ['input', 'assert']
# 43 ['input', 'lemma', 'posreal_mult_closed']
# 45 ['input', 'inst', '-1', 'x!1', 'y!1']
# 47 ['input', 'simplify', '*', 't', 't', 'rewrite-flag', None, 'flush?', None, 'linear?', None, 'cases-rewrite?', None, 'type-constraints?', 't', 'ignore-prover-output?', None, 'let-reduce?', 't', 'quant-simp?', None, 'implicit-typepreds?', None, 'ignore-typepreds?', None]
# 49 ['input', 'assert']
# 51 ['input', 'lemma', 'posreal_mult_closed']
# 53 ['input', 'inst', '-1', '-x!1', '-y!1']
# 55 ['input', 'simplify', '*', 't', 't', 'rewrite-flag', None, 'flush?', None, 'linear?', None, 'cases-rewrite?', None, 'type-constraints?', 't', 'ignore-prover-output?', None, 'let-reduce?', 't', 'quant-simp?', None, 'implicit-typepreds?', None, 'ignore-typepreds?', None]
# 57 ['input', 'assert']
# - - - - -
# 1 ['input', 'grind']
# - - - - -
# 1 ['input', 'lemma', 'neg_times_le']
# 3 ['input', 'skolem', '1', ['x!1', 'y!1']]
# 5 ['input', 'skolem!', '*', 'keep-underscore?', None, 'skolem-typepreds?', None, 'dont-simplify?', None]
# 7 ['input', 'skosimp']
# 9 ['input', 'instantiate', '-1', [{'tag': 'constant', 'constant-name': 'real_props__x!1', 'actuals': None, 'type': 4227483815}, {'tag': 'constant', 'constant-name': 'real_props__y!1', 'actuals': None, 'type': 4227483815}]]
# 11 ['input', 'inst?']
# 13 ['input', 'grind']
# - - - - -
# 1 ['input', 'tcc', 'defs', '!']
# - - - - -
# 1 ['input', 'tcc', 'defs', '!']
# - - - - -
# 1 ['input', 'lemma', 'both_sides_div_neg_le2']
# 3 ['input', 'skolem', '1', ['nx!1', 'ny!1', 'pz!1']]
# 5 ['input', 'skolem!', '*', 'keep-underscore?', None, 'skolem-typepreds?', None, 'dont-simplify?', None]
# 7 ['input', 'skosimp']
# 9 ['input', 'inst', '-1', 'ny!1', 'nx!1', 'pz!1']
# 11 ['input', 'grind']
# - - - - -
# 1 ['input', 'lemma', 'both_sides_times1']
# 3 ['input', 'skosimp*']
# 5 ['input', 'split']
# 7 ['input', 'prop']
# 9 ['input', 'inst', '-2', 'n0z!1', 'x!1', 'y!1']
# 11 ['input', 'replace', '-1']
# 13 ['input', 'simplify', '*', 't', 't', 'rewrite-flag', None, 'flush?', None, 'linear?', None, 'cases-rewrite?', None, 'type-constraints?', 't', 'ignore-prover-output?', None, 'let-reduce?', 't', 'quant-simp?', None, 'implicit-typepreds?', None, 'ignore-typepreds?', None]
# 15 ['input', 'assert']
# 17 ['input', 'simplify', '*', 't', 't', 'rewrite-flag', None, 'flush?', None, 'linear?', None, 'cases-rewrite?', None, 'type-constraints?', 't', 'ignore-prover-output?', None, 'let-reduce?', 't', 'quant-simp?', None, 'implicit-typepreds?', None, 'ignore-typepreds?', None]
# 19 ['input', 'assert']
# - - - - -
# 1 ['input', 'lemma', 'both_sides_times_pos_lt1']
# 3 ['input', 'skolem', '1', ['nz!1', 'x!1', 'y!1']]
# 5 ['input', 'skolem!', '*', 'keep-underscore?', None, 'skolem-typepreds?', None, 'dont-simplify?', None]
# 7 ['input', 'skosimp']
# 9 ['input', 'inst', '-1', '-nz!1', 'y!1', 'x!1']
# 11 ['input', 'grind']
# - - - - -
# 1 ['input', 'lemma', 'div_mult_neg_le1']
# 3 ['input', 'skolem', '1', ['ny!1', 'x!1', 'z!1']]
# 5 ['input', 'skolem!', '*', 'keep-underscore?', None, 'skolem-typepreds?', None, 'dont-simplify?', None]
# 7 ['input', 'skosimp']
# 9 ['input', 'instantiate', '-1', [{'tag': 'constant', 'constant-name': 'real_props__ny!1', 'actuals': None, 'type': 2460867440}, '_', {'tag': 'constant', 'constant-name': 'real_props__z!1', 'actuals': None, 'type': 4227483815}]]
# 11 ['input', 'inst?']
# 13 ['input', 'instantiate', '-1', [{'tag': 'constant', 'constant-name': 'real_props__x!1', 'actuals': None, 'type': 4227483815}]]
# 15 ['input', 'inst?']
# 17 ['input', 'grind']
# - - - - -
# 1 ['input', 'lemma', 'both_sides_div_pos_lt3']
# 3 ['input', 'skolem', '1', ['nx!1', 'ny!1', 'nz!1']]
# 5 ['input', 'skolem!', '*', 'keep-underscore?', None, 'skolem-typepreds?', None, 'dont-simplify?', None]
# 7 ['input', 'skosimp']
# 9 ['input', 'inst', '-1', 'nz!1', '-ny!1', '-nx!1']
# 11 ['input', 'grind']
# - - - - -
# 1 ['input', 'grind']
# - - - - -
# 1 ['input', 'skolem', '1', ['x!1', 'y!1']]
# 3 ['input', 'skolem!', '*', 'keep-underscore?', None, 'skolem-typepreds?', None, 'dont-simplify?', None]
# 5 ['input', 'skosimp']
# 7 ['input', 'lemma', 'div_cancel3']
# 9 ['input', 'inst', '-1', 'y!1', '1', 'x!1']
# 11 ['input', 'simplify', '*', 't', 't', 'rewrite-flag', None, 'flush?', None, 'linear?', None, 'cases-rewrite?', None, 'type-constraints?', 't', 'ignore-prover-output?', None, 'let-reduce?', 't', 'quant-simp?', None, 'implicit-typepreds?', None, 'ignore-typepreds?', None]
# 13 ['input', 'assert']
# 15 ['input', 'hide', '-3']
# 17 ['input', 'replace', '-1', 'dir', 'rl']
# 19 ['input', 'hide', '-1']
# 21 ['input', 'lemma', 'div_mult_pos_ge2']
# 23 ['input', 'inst', '-1', 'y!1', '1', '1']
# 25 ['input', 'simplify', '*', 't', 't', 'rewrite-flag', None, 'flush?', None, 'linear?', None, 'cases-rewrite?', None, 'type-constraints?', 't', 'ignore-prover-output?', None, 'let-reduce?', 't', 'quant-simp?', None, 'implicit-typepreds?', None, 'ignore-typepreds?', None]
# 27 ['input', 'assert']
# 29 ['input', 'lemma', 'zero_times3']
# 31 ['input', 'instantiate', '-1', [{'tag': 'constant', 'constant-name': 'real_props__x!1', 'actuals': None, 'type': 4227483815}, {'tag': 'constant', 'constant-name': 'real_props__y!1', 'actuals': None, 'type': 4227483815}]]
# 33 ['input', 'inst?']
# 35 ['input', 'grind']
# - - - - -
# 1 ['input', 'skolem', '1', ['i!1', 'j!1']]
# 3 ['input', 'skolem!', '*', 'keep-underscore?', None, 'skolem-typepreds?', None, 'dont-simplify?', None]
# 5 ['input', 'skosimp']
# 7 ['input', 'lemma', 'product_1']
# 9 ['input', 'inst', '-1', 'i!1', '-j!1']
# 11 ['input', 'simplify', '*', 't', 't', 'rewrite-flag', None, 'flush?', None, 'linear?', None, 'cases-rewrite?', None, 'type-constraints?', 't', 'ignore-prover-output?', None, 'let-reduce?', 't', 'quant-simp?', None, 'implicit-typepreds?', None, 'ignore-typepreds?', None]
# 13 ['input', 'assert']
# 15 ['input', 'flatten-disjunct', None, None]
# 17 ['input', 'flatten']
# 19 ['input', 'simplify', '*', 't', 't', 'rewrite-flag', None, 'flush?', None, 'linear?', None, 'cases-rewrite?', None, 'type-constraints?', 't', 'ignore-prover-output?', None, 'let-reduce?', 't', 'quant-simp?', None, 'implicit-typepreds?', None, 'ignore-typepreds?', None]
# 21 ['input', 'assert']
# - - - - -
# 1 ['input', 'grind']
# - - - - -
# 1 ['input', 'grind']
# - - - - -
# 1 ['input', 'lemma', 'both_sides_times_neg_le2']
# 3 ['input', 'skolem', '1', ['nz!1', 'x!1', 'y!1']]
# 5 ['input', 'skolem!', '*', 'keep-underscore?', None, 'skolem-typepreds?', None, 'dont-simplify?', None]
# 7 ['input', 'skosimp']
# 9 ['input', 'inst', '-1', 'nz!1', 'y!1', 'x!1']
# 11 ['input', 'grind']
# - - - - -
# 1 ['input', 'lemma', 'le_div_le_pos']
# 3 ['input', 'skolem', '1', ['npy!1', 'nw!1', 'x!1', 'z!1']]
# 5 ['input', 'skolem!', '*', 'keep-underscore?', None, 'skolem-typepreds?', None, 'dont-simplify?', None]
# 7 ['input', 'skosimp']
# 9 ['input', 'inst', '-1', '-npy!1', '-nw!1', '-z!1', '-x!1']
# 11 ['input', 'grind']
# - - - - -
# 1 ['input', 'lemma', 'lt_times_lt_neg2']
# 3 ['input', 'skolem', '1', ['npx!1', 'nz!1', 'w!1', 'y!1']]
# 5 ['input', 'skolem!', '*', 'keep-underscore?', None, 'skolem-typepreds?', None, 'dont-simplify?', None]
# 7 ['input', 'skosimp']
# 9 ['input', 'inst', '-1', 'npx!1', 'nz!1', 'y!1', 'w!1']
# 11 ['input', 'grind']
# - - - - -
# 1 ['input', 'skosimp*']
# 3 ['input', 'case', 'x!1 * x!1 - 1 < 0']
# 5 ['input', 'case-replace', 'x!1 * x!1 - 1 < 0']
# 7 ['input', 'hide', '-2']
# 9 ['input', 'case', 'x!1 * x!1 - 1 = (x!1 + 1)*(x!1 - 1)']
# 11 ['input', 'case-replace', 'x!1 * x!1 - 1 = (x!1 + 1)*(x!1 - 1)']
# 13 ['input', 'hide', '-1']
# 15 ['input', 'lemma', 'pos_times_lt']
# 17 ['input', 'instantiate', '-1', [{'tag': 'apply', 'operator': {'tag': 'constant', 'constant-name': 'number_fields__plus', 'actuals': None, 'type': 3936226261}, 'argument': [['tag', 'tuple'], {'tag': 'constant', 'constant-name': 'real_props__x!1', 'actuals': None, 'type': 4227483815}, {'tag': 'integer', 'integer-value': 1}]}, {'tag': 'apply', 'operator': {'tag': 'constant', 'constant-name': 'number_fields__difference__1', 'actuals': None, 'type': 3936226261}, 'argument': [['tag', 'tuple'], {'tag': 'constant', 'constant-name': 'real_props__x!1', 'actuals': None, 'type': 4227483815}, {'tag': 'integer', 'integer-value': 1}]}]]
# 19 ['input', 'inst?']
# 21 ['input', 'simplify', '*', 't', 't', 'rewrite-flag', None, 'flush?', None, 'linear?', None, 'cases-rewrite?', None, 'type-constraints?', 't', 'ignore-prover-output?', None, 'let-reduce?', 't', 'quant-simp?', None, 'implicit-typepreds?', None, 'ignore-typepreds?', None]
# 23 ['input', 'assert']
# 25 ['input', 'hide', '-1']
# 27 ['input', 'grind']
# 29 ['input', 'simplify', '*', 't', 't', 'rewrite-flag', None, 'flush?', None, 'linear?', None, 'cases-rewrite?', None, 'type-constraints?', 't', 'ignore-prover-output?', None, 'let-reduce?', 't', 'quant-simp?', None, 'implicit-typepreds?', None, 'ignore-typepreds?', None]
# 31 ['input', 'assert']
# 33 ['input', 'simplify', '*', 't', 't', 'rewrite-flag', None, 'flush?', None, 'linear?', None, 'cases-rewrite?', None, 'type-constraints?', 't', 'ignore-prover-output?', None, 'let-reduce?', 't', 'quant-simp?', None, 'implicit-typepreds?', None, 'ignore-typepreds?', None]
# 35 ['input', 'assert']
# - - - - -
# 1 ['input', 'grind']
# - - - - -
# 1 ['input', 'lemma', 'both_sides_div_neg_lt2']
# 3 ['input', 'skolem', '1', ['nx!1', 'ny!1', 'pz!1']]
# 5 ['input', 'skolem!', '*', 'keep-underscore?', None, 'skolem-typepreds?', None, 'dont-simplify?', None]
# 7 ['input', 'skosimp']
# 9 ['input', 'inst', '-1', 'ny!1', 'nx!1', 'pz!1']
# 11 ['input', 'grind']
# - - - - -
# 1 ['input', 'skolem', '1', ['x!1', 'y!1']]
# 3 ['input', 'skolem!', '*', 'keep-underscore?', None, 'skolem-typepreds?', None, 'dont-simplify?', None]
# 5 ['input', 'skosimp']
# 7 ['input', 'lemma', 'eq1_gt']
# 9 ['input', 'inst', '-1', '-x!1', 'y!1']
# 11 ['input', 'grind']
# - - - - -
# 1 ['input', 'grind']
# - - - - -
# 1 ['input', 'grind']
# - - - - -
# 1 ['input', 'grind']
# - - - - -
# 1 ['input', 'subtype-tcc']
# - - - - -
# 1 ['input', 'lemma', 'both_sides_div_pos_lt2']
# 3 ['input', 'skolem', '1', ['nx!1', 'ny!1', 'pz!1']]
# 5 ['input', 'skolem!', '*', 'keep-underscore?', None, 'skolem-typepreds?', None, 'dont-simplify?', None]
# 7 ['input', 'skosimp']
# 9 ['input', 'inst', '-1', '-ny!1', '-nx!1', 'pz!1']
# 11 ['input', 'grind']
# - - - - -
# 1 ['input', 'tcc', 'defs', '!']
# - - - - -
# 1 ['input', 'lemma', 'both_sides_div_pos_le2']
# 3 ['input', 'skolem', '1', ['nz!1', 'px!1', 'py!1']]
# 5 ['input', 'skolem!', '*', 'keep-underscore?', None, 'skolem-typepreds?', None, 'dont-simplify?', None]
# 7 ['input', 'skosimp']
# 9 ['input', 'inst', '-1', 'py!1', 'px!1', '-nz!1']
# 11 ['input', 'grind']
# - - - - -
# 1 ['input', 'grind']
# - - - - -
# 1 ['input', 'subtype-tcc']
# - - - - -
# 1 ['input', 'tcc', 'defs', '!']
# - - - - -
# 1 ['input', 'grind']
# - - - - -
# 1 ['input', 'skosimp*']
# 3 ['input', 'split']
# 5 ['input', 'ground']
# 7 ['input', 'case', {'tag': 'apply', 'operator': {'tag': 'constant', 'constant-name': 'reals__greaterp', 'actuals': None, 'type': 2209491690}, 'argument': [['tag', 'tuple'], {'tag': 'apply', 'operator': {'tag': 'constant', 'constant-name': 'real_defs__abs', 'actuals': None, 'type': 4021879377}, 'argument': {'tag': 'constant', 'constant-name': 'real_props__x!1', 'actuals': None, 'type': 4227483815}}, {'tag': 'integer', 'integer-value': 1}]}]
# 9 ['input', 'lemma', 'eq1_gt']
# 11 ['input', 'inst', '-1', 'abs(x!1)', 'abs(x!1)']
# 13 ['input', 'simplify', '*', 't', 't', 'rewrite-flag', None, 'flush?', None, 'linear?', None, 'cases-rewrite?', None, 'type-constraints?', 't', 'ignore-prover-output?', None, 'let-reduce?', 't', 'quant-simp?', None, 'implicit-typepreds?', None, 'ignore-typepreds?', None]
# 15 ['input', 'assert']
# 17 ['input', 'expand', 'abs', '1']
# 19 ['input', 'lift-if']
# 21 ['input', 'split']
# 23 ['input', 'prop']
# 25 ['input', 'simplify', '*', 't', 't', 'rewrite-flag', None, 'flush?', None, 'linear?', None, 'cases-rewrite?', None, 'type-constraints?', 't', 'ignore-prover-output?', None, 'let-reduce?', 't', 'quant-simp?', None, 'implicit-typepreds?', None, 'ignore-typepreds?', None]
# 27 ['input', 'assert']
# 29 ['input', 'lemma', 'div_mult_pos_ge1']
# 31 ['input', 'inst', '-1', 'abs(x!1)', '1', '1']
# 33 ['input', 'flatten-disjunct', None, None]
# 35 ['input', 'flatten']
# 37 ['input', 'ground']
# 39 ['input', 'lemma', 'eq1_ge']
# 41 ['input', 'inst', '-1', '1/abs(x!1)', '1/abs(x!1)']
# 43 ['input', 'simplify', '*', 't', 't', 'rewrite-flag', None, 'flush?', None, 'linear?', None, 'cases-rewrite?', None, 'type-constraints?', 't', 'ignore-prover-output?', None, 'let-reduce?', 't', 'quant-simp?', None, 'implicit-typepreds?', None, 'ignore-typepreds?', None]
# 45 ['input', 'assert']
# 47 ['input', 'split']
# 49 ['input', 'case', {'tag': 'apply', 'operator': {'tag': 'constant', 'constant-name': 'equalities__equal', 'actuals': [{'tag': 'type-actual', 'type': 2910104866}], 'type': 2895152588}, 'argument': [['tag', 'tuple'], {'tag': 'apply', 'operator': {'tag': 'constant', 'constant-name': 'real_defs__abs', 'actuals': None, 'type': 4021879377}, 'argument': {'tag': 'constant', 'constant-name': 'real_props__x!1', 'actuals': None, 'type': 4227483815}}, {'tag': 'integer', 'integer-value': 1}]}]
# 51 ['input', 'simplify', '*', 't', 't', 'rewrite-flag', None, 'flush?', None, 'linear?', None, 'cases-rewrite?', None, 'type-constraints?', 't', 'ignore-prover-output?', None, 'let-reduce?', 't', 'quant-simp?', None, 'implicit-typepreds?', None, 'ignore-typepreds?', None]
# 53 ['input', 'assert']
# 55 ['input', 'expand', 'abs', '-1']
# 57 ['input', 'lift-if']
# 59 ['input', 'simplify', '*', 't', 't', 'rewrite-flag', None, 'flush?', None, 'linear?', None, 'cases-rewrite?', None, 'type-constraints?', 't', 'ignore-prover-output?', None, 'let-reduce?', 't', 'quant-simp?', None, 'implicit-typepreds?', None, 'ignore-typepreds?', None]
# 61 ['input', 'assert']
# 63 ['input', 'simplify', '*', 't', 't', 'rewrite-flag', None, 'flush?', None, 'linear?', None, 'cases-rewrite?', None, 'type-constraints?', 't', 'ignore-prover-output?', None, 'let-reduce?', 't', 'quant-simp?', None, 'implicit-typepreds?', None, 'ignore-typepreds?', None]
# 65 ['input', 'assert']
# 67 ['input', 'simplify', '*', 't', 't', 'rewrite-flag', None, 'flush?', None, 'linear?', None, 'cases-rewrite?', None, 'type-constraints?', 't', 'ignore-prover-output?', None, 'let-reduce?', 't', 'quant-simp?', None, 'implicit-typepreds?', None, 'ignore-typepreds?', None]
# 69 ['input', 'assert']
# 71 ['input', 'expand', 'abs', '1']
# 73 ['input', 'lift-if']
# 75 ['input', 'split']
# 77 ['input', 'prop']
# 79 ['input', 'simplify', '*', 't', 't', 'rewrite-flag', None, 'flush?', None, 'linear?', None, 'cases-rewrite?', None, 'type-constraints?', 't', 'ignore-prover-output?', None, 'let-reduce?', 't', 'quant-simp?', None, 'implicit-typepreds?', None, 'ignore-typepreds?', None]
# 81 ['input', 'assert']
# 83 ['input', 'simplify', '*', 't', 't', 'rewrite-flag', None, 'flush?', None, 'linear?', None, 'cases-rewrite?', None, 'type-constraints?', 't', 'ignore-prover-output?', None, 'let-reduce?', 't', 'quant-simp?', None, 'implicit-typepreds?', None, 'ignore-typepreds?', None]
# 85 ['input', 'assert']
# 87 ['input', 'case', {'tag': 'apply', 'operator': {'tag': 'constant', 'constant-name': 'equalities__equal', 'actuals': [{'tag': 'type-actual', 'type': 2910104866}], 'type': 2895152588}, 'argument': [['tag', 'tuple'], {'tag': 'constant', 'constant-name': 'real_props__x!1', 'actuals': None, 'type': 4227483815}, {'tag': 'integer', 'integer-value': 0}]}]
# 89 ['input', 'replace', '-1']
# 91 ['input', 'simplify', '*', 't', 't', 'rewrite-flag', None, 'flush?', None, 'linear?', None, 'cases-rewrite?', None, 'type-constraints?', 't', 'ignore-prover-output?', None, 'let-reduce?', 't', 'quant-simp?', None, 'implicit-typepreds?', None, 'ignore-typepreds?', None]
# 93 ['input', 'assert']
# 95 ['input', 'simplify', '*', 't', 't', 'rewrite-flag', None, 'flush?', None, 'linear?', None, 'cases-rewrite?', None, 'type-constraints?', 't', 'ignore-prover-output?', None, 'let-reduce?', 't', 'quant-simp?', None, 'implicit-typepreds?', None, 'ignore-typepreds?', None]
# 97 ['input', 'assert']
# - - - - -
# 1 ['input', 'grind']
# - - - - -
# 1 ['input', 'lemma', 'both_sides_times_pos_lt1']
# 3 ['input', 'skolem', '1', ['pz!1', 'x!1', 'y!1']]
# 5 ['input', 'skolem!', '*', 'keep-underscore?', None, 'skolem-typepreds?', None, 'dont-simplify?', None]
# 7 ['input', 'skosimp']
# 9 ['input', 'instantiate', '-1', [{'tag': 'constant', 'constant-name': 'real_props__pz!1', 'actuals': None, 'type': 2461461913}, {'tag': 'constant', 'constant-name': 'real_props__x!1', 'actuals': None, 'type': 4227483815}, '_']]
# 11 ['input', 'inst?']
# 13 ['input', 'inst', '-1', 'y!1']
# 15 ['input', 'grind']
# 17 ['input', 'lemma', 'both_sides_times1']
# 19 ['input', 'instantiate', '-1', [{'tag': 'constant', 'constant-name': 'real_props__pz!1', 'actuals': None, 'type': 2461461913}, {'tag': 'constant', 'constant-name': 'real_props__x!1', 'actuals': None, 'type': 4227483815}, '_']]
# 21 ['input', 'inst?']
# 23 ['input', 'inst', '-1', 'y!1']
# 25 ['input', 'grind']
# - - - - -
# 1 ['input', 'lemma', 'lt_div_lt_pos1']
# 3 ['input', 'skolem', '1', ['nw!1', 'ny!1', 'x!1', 'z!1']]
# 5 ['input', 'skolem!', '*', 'keep-underscore?', None, 'skolem-typepreds?', None, 'dont-simplify?', None]
# 7 ['input', 'skosimp']
# 9 ['input', 'inst', '-1', '-ny!1', '-nw!1', '-z!1', '-x!1']
# 11 ['input', 'grind']
# - - - - -
# 1 ['input', 'lemma', 'le_div_le_pos']
# 3 ['input', 'skolem', '1', ['nny!1', 'pw!1', 'x!1', 'z!1']]
# 5 ['input', 'skolem!', '*', 'keep-underscore?', None, 'skolem-typepreds?', None, 'dont-simplify?', None]
# 7 ['input', 'skosimp']
# 9 ['input', 'inst', '-1', 'nny!1', 'pw!1', 'z!1', 'x!1']
# 11 ['input', 'simplify', '*', 't', 't', 'rewrite-flag', None, 'flush?', None, 'linear?', None, 'cases-rewrite?', None, 'type-constraints?', 't', 'ignore-prover-output?', None, 'let-reduce?', 't', 'quant-simp?', None, 'implicit-typepreds?', None, 'ignore-typepreds?', None]
# 13 ['input', 'assert']
# - - - - -
# 1 ['input', 'skosimp*']
# 3 ['input', 'lemma', 'pos_times_lt']
# 5 ['input', 'inst', '-1', 'x!1', '1/n0y!1']
# 7 ['input', 'lemma', 'quotient_pos_lt']
# 9 ['input', 'inst', '-1', 'n0y!1']
# 11 ['input', 'lemma', 'quotient_neg_lt']
# 13 ['input', 'inst', '-1', 'n0y!1']
# 15 ['input', 'grind']
# - - - - -
# 1 ['input', 'lemma', 'le_times_le_pos']
# 3 ['input', 'skolem', '1', ['nnx!1', 'pz!1', 'w!1', 'y!1']]
# 5 ['input', 'skolem!', '*', 'keep-underscore?', None, 'skolem-typepreds?', None, 'dont-simplify?', None]
# 7 ['input', 'skosimp']
# 9 ['input', 'inst', '-1', 'nnx!1', '1/w!1', '1/pz!1', 'y!1']
# 11 ['input', 'grind']
# 13 ['input', 'lemma', 'both_sides_div_pos_le2', ['py', {'tag': 'constant', 'constant-name': 'real_props__pz!1', 'actuals': None, 'type': 2461461913}, 'px', {'tag': 'constant', 'constant-name': 'real_props__w!1', 'actuals': None, 'type': 4227483815}, 'pz', {'tag': 'integer', 'integer-value': 1}]]
# 15 ['input', 'rewrite', 'both_sides_div_pos_le2']
# 17 ['input', 'simplify', '*', 't', 't', 'rewrite-flag', None, 'flush?', None, 'linear?', None, 'cases-rewrite?', None, 'type-constraints?', 't', 'ignore-prover-output?', None, 'let-reduce?', 't', 'quant-simp?', None, 'implicit-typepreds?', None, 'ignore-typepreds?', None]
# 19 ['input', 'assert']
# 21 ['input', 'lemma', 'quotient_pos_lt']
# 23 ['input', 'inst', '-1', 'w!1']
# 25 ['input', 'grind']
# - - - - -
# 1 ['input', 'tcc', 'defs', '!']
# - - - - -
# 1 ['input', 'lemma', 'both_sides_times_neg_le1']
# 3 ['input', 'skolem', '1', ['nz!1', 'x!1', 'y!1']]
# 5 ['input', 'skolem!', '*', 'keep-underscore?', None, 'skolem-typepreds?', None, 'dont-simplify?', None]
# 7 ['input', 'skosimp']
# 9 ['input', 'inst', '-1', 'nz!1', 'y!1', 'x!1']
# 11 ['input', 'grind']
# - - - - -
# 1 ['input', 'skolem', '1', ['x!1', 'y!1']]
# 3 ['input', 'skolem!', '*', 'keep-underscore?', None, 'skolem-typepreds?', None, 'dont-simplify?', None]
# 5 ['input', 'skosimp']
# 7 ['input', 'lemma', 'neg_times_lt']
# 9 ['input', 'instantiate', '-1', [{'tag': 'constant', 'constant-name': 'real_props__x!1', 'actuals': None, 'type': 4227483815}, {'tag': 'constant', 'constant-name': 'real_props__y!1', 'actuals': None, 'type': 4227483815}]]
# 11 ['input', 'inst?']
# 13 ['input', 'grind']
# - - - - -
# 1 ['input', 'grind']
# - - - - -
# 1 ['input', 'tcc', 'defs', '!']
# - - - - -
# 1 ['input', 'lemma', 'both_sides_times_pos_le1']
# 3 ['input', 'skolem', '1', ['pz!1', 'x!1', 'y!1']]
# 5 ['input', 'skolem!', '*', 'keep-underscore?', None, 'skolem-typepreds?', None, 'dont-simplify?', None]
# 7 ['input', 'skosimp']
# 9 ['input', 'inst', '-1', 'pz!1', 'y!1', 'x!1']
# 11 ['input', 'grind']
# - - - - -
# 1 ['input', 'tcc', 'defs', '!']
# - - - - -
# 1 ['input', 'grind']
# - - - - -
# 1 ['input', 'skosimp*']
# 3 ['input', 'lemma', 'both_sides_div_pos_lt2']
# 5 ['input', 'inst', '-1', 'py!1', 'px!1', '-nz!1']
# 7 ['input', 'grind']
# - - - - -
# 1 ['input', 'grind']
# - - - - -
# 1 ['input', 'grind']
# - - - - -
# 1 ['input', 'skolem', '1', ['x!1', 'y!1']]
# 3 ['input', 'skolem!', '*', 'keep-underscore?', None, 'skolem-typepreds?', None, 'dont-simplify?', None]
# 5 ['input', 'skosimp']
# 7 ['input', 'lemma', 'eq1_gt']
# 9 ['input', 'inst', '-1', 'x!1', '-y!1']
# 11 ['input', 'grind']
# - - - - -
# 1 ['input', 'lemma', 'lt_times_lt_pos1']
# 3 ['input', 'skolem', '1', ['npw!1', 'ny!1', 'x!1', 'z!1']]
# 5 ['input', 'skolem!', '*', 'keep-underscore?', None, 'skolem-typepreds?', None, 'dont-simplify?', None]
# 7 ['input', 'skosimp']
# 9 ['input', 'inst', '-1', '-npw!1', '-ny!1', '-z!1', '-x!1']
# 11 ['input', 'grind']
# - - - - -
# 1 ['input', 'lemma', 'div_mult_pos_le1']
# 3 ['input', 'skolem', '1', ['py!1', 'x!1', 'z!1']]
# 5 ['input', 'skolem!', '*', 'keep-underscore?', None, 'skolem-typepreds?', None, 'dont-simplify?', None]
# 7 ['input', 'skosimp']
# 9 ['input', 'instantiate', '-1', [{'tag': 'constant', 'constant-name': 'real_props__py!1', 'actuals': None, 'type': 2461461913}, '_', {'tag': 'constant', 'constant-name': 'real_props__z!1', 'actuals': None, 'type': 4227483815}]]
# 11 ['input', 'inst?']
# 13 ['input', 'instantiate', '-1', [{'tag': 'constant', 'constant-name': 'real_props__x!1', 'actuals': None, 'type': 4227483815}]]
# 15 ['input', 'inst?']
# 17 ['input', 'grind']
# - - - - -
# 1 ['input', 'lemma', 'pos_div_le']
# 3 ['input', 'skolem', '1', ['n0y!1', 'x!1']]
# 5 ['input', 'skolem!', '*', 'keep-underscore?', None, 'skolem-typepreds?', None, 'dont-simplify?', None]
# 7 ['input', 'skosimp']
# 9 ['input', 'inst', '-1', '-n0y!1', 'x!1']
# 11 ['input', 'grind']
# - - - - -
# 1 ['input', 'lemma', 'both_sides_div_pos_lt3']
# 3 ['input', 'skolem', '1', ['nz!1', 'px!1', 'py!1']]
# 5 ['input', 'skolem!', '*', 'keep-underscore?', None, 'skolem-typepreds?', None, 'dont-simplify?', None]
# 7 ['input', 'skosimp']
# 9 ['input', 'inst', '-1', 'nz!1', 'py!1', 'px!1']
# 11 ['input', 'grind']
# - - - - -
# 1 ['input', 'skosimp*']
# 3 ['input', 'expand', 'abs']
# 5 ['input', 'lift-if']
# 7 ['input', 'split']
# 9 ['input', 'ground']
# - - - - -
# 1 ['input', 'grind']
# - - - - -
# 1 ['input', 'skosimp*']
#  14%|██████████▍                                                             | 278/1920 [00:00<00:03, 453.19it/s]
# 3 ['input', 'lemma', 'both_sides_times_pos_lt1']
# 5 ['input', 'inst', '-1', 'px!1 * py!1', 'pz!1 / px!1', 'pz!1 / py!1']
# 7 ['input', 'simplify', '*', 't', 't', 'rewrite-flag', None, 'flush?', None, 'linear?', None, 'cases-rewrite?', None, 'type-constraints?', 't', 'ignore-prover-output?', None, 'let-reduce?', 't', 'quant-simp?', None, 'implicit-typepreds?', None, 'ignore-typepreds?', None]
# 9 ['input', 'assert']
# 11 ['input', 'grind']
# 13 ['input', 'case', {'tag': 'apply', 'operator': {'tag': 'constant', 'constant-name': 'equalities__equal', 'actuals': [{'tag': 'type-actual', 'type': 2910104866}], 'type': 2895152588}, 'argument': [['tag', 'tuple'], {'tag': 'apply', 'operator': {'tag': 'constant', 'constant-name': 'number_fields__times', 'actuals': None, 'type': 3936226261}, 'argument': [['tag', 'tuple'], {'tag': 'apply', 'operator': {'tag': 'constant', 'constant-name': 'number_fields__divide', 'actuals': None, 'type': 3889784157}, 'argument': [['tag', 'tuple'], {'tag': 'constant', 'constant-name': 'real_props__pz!1', 'actuals': None, 'type': 2461461913}, {'tag': 'constant', 'constant-name': 'real_props__px!1', 'actuals': None, 'type': 2461461913}]}, {'tag': 'apply', 'operator': {'tag': 'constant', 'constant-name': 'number_fields__times', 'actuals': None, 'type': 3936226261}, 'argument': [['tag', 'tuple'], {'tag': 'constant', 'constant-name': 'real_props__px!1', 'actuals': None, 'type': 2461461913}, {'tag': 'constant', 'constant-name': 'real_props__py!1', 'actuals': None, 'type': 2461461913}]}]}, {'tag': 'apply', 'operator': {'tag': 'constant', 'constant-name': 'number_fields__times', 'actuals': None, 'type': 3936226261}, 'argument': [['tag', 'tuple'], {'tag': 'constant', 'constant-name': 'real_props__pz!1', 'actuals': None, 'type': 2461461913}, {'tag': 'constant', 'constant-name': 'real_props__py!1', 'actuals': None, 'type': 2461461913}]}]}]
# 15 ['input', 'replace', '-1']
# 17 ['input', 'hide', '-1']
# 19 ['input', 'case', {'tag': 'apply', 'operator': {'tag': 'constant', 'constant-name': 'equalities__equal', 'actuals': [{'tag': 'type-actual', 'type': 2910104866}], 'type': 2895152588}, 'argument': [['tag', 'tuple'], {'tag': 'apply', 'operator': {'tag': 'constant', 'constant-name': 'number_fields__times', 'actuals': None, 'type': 3936226261}, 'argument': [['tag', 'tuple'], {'tag': 'apply', 'operator': {'tag': 'constant', 'constant-name': 'number_fields__divide', 'actuals': None, 'type': 3889784157}, 'argument': [['tag', 'tuple'], {'tag': 'constant', 'constant-name': 'real_props__pz!1', 'actuals': None, 'type': 2461461913}, {'tag': 'constant', 'constant-name': 'real_props__py!1', 'actuals': None, 'type': 2461461913}]}, {'tag': 'apply', 'operator': {'tag': 'constant', 'constant-name': 'number_fields__times', 'actuals': None, 'type': 3936226261}, 'argument': [['tag', 'tuple'], {'tag': 'constant', 'constant-name': 'real_props__px!1', 'actuals': None, 'type': 2461461913}, {'tag': 'constant', 'constant-name': 'real_props__py!1', 'actuals': None, 'type': 2461461913}]}]}, {'tag': 'apply', 'operator': {'tag': 'constant', 'constant-name': 'number_fields__times', 'actuals': None, 'type': 3936226261}, 'argument': [['tag', 'tuple'], {'tag': 'constant', 'constant-name': 'real_props__pz!1', 'actuals': None, 'type': 2461461913}, {'tag': 'constant', 'constant-name': 'real_props__px!1', 'actuals': None, 'type': 2461461913}]}]}]
# 21 ['input', 'replace', '-1']
# 23 ['input', 'hide', '-1']
# 25 ['input', 'lemma', 'both_sides_times_pos_lt2', ['y', {'tag': 'constant', 'constant-name': 'real_props__px!1', 'actuals': None, 'type': 2461461913}, 'x', {'tag': 'constant', 'constant-name': 'real_props__py!1', 'actuals': None, 'type': 2461461913}, 'pz', {'tag': 'constant', 'constant-name': 'real_props__pz!1', 'actuals': None, 'type': 2461461913}]]
# 27 ['input', 'rewrite', 'both_sides_times_pos_lt2']
# 29 ['input', 'simplify', '*', 't', 't', 'rewrite-flag', None, 'flush?', None, 'linear?', None, 'cases-rewrite?', None, 'type-constraints?', 't', 'ignore-prover-output?', None, 'let-reduce?', 't', 'quant-simp?', None, 'implicit-typepreds?', None, 'ignore-typepreds?', None]
# 31 ['input', 'assert']
# 33 ['input', 'simplify', '*', 't', 't', 'rewrite-flag', None, 'flush?', None, 'linear?', None, 'cases-rewrite?', None, 'type-constraints?', 't', 'ignore-prover-output?', None, 'let-reduce?', 't', 'quant-simp?', None, 'implicit-typepreds?', None, 'ignore-typepreds?', None]
# 35 ['input', 'assert']
# 37 ['input', 'case', {'tag': 'apply', 'operator': {'tag': 'constant', 'constant-name': 'equalities__equal', 'actuals': [{'tag': 'type-actual', 'type': 2910104866}], 'type': 2895152588}, 'argument': [['tag', 'tuple'], {'tag': 'apply', 'operator': {'tag': 'constant', 'constant-name': 'number_fields__times', 'actuals': None, 'type': 3936226261}, 'argument': [['tag', 'tuple'], {'tag': 'apply', 'operator': {'tag': 'constant', 'constant-name': 'number_fields__divide', 'actuals': None, 'type': 3889784157}, 'argument': [['tag', 'tuple'], {'tag': 'constant', 'constant-name': 'real_props__pz!1', 'actuals': None, 'type': 2461461913}, {'tag': 'constant', 'constant-name': 'real_props__px!1', 'actuals': None, 'type': 2461461913}]}, {'tag': 'apply', 'operator': {'tag': 'constant', 'constant-name': 'number_fields__times', 'actuals': None, 'type': 3936226261}, 'argument': [['tag', 'tuple'], {'tag': 'constant', 'constant-name': 'real_props__px!1', 'actuals': None, 'type': 2461461913}, {'tag': 'constant', 'constant-name': 'real_props__py!1', 'actuals': None, 'type': 2461461913}]}]}, {'tag': 'apply', 'operator': {'tag': 'constant', 'constant-name': 'number_fields__times', 'actuals': None, 'type': 3936226261}, 'argument': [['tag', 'tuple'], {'tag': 'constant', 'constant-name': 'real_props__pz!1', 'actuals': None, 'type': 2461461913}, {'tag': 'constant', 'constant-name': 'real_props__py!1', 'actuals': None, 'type': 2461461913}]}]}]
# 39 ['input', 'case', {'tag': 'apply', 'operator': {'tag': 'constant', 'constant-name': 'equalities__equal', 'actuals': [{'tag': 'type-actual', 'type': 2910104866}], 'type': 2895152588}, 'argument': [['tag', 'tuple'], {'tag': 'apply', 'operator': {'tag': 'constant', 'constant-name': 'number_fields__times', 'actuals': None, 'type': 3936226261}, 'argument': [['tag', 'tuple'], {'tag': 'apply', 'operator': {'tag': 'constant', 'constant-name': 'number_fields__divide', 'actuals': None, 'type': 3889784157}, 'argument': [['tag', 'tuple'], {'tag': 'constant', 'constant-name': 'real_props__pz!1', 'actuals': None, 'type': 2461461913}, {'tag': 'constant', 'constant-name': 'real_props__py!1', 'actuals': None, 'type': 2461461913}]}, {'tag': 'apply', 'operator': {'tag': 'constant', 'constant-name': 'number_fields__times', 'actuals': None, 'type': 3936226261}, 'argument': [['tag', 'tuple'], {'tag': 'constant', 'constant-name': 'real_props__px!1', 'actuals': None, 'type': 2461461913}, {'tag': 'constant', 'constant-name': 'real_props__py!1', 'actuals': None, 'type': 2461461913}]}]}, {'tag': 'apply', 'operator': {'tag': 'constant', 'constant-name': 'number_fields__times', 'actuals': None, 'type': 3936226261}, 'argument': [['tag', 'tuple'], {'tag': 'constant', 'constant-name': 'real_props__pz!1', 'actuals': None, 'type': 2461461913}, {'tag': 'constant', 'constant-name': 'real_props__px!1', 'actuals': None, 'type': 2461461913}]}]}]
# 41 ['input', 'replace', '-1']
# 43 ['input', 'replace', '-2']
# 45 ['input', 'hide', '-1', '-2']
# 47 ['input', 'lemma', 'both_sides_times_pos_lt2']
# 49 ['input', 'instantiate', '-1', [{'tag': 'constant', 'constant-name': 'real_props__pz!1', 'actuals': None, 'type': 2461461913}, {'tag': 'constant', 'constant-name': 'real_props__py!1', 'actuals': None, 'type': 2461461913}, {'tag': 'constant', 'constant-name': 'real_props__px!1', 'actuals': None, 'type': 2461461913}]]
# 51 ['input', 'inst?']
# 53 ['input', 'grind']
# 55 ['input', 'grind']
# 57 ['input', 'grind']
# - - - - -
# 1 ['input', 'lemma', 'both_sides_div_pos_le2']
# 3 ['input', 'skolem', '1', ['px!1', 'py!1', 'pz!1']]
# 5 ['input', 'skolem!', '*', 'keep-underscore?', None, 'skolem-typepreds?', None, 'dont-simplify?', None]
# 7 ['input', 'skosimp']
# 9 ['input', 'inst', '-1', 'py!1', 'px!1', 'pz!1']
# 11 ['input', 'grind']
# - - - - -
# 1 ['input', 'lemma', 'zero_times3']
# 3 ['input', 'skolem', '1', ['n0y!1', 'x!1']]
# 5 ['input', 'skolem!', '*', 'keep-underscore?', None, 'skolem-typepreds?', None, 'dont-simplify?', None]
# 7 ['input', 'skosimp']
# 9 ['input', 'instantiate', '-1', [{'tag': 'constant', 'constant-name': 'real_props__x!1', 'actuals': None, 'type': 4227483815}, {'tag': 'constant', 'constant-name': 'real_props__n0y!1', 'actuals': None, 'type': 4204262761}]]
# 11 ['input', 'inst?']
# 13 ['input', 'grind']
# - - - - -
# 1 ['input', 'grind']
# - - - - -
# 1 ['input', 'lemma', 'quotient_pos_lt']
# 3 ['input', 'skolem', '1', ['n0x!1']]
# 5 ['input', 'skolem!', '*', 'keep-underscore?', None, 'skolem-typepreds?', None, 'dont-simplify?', None]
# 7 ['input', 'skosimp']
# 9 ['input', 'instantiate', '-1', [{'tag': 'constant', 'constant-name': 'real_props__n0x!1', 'actuals': None, 'type': 4204262761}]]
# 11 ['input', 'inst?']
# 13 ['input', 'lemma', 'inv_ne_0']
# 15 ['input', 'instantiate', '-1', [{'tag': 'constant', 'constant-name': 'real_props__n0x!1', 'actuals': None, 'type': 4204262761}]]
# 17 ['input', 'inst?']
# 19 ['input', 'grind']
# - - - - -
# 1 ['input', 'grind']
# - - - - -
# 1 ['input', 'lemma', 'div_mult_neg_lt2']
# 3 ['input', 'skolem', '1', ['ny!1', 'x!1', 'z!1']]
# 5 ['input', 'skolem!', '*', 'keep-underscore?', None, 'skolem-typepreds?', None, 'dont-simplify?', None]
# 7 ['input', 'skosimp']
# 9 ['input', 'instantiate', '-1', [{'tag': 'constant', 'constant-name': 'real_props__ny!1', 'actuals': None, 'type': 2460867440}, '_', {'tag': 'constant', 'constant-name': 'real_props__z!1', 'actuals': None, 'type': 4227483815}]]
# 11 ['input', 'inst?']
# 13 ['input', 'instantiate', '-1', [{'tag': 'constant', 'constant-name': 'real_props__x!1', 'actuals': None, 'type': 4227483815}]]
# 15 ['input', 'inst?']
# 17 ['input', 'grind']
# 19 ['input', 'case', 'z!1 = x!1 * ny!1']
# 21 ['input', 'case-replace', 'z!1 = x!1 * ny!1']
# 23 ['input', 'case', 'x!1 * ny!1 / ny!1 = x!1']
# 25 ['input', 'case-replace', 'x!1 * ny!1 / ny!1 = x!1']
# 27 ['input', 'simplify', '*', 't', 't', 'rewrite-flag', None, 'flush?', None, 'linear?', None, 'cases-rewrite?', None, 'type-constraints?', 't', 'ignore-prover-output?', None, 'let-reduce?', 't', 'quant-simp?', None, 'implicit-typepreds?', None, 'ignore-typepreds?', None]
# 29 ['input', 'assert']
# 31 ['input', 'hide', '-1', '-2', '2', '3', '4']
# 33 ['input', 'lemma', 'div_def', None]
# 35 ['input', 'use', 'div_def']
# 37 ['input', 'replace', '-1']
# 39 ['input', 'simplify', '*', 't', 't', 'rewrite-flag', None, 'flush?', None, 'linear?', None, 'cases-rewrite?', None, 'type-constraints?', 't', 'ignore-prover-output?', None, 'let-reduce?', 't', 'quant-simp?', None, 'implicit-typepreds?', None, 'ignore-typepreds?', None]
# 41 ['input', 'assert']
# - - - - -
# 1 ['input', 'lemma', 'both_sides_times_neg_lt2']
# 3 ['input', 'skolem', '1', ['nz!1', 'x!1', 'y!1']]
# 5 ['input', 'skolem!', '*', 'keep-underscore?', None, 'skolem-typepreds?', None, 'dont-simplify?', None]
# 7 ['input', 'skosimp']
# 9 ['input', 'inst', '-1', 'nz!1', 'y!1', 'x!1']
# 11 ['input', 'grind']
# - - - - -
# 1 ['input', 'tcc', 'defs', '!']
# - - - - -
# 1 ['input', 'lemma', 'le_div_le_neg']
# 3 ['input', 'skosimp*']
# 5 ['input', 'inst', '-1', 'npx!1', 'nz!1', 'y!1', 'w!1']
# 7 ['input', 'simplify', '*', 't', 't', 'rewrite-flag', None, 'flush?', None, 'linear?', None, 'cases-rewrite?', None, 'type-constraints?', 't', 'ignore-prover-output?', None, 'let-reduce?', 't', 'quant-simp?', None, 'implicit-typepreds?', None, 'ignore-typepreds?', None]
# 9 ['input', 'assert']
# - - - - -
# 1 ['input', 'subtype-tcc']
# - - - - -
# 1 ['input', 'lemma', 'quotient_pos_le']
# 3 ['input', 'skolem', '1', ['n0x!1']]
# 5 ['input', 'skolem!', '*', 'keep-underscore?', None, 'skolem-typepreds?', None, 'dont-simplify?', None]
# 7 ['input', 'skosimp']
# 9 ['input', 'inst', '-1', '-n0x!1']
# 11 ['input', 'grind']
# - - - - -
# 1 ['input', 'lemma', 'both_sides_div_pos_le3']
# 3 ['input', 'skolem', '1', ['nx!1', 'ny!1', 'nz!1']]
# 5 ['input', 'skolem!', '*', 'keep-underscore?', None, 'skolem-typepreds?', None, 'dont-simplify?', None]
# 7 ['input', 'skosimp']
# 9 ['input', 'inst', '-1', 'nz!1', '-ny!1', '-nx!1']
# 11 ['input', 'grind']
# - - - - -
# 1 ['input', 'lemma', 'both_sides_div_neg_lt1']
# 3 ['input', 'skolem', '1', ['nz!1', 'x!1', 'y!1']]
# 5 ['input', 'skolem!', '*', 'keep-underscore?', None, 'skolem-typepreds?', None, 'dont-simplify?', None]
# 7 ['input', 'skosimp']
# 9 ['input', 'inst', '-1', 'nz!1', 'y!1', 'x!1']
# 11 ['input', 'grind']
# - - - - -
# 1 ['input', 'grind']
# - - - - -
# 1 ['input', 'grind']
# 3 ['input', 'lemma', 'posreal_mult_closed']
# 5 ['input', 'inst', '-1', 'x!1 - (z!1/py!1)', 'py!1']
# 7 ['input', 'simplify', '*', 't', 't', 'rewrite-flag', None, 'flush?', None, 'linear?', None, 'cases-rewrite?', None, 'type-constraints?', 't', 'ignore-prover-output?', None, 'let-reduce?', 't', 'quant-simp?', None, 'implicit-typepreds?', None, 'ignore-typepreds?', None]
# 9 ['input', 'assert']
# 11 ['input', 'lemma', 'posreal_mult_closed']
# 13 ['input', 'inst', '-1', 'x!1*py!1 - z!1', '1/py!1']
# 15 ['input', 'simplify', '*', 't', 't', 'rewrite-flag', None, 'flush?', None, 'linear?', None, 'cases-rewrite?', None, 'type-constraints?', 't', 'ignore-prover-output?', None, 'let-reduce?', 't', 'quant-simp?', None, 'implicit-typepreds?', None, 'ignore-typepreds?', None]
# 17 ['input', 'assert']
# - - - - -
# 1 ['input', 'lemma', 'zero_times3']
# 3 ['input', 'skolem', '1', ['n0x!1', 'n0y!1']]
# 5 ['input', 'skolem!', '*', 'keep-underscore?', None, 'skolem-typepreds?', None, 'dont-simplify?', None]
# 7 ['input', 'skosimp']
# 9 ['input', 'instantiate', '-1', [{'tag': 'constant', 'constant-name': 'real_props__n0x!1', 'actuals': None, 'type': 4204262761}, {'tag': 'constant', 'constant-name': 'real_props__n0y!1', 'actuals': None, 'type': 4204262761}]]
# 11 ['input', 'inst?']
# 13 ['input', 'grind']
# - - - - -
# 1 ['input', 'grind']
# - - - - -
# 1 ['input', 'grind']
# - - - - -
# 1 ['input', 'skosimp*']
# 3 ['input', 'lemma', 'inverse_mult']
# 5 ['input', 'instantiate', '-1', [{'tag': 'constant', 'constant-name': 'real_props__n0x!1', 'actuals': None, 'type': 4204262761}]]
# 7 ['input', 'inst?']
# 9 ['input', 'lemma', 'pos_times_lt']
# 11 ['input', 'inst', '-1', 'n0x!1', '1/n0x!1']
# 13 ['input', 'replace', '-2']
# 15 ['input', 'simplify', '*', 't', 't', 'rewrite-flag', None, 'flush?', None, 'linear?', None, 'cases-rewrite?', None, 'type-constraints?', 't', 'ignore-prover-output?', None, 'let-reduce?', 't', 'quant-simp?', None, 'implicit-typepreds?', None, 'ignore-typepreds?', None]
# 17 ['input', 'assert']
# 19 ['input', 'split']
# 21 ['input', 'ground']
# - - - - -
# 1 ['input', 'lemma', 'both_sides_div_pos_lt1']
# 3 ['input', 'skolem', '1', ['pz!1', 'x!1', 'y!1']]
# 5 ['input', 'skolem!', '*', 'keep-underscore?', None, 'skolem-typepreds?', None, 'dont-simplify?', None]
# 7 ['input', 'skosimp']
# 9 ['input', 'inst', '-1', 'pz!1', 'y!1', 'x!1']
# 11 ['input', 'grind']
# - - - - -
# 1 ['input', 'lemma', 'pos_times_lt']
# 3 ['input', 'skolem', '1', ['x!1', 'y!1']]
# 5 ['input', 'skolem!', '*', 'keep-underscore?', None, 'skolem-typepreds?', None, 'dont-simplify?', None]
# 7 ['input', 'skosimp']
# 9 ['input', 'case', {'tag': 'apply', 'operator': {'tag': 'constant', 'constant-name': 'equalities__equal', 'actuals': [{'tag': 'type-actual', 'type': 2910104866}], 'type': 2895152588}, 'argument': [['tag', 'tuple'], {'tag': 'constant', 'constant-name': 'real_props__x!1', 'actuals': None, 'type': 4227483815}, {'tag': 'integer', 'integer-value': 0}]}]
# 11 ['input', 'grind']
# 13 ['input', 'case', {'tag': 'apply', 'operator': {'tag': 'constant', 'constant-name': 'equalities__equal', 'actuals': [{'tag': 'type-actual', 'type': 2910104866}], 'type': 2895152588}, 'argument': [['tag', 'tuple'], {'tag': 'constant', 'constant-name': 'real_props__y!1', 'actuals': None, 'type': 4227483815}, {'tag': 'integer', 'integer-value': 0}]}]
# 15 ['input', 'grind']
# 17 ['input', 'instantiate', '-1', [{'tag': 'constant', 'constant-name': 'real_props__x!1', 'actuals': None, 'type': 4227483815}, {'tag': 'constant', 'constant-name': 'real_props__y!1', 'actuals': None, 'type': 4227483815}]]
# 19 ['input', 'inst?']
# 21 ['input', 'lemma', 'zero_times3']
# 23 ['input', 'instantiate', '-1', [{'tag': 'constant', 'constant-name': 'real_props__x!1', 'actuals': None, 'type': 4227483815}, {'tag': 'constant', 'constant-name': 'real_props__y!1', 'actuals': None, 'type': 4227483815}]]
# 25 ['input', 'inst?']
# 27 ['input', 'grind']
# - - - - -
# 1 ['input', 'lemma', 'pos_div_lt']
# 3 ['input', 'skolem', '1', ['n0y!1', 'x!1']]
# 5 ['input', 'skolem!', '*', 'keep-underscore?', None, 'skolem-typepreds?', None, 'dont-simplify?', None]
# 7 ['input', 'skosimp']
# 9 ['input', 'instantiate', '-1', [{'tag': 'constant', 'constant-name': 'real_props__n0y!1', 'actuals': None, 'type': 4204262761}, {'tag': 'constant', 'constant-name': 'real_props__x!1', 'actuals': None, 'type': 4227483815}]]
# 11 ['input', 'inst?']
# 13 ['input', 'grind']
# - - - - -
# 1 ['input', 'lemma', 'pos_times_lt']
# 3 ['input', 'skolem', '1', ['x!1', 'y!1']]
# 5 ['input', 'skolem!', '*', 'keep-underscore?', None, 'skolem-typepreds?', None, 'dont-simplify?', None]
# 7 ['input', 'skosimp']
# 9 ['input', 'instantiate', '-1', [{'tag': 'constant', 'constant-name': 'real_props__x!1', 'actuals': None, 'type': 4227483815}, {'tag': 'constant', 'constant-name': 'real_props__y!1', 'actuals': None, 'type': 4227483815}]]
# 11 ['input', 'inst?']
# 13 ['input', 'grind']
# - - - - -
# 1 ['input', 'grind']
# - - - - -
# 1 ['input', 'subtype-tcc']
# - - - - -
# 1 ['input', 'lemma', 'neg_div_lt']
# 3 ['input', 'skolem', '1', ['n0y!1', 'x!1']]
# 5 ['input', 'skolem!', '*', 'keep-underscore?', None, 'skolem-typepreds?', None, 'dont-simplify?', None]
# 7 ['input', 'skosimp']
# 9 ['input', 'instantiate', '-1', [{'tag': 'constant', 'constant-name': 'real_props__n0y!1', 'actuals': None, 'type': 4204262761}, {'tag': 'constant', 'constant-name': 'real_props__x!1', 'actuals': None, 'type': 4227483815}]]
# 11 ['input', 'inst?']
# 13 ['input', 'flatten-disjunct', None, None]
# 15 ['input', 'flatten']
# 17 ['input', 'ground']
# - - - - -
# 1 ['input', 'lemma', 'quotient_pos_lt']
# 3 ['input', 'skolem', '1', ['n0x!1']]
# 5 ['input', 'skolem!', '*', 'keep-underscore?', None, 'skolem-typepreds?', None, 'dont-simplify?', None]
# 7 ['input', 'skosimp']
# 9 ['input', 'instantiate', '-1', [{'tag': 'constant', 'constant-name': 'real_props__n0x!1', 'actuals': None, 'type': 4204262761}]]
# 11 ['input', 'inst?']
# 13 ['input', 'grind']
# - - - - -
# 1 ['input', 'lemma', 'both_sides_div_neg_le1']
# 3 ['input', 'skolem', '1', ['nz!1', 'x!1', 'y!1']]
# 5 ['input', 'skolem!', '*', 'keep-underscore?', None, 'skolem-typepreds?', None, 'dont-simplify?', None]
# 7 ['input', 'skosimp']
# 9 ['input', 'inst', '-1', 'nz!1', 'y!1', 'x!1']
# 11 ['input', 'grind']
# ...
# 49 ['input', 'skolem!', '*', 'keep-underscore?', None, 'skolem-typepreds?', None, 'dont-simplify?', None]
# 51 ['input', 'skosimp']
# 53 ['input', 'expand', '<', '-4']
# 55 ['input', 'lift-if']
# 57 ['input', 'split', '-4']
# 59 ['input', 'flatten-disjunct', None, None]
# 61 ['input', 'flatten']
# 63 ['input', 'simplify', '*', 't', 't', 'rewrite-flag', None, 'flush?', None, 'linear?', None, 'cases-rewrite?', None, 'type-constraints?', 't', 'ignore-prover-output?', None, 'let-reduce?', 't', 'quant-simp?', None, 'implicit-typepreds?', None, 'ignore-typepreds?', None]
# 65 ['input', 'assert']
# 67 ['input', 'flatten-disjunct', None, None]
# 69 ['input', 'flatten']
# 71 ['input', 'expand', '<', '-5']
# 73 ['input', 'lift-if']
# 75 ['input', 'split']
# 77 ['input', 'split']
# 79 ['input', 'flatten-disjunct', None, None]
# 81 ['input', 'flatten']
# 83 ['input', 'expand', '<', '2']
# 85 ['input', 'simplify', '*', 't', 't', 'rewrite-flag', None, 'flush?', None, 'linear?', None, 'cases-rewrite?', None, 'type-constraints?', 't', 'ignore-prover-output?', None, 'let-reduce?', 't', 'quant-simp?', None, 'implicit-typepreds?', None, 'ignore-typepreds?', None]
# 87 ['input', 'assert']
# 89 ['input', 'simplify', '*', 't', 't', 'rewrite-flag', None, 'flush?', None, 'linear?', None, 'cases-rewrite?', None, 'type-constraints?', 't', 'ignore-prover-output?', None, 'let-reduce?', 't', 'quant-simp?', None, 'implicit-typepreds?', None, 'ignore-typepreds?', None]
# 91 ['input', 'assert']
# 93 ['input', 'flatten-disjunct', None, None]
# 95 ['input', 'flatten']
# 97 ['input', 'simplify', '*', 't', 't', 'rewrite-flag', None, 'flush?', None, 'linear?', None, 'cases-rewrite?', None, 'type-constraints?', 't', 'ignore-prover-output?', None, 'let-reduce?', 't', 'quant-simp?', None, 'implicit-typepreds?', None, 'ignore-typepreds?', None]
# 99 ['input', 'assert']
# 101 ['input', 'expand', '<', '3']
# 103 ['input', 'simplify', '*', 't', 't', 'rewrite-flag', None, 'flush?', None, 'linear?', None, 'cases-rewrite?', None, 'type-constraints?', 't', 'ignore-prover-output?', None, 'let-reduce?', 't', 'quant-simp?', None, 'implicit-typepreds?', None, 'ignore-typepreds?', None]
# 105 ['input', 'assert']
# 107 ['input', 'flatten-disjunct', None, None]
# 109 ['input', 'flatten']
# 111 ['input', 'split']
# 113 ['input', 'simplify', '*', 't', 't', 'rewrite-flag', None, 'flush?', None, 'linear?', None, 'cases-rewrite?', None, 'type-constraints?', 't', 'ignore-prover-output?', None, 'let-reduce?', 't', 'quant-simp?', None, 'implicit-typepreds?', None, 'ignore-typepreds?', None]
# 115 ['input', 'assert']
# 117 ['input', 'split']
# 119 ['input', 'prop']
# 121 ['input', 'simplify', '*', 't', 't', 'rewrite-flag', None, 'flush?', None, 'linear?', None, 'cases-rewrite?', None, 'type-constraints?', 't', 'ignore-prover-output?', None, 'let-reduce?', 't', 'quant-simp?', None, 'implicit-typepreds?', None, 'ignore-typepreds?', None]
# 123 ['input', 'assert']
# 125 ['input', 'expand', '<', '4']
# 127 ['input', 'flatten-disjunct', None, None]
# 129 ['input', 'flatten']
# 131 ['input', 'simplify', '*', 't', 't', 'rewrite-flag', None, 'flush?', None, 'linear?', None, 'cases-rewrite?', None, 'type-constraints?', 't', 'ignore-prover-output?', None, 'let-reduce?', 't', 'quant-simp?', None, 'implicit-typepreds?', None, 'ignore-typepreds?', None]
# 133 ['input', 'assert']
# 135 ['input', 'inst', '-4', 'exp(r!1)', 'exp(t!1)']
# 137 ['input', 'simplify', '*', 't', 't', 'rewrite-flag', None, 'flush?', None, 'linear?', None, 'cases-rewrite?', None, 'type-constraints?', 't', 'ignore-prover-output?', None, 'let-reduce?', 't', 'quant-simp?', None, 'implicit-typepreds?', None, 'ignore-typepreds?', None]
# 139 ['input', 'assert']
# 141 ['input', 'simplify', '*', 't', 't', 'rewrite-flag', None, 'flush?', None, 'linear?', None, 'cases-rewrite?', None, 'type-constraints?', 't', 'ignore-prover-output?', None, 'let-reduce?', 't', 'quant-simp?', None, 'implicit-typepreds?', None, 'ignore-typepreds?', None]
# 143 ['input', 'assert']
# 145 ['input', 'typepred', {'tag': 'constant', 'constant-name': 'ordinals__t!1', 'actuals': None, 'type': 1247049813}]
# 147 ['input', 'expand', 'ordinal?', '-1']
# 149 ['input', 'typepred', {'tag': 'constant', 'constant-name': 'ordinals__r!1', 'actuals': None, 'type': 1247049813}]
# 151 ['input', 'expand', 'ordinal?', '-1']
# 153 ['input', 'simplify', '*', 't', 't', 'rewrite-flag', None, 'flush?', None, 'linear?', None, 'cases-rewrite?', None, 'type-constraints?', 't', 'ignore-prover-output?', None, 'let-reduce?', 't', 'quant-simp?', None, 'implicit-typepreds?', None, 'ignore-typepreds?', None]
# 155 ['input', 'assert']
# 157 ['input', 'expand', '<', '4']
# 159 ['input', 'simplify', '*', 't', 't', 'rewrite-flag', None, 'flush?', None, 'linear?', None, 'cases-rewrite?', None, 'type-constraints?', 't', 'ignore-prover-output?', None, 'let-reduce?', 't', 'quant-simp?', None, 'implicit-typepreds?', None, 'ignore-typepreds?', None]
# 161 ['input', 'assert']
# 163 ['input', 'expand', '<', '4']
# 165 ['input', 'simplify', '*', 't', 't', 'rewrite-flag', None, 'flush?', None, 'linear?', None, 'cases-rewrite?', None, 'type-constraints?', 't', 'ignore-prover-output?', None, 'let-reduce?', 't', 'quant-simp?', None, 'implicit-typepreds?', None, 'ignore-typepreds?', None]
# 167 ['input', 'assert']
# 169 ['input', 'expand', '<', '5']
# 171 ['input', 'simplify', '*', 't', 't', 'rewrite-flag', None, 'flush?', None, 'linear?', None, 'cases-rewrite?', None, 'type-constraints?', 't', 'ignore-prover-output?', None, 'let-reduce?', 't', 'quant-simp?', None, 'implicit-typepreds?', None, 'ignore-typepreds?', None]
# 173 ['input', 'assert']
# 175 ['input', 'inst', '-4', 'exp(r!1)', 'exp(t!1)']
# 177 ['input', 'simplify', '*', 't', 't', 'rewrite-flag', None, 'flush?', None, 'linear?', None, 'cases-rewrite?', None, 'type-constraints?', 't', 'ignore-prover-output?', None, 'let-reduce?', 't', 'quant-simp?', None, 'implicit-typepreds?', None, 'ignore-typepreds?', None]
# 179 ['input', 'assert']
# 181 ['input', 'typepred', {'tag': 'constant', 'constant-name': 'ordinals__t!1', 'actuals': None, 'type': 1247049813}]
# 183 ['input', 'expand', 'ordinal?', '-1']
# 185 ['input', 'simplify', '*', 't', 't', 'rewrite-flag', None, 'flush?', None, 'linear?', None, 'cases-rewrite?', None, 'type-constraints?', 't', 'ignore-prover-output?', None, 'let-reduce?', 't', 'quant-simp?', None, 'implicit-typepreds?', None, 'ignore-typepreds?', None]
# 187 ['input', 'assert']
# 189 ['input', 'typepred', {'tag': 'constant', 'constant-name': 'ordinals__r!1', 'actuals': None, 'type': 1247049813}]
# 191 ['input', 'expand', 'ordinal?', '-1']
# 193 ['input', 'simplify', '*', 't', 't', 'rewrite-flag', None, 'flush?', None, 'linear?', None, 'cases-rewrite?', None, 'type-constraints?', 't', 'ignore-prover-output?', None, 'let-reduce?', 't', 'quant-simp?', None, 'implicit-typepreds?', None, 'ignore-typepreds?', None]
# 195 ['input', 'assert']
# 197 ['input', 'expand', '<', '5']
# 199 ['input', 'simplify', '*', 't', 't', 'rewrite-flag', None, 'flush?', None, 'linear?', None, 'cases-rewrite?', None, 'type-constraints?', 't', 'ignore-prover-output?', None, 'let-reduce?', 't', 'quant-simp?', None, 'implicit-typepreds?', None, 'ignore-typepreds?', None]
# 201 ['input', 'assert']
# 203 ['input', 'expand', '<', '5']
# 205 ['input', 'simplify', '*', 't', 't', 'rewrite-flag', None, 'flush?', None, 'linear?', None, 'cases-rewrite?', None, 'type-constraints?', 't', 'ignore-prover-output?', None, 'let-reduce?', 't', 'quant-simp?', None, 'implicit-typepreds?', None, 'ignore-typepreds?', None]
# 207 ['input', 'assert']
# 209 ['input', 'split', '-5']
# 211 ['input', 'flatten-disjunct', None, None]
# 213 ['input', 'flatten']
# 215 ['input', 'hide', '-6']
# 217 ['input', 'split']
# 219 ['input', 'prop']
# 221 ['input', 'simplify', '*', 't', 't', 'rewrite-flag', None, 'flush?', None, 'linear?', None, 'cases-rewrite?', None, 'type-constraints?', 't', 'ignore-prover-output?', None, 'let-reduce?', 't', 'quant-simp?', None, 'implicit-typepreds?', None, 'ignore-typepreds?', None]
# 223 ['input', 'assert']
# 225 ['input', 'expand', '<', '4']
# 227 ['input', 'expand', '<', '4']
# 229 ['input', 'simplify', '*', 't', 't', 'rewrite-flag', None, 'flush?', None, 'linear?', None, 'cases-rewrite?', None, 'type-constraints?', 't', 'ignore-prover-output?', None, 'let-reduce?', 't', 'quant-simp?', None, 'implicit-typepreds?', None, 'ignore-typepreds?', None]
# 231 ['input', 'assert']
# 233 ['input', 'expand', '<', '4']
# 235 ['input', 'simplify', '*', 't', 't', 'rewrite-flag', None, 'flush?', None, 'linear?', None, 'cases-rewrite?', None, 'type-constraints?', 't', 'ignore-prover-output?', None, 'let-reduce?', 't', 'quant-simp?', None, 'implicit-typepreds?', None, 'ignore-typepreds?', None]
# 237 ['input', 'assert']
# 239 ['input', 'expand', '<', '3']
# 241 ['input', 'simplify', '*', 't', 't', 'rewrite-flag', None, 'flush?', None, 'linear?', None, 'cases-rewrite?', None, 'type-constraints?', 't', 'ignore-prover-output?', None, 'let-reduce?', 't', 'quant-simp?', None, 'implicit-typepreds?', None, 'ignore-typepreds?', None]
# 243 ['input', 'assert']
# 245 ['input', 'hide', '-4']
# 247 ['input', 'split', '-4']
# 249 ['input', 'flatten-disjunct', None, None]
# 251 ['input', 'flatten']
# 253 ['input', 'simplify', '*', 't', 't', 'rewrite-flag', None, 'flush?', None, 'linear?', None, 'cases-rewrite?', None, 'type-constraints?', 't', 'ignore-prover-output?', None, 'let-reduce?', 't', 'quant-simp?', None, 'implicit-typepreds?', None, 'ignore-typepreds?', None]
# 255 ['input', 'assert']
# 257 ['input', 'flatten-disjunct', None, None]
# 259 ['input', 'flatten']
# 261 ['input', 'simplify', '*', 't', 't', 'rewrite-flag', None, 'flush?', None, 'linear?', None, 'cases-rewrite?', None, 'type-constraints?', 't', 'ignore-prover-output?', None, 'let-reduce?', 't', 'quant-simp?', None, 'implicit-typepreds?', None, 'ignore-typepreds?', None]
# 263 ['input', 'assert']
# 265 ['input', 'split', '-1']
# 267 ['input', 'flatten-disjunct', None, None]
# 269 ['input', 'flatten']
# 271 ['input', 'simplify', '*', 't', 't', 'rewrite-flag', None, 'flush?', None, 'linear?', None, 'cases-rewrite?', None, 'type-constraints?', 't', 'ignore-prover-output?', None, 'let-reduce?', 't', 'quant-simp?', None, 'implicit-typepreds?', None, 'ignore-typepreds?', None]
# 273 ['input', 'assert']
# 275 ['input', 'flatten-disjunct', None, None]
# 277 ['input', 'flatten']
# 279 ['input', 'simplify', '*', 't', 't', 'rewrite-flag', None, 'flush?', None, 'linear?', None, 'cases-rewrite?', None, 'type-constraints?', 't', 'ignore-prover-output?', None, 'let-reduce?', 't', 'quant-simp?', None, 'implicit-typepreds?', None, 'ignore-typepreds?', None]
# 281 ['input', 'assert']
# 283 ['input', 'inst', '-8', 'rest(r!1)', 'rest(t!1)']
# 285 ['input', 'simplify', '*', 't', 't', 'rewrite-flag', None, 'flush?', None, 'linear?', None, 'cases-rewrite?', None, 'type-constraints?', 't', 'ignore-prover-output?', None, 'let-reduce?', 't', 'quant-simp?', None, 'implicit-typepreds?', None, 'ignore-typepreds?', None]
# 287 ['input', 'assert']
# 289 ['input', 'typepred', {'tag': 'constant', 'constant-name': 'ordinals__t!1', 'actuals': None, 'type': 1247049813}]
# 291 ['input', 'expand', 'ordinal?', '-1']
# 293 ['input', 'simplify', '*', 't', 't', 'rewrite-flag', None, 'flush?', None, 'linear?', None, 'cases-rewrite?', None, 'type-constraints?', 't', 'ignore-prover-output?', None, 'let-reduce?', 't', 'quant-simp?', None, 'implicit-typepreds?', None, 'ignore-typepreds?', None]
# 295 ['input', 'assert']
# 297 ['input', 'typepred', {'tag': 'constant', 'constant-name': 'ordinals__r!1', 'actuals': None, 'type': 1247049813}]
# 299 ['input', 'expand', 'ordinal?', '-1']
# 301 ['input', 'simplify', '*', 't', 't', 'rewrite-flag', None, 'flush?', None, 'linear?', None, 'cases-rewrite?', None, 'type-constraints?', 't', 'ignore-prover-output?', None, 'let-reduce?', 't', 'quant-simp?', None, 'implicit-typepreds?', None, 'ignore-typepreds?', None]
# 303 ['input', 'assert']
# - - - - -
# 1 ['input', 'skolem', '1', ['r!1', 's!1']]
# 3 ['input', 'skolem!', '*', 'keep-underscore?', None, 'skolem-typepreds?', None, 'dont-simplify?', None]
# 5 ['input', 'skosimp']
# 7 ['input', 'expand', '<=']
# 9 ['input', 'split']
# 11 ['input', 'split']
# 13 ['input', 'lemma', 'ordinal_antisym']
# 15 ['input', 'instantiate', '-1', [{'tag': 'constant', 'constant-name': 'ordinals__r!1', 'actuals': None, 'type': 1247049813}, {'tag': 'constant', 'constant-name': 'ordinals__s!1', 'actuals': None, 'type': 1247049813}]]
# 17 ['input', 'inst?']
# 19 ['input', 'simplify', '*', 't', 't', 'rewrite-flag', None, 'flush?', None, 'linear?', None, 'cases-rewrite?', None, 'type-constraints?', 't', 'ignore-prover-output?', None, 'let-reduce?', 't', 'quant-simp?', None, 'implicit-typepreds?', None, 'ignore-typepreds?', None]
# 21 ['input', 'assert']
# 23 ['input', 'simplify', '*', 't', 't', 'rewrite-flag', None, 'flush?', None, 'linear?', None, 'cases-rewrite?', None, 'type-constraints?', 't', 'ignore-prover-output?', None, 'let-reduce?', 't', 'quant-simp?', None, 'implicit-typepreds?', None, 'ignore-typepreds?', None]
# 25 ['input', 'assert']
# - - - - -
# 1 ['input', 'expand', 'well_founded?']
# 3 ['input', 'lemma', 'ordinal_induction']
# 5 ['input', 'skolem', '1', ['p!1']]
# 7 ['input', 'skolem!', '*', 'keep-underscore?', None, 'skolem-typepreds?', None, 'dont-simplify?', None]
# 9 ['input', 'skosimp']
# 11 ['input', 'skolem', '-2', ['y!1']]
# 13 ['input', 'skolem!', '*', 'keep-underscore?', None, 'skolem-typepreds?', None, 'dont-simplify?', None]
# 15 ['input', 'skosimp']
# 17 ['input', 'inst', '-1', 'LAMBDA (x:ordinal): NOT p!1(x)']
# 19 ['input', 'split']
# 21 ['input', 'inst', '-1', 'y!1']
# 23 ['input', 'skolem', '1', ['r!1']]
# 25 ['input', 'skolem!', '*', 'keep-underscore?', None, 'skolem-typepreds?', None, 'dont-simplify?', None]
# 27 ['input', 'skosimp']
# 29 ['input', 'inst', '1', 'r!1']
# 31 ['input', 'skolem', '1', ['x!1']]
# 33 ['input', 'skolem!', '*', 'keep-underscore?', None, 'skolem-typepreds?', None, 'dont-simplify?', None]
# 35 ['input', 'skosimp']
# 37 ['input', 'inst', '-1', 'x!1']
# 39 ['input', 'simplify', '*', 't', 't', 'rewrite-flag', None, 'flush?', None, 'linear?', None, 'cases-rewrite?', None, 'type-constraints?', 't', 'ignore-prover-output?', None, 'let-reduce?', 't', 'quant-simp?', None, 'implicit-typepreds?', None, 'ignore-typepreds?', None]
# 41 ['input', 'assert']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [196], in <cell line: 2>()
#       2 for json_fpath in tqdm(json_files):
#       3     with open(json_fpath, 'r') as f:
# ----> 4         json_root_obj = json.load(f)
#       5         if PROOF in json_root_obj:
#       6             proof_seq = json_root_obj[PROOF]
#
# File ~/anaconda/anaconda3/envs/coprovers/lib/python3.9/json/__init__.py:293, in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     274 def load(fp, *, cls=None, object_hook=None, parse_float=None,
#     275         parse_int=None, parse_constant=None, object_pairs_hook=None, **kw):
#     276     """Deserialize ``fp`` (a ``.read()``-supporting file-like object containing
#     277     a JSON document) to a Python object.
#     278
#    (...)
#     291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
#     294         cls=cls, object_hook=object_hook,
#     295         parse_float=parse_float, parse_int=parse_int,
#     296         parse_constant=parse_constant, object_pairs_hook=object_pairs_hook, **kw)
#
# File ~/anaconda/anaconda3/envs/coprovers/lib/python3.9/codecs.py:319, in BufferedIncrementalDecoder.decode(self, input, final)
#     314 def _buffer_decode(self, input, errors, final):
#     315     # Overwrite this method in subclasses: It must decode input
#     316     # and return an (output, length consumed) tuple
#     317     raise NotImplementedError
# --> 319 def decode(self, input, final=False):
#     320     # decode input (taking the buffer into account)
#     321     data = self.buffer + input
#     322     (result, consumed) = self._buffer_decode(data, self.errors, final)
#
# KeyboardInterrupt:

# %%
tok_counter
# Out:
# Counter({'proofstate': 16071,
#          'current-goal': 16071,
#          'sequent': 16071,
#          'antecedents': 16071,
#          'consequents': 16071,
#          's-formula': 86048,
#          'new?': 86048,
#          'formula': 86048,
#          'forall': 37188,
#          'bindings': 55674,
#          'variable': 218017,
#          'expression': 55403,
#          'apply': 403862,
#          'operator': 403380,
#          'getfield': 5996,
#          'field': 5996,
#          'dom': 34,
#          'argument': 418689,
#          'fun': 33,
#          'asserted?': 86048,
#          'hidden': 16071,
#          'constant': 536207,
#          'equalities__equal': 45881,
#          'tag': 214499,
#          'tuple': 214499,
#          'PartialFunctionDefinitions__SPartFun_to_LPartFun': 20,
#          'PartialFunctionComposition__oh__2': 9,
#          'PartialFunctionComposition__oh__1': 10,
#          'booleans__NOT': 59313,
#          'booleans__IMPLIES': 21100,
#          'PartialFunctionDefinitions__LPartFun_to_SPartFun': 30,
#          'booleans__AND': 12997,
#          'lift_adt__bottomp': 2,
#          'PartialFunctionComposition__f!1': 4,
#          'lift_adt__down': 8,
#          'PartialFunctionComposition__g!1': 2,
#          'list_adt__cons': 1154,
#          'reals__lessp': 16355,
#          'list_props__length': 1042,
#          'filters__p!1': 4,
#          'number_fields__plus': 12204,
#          'integer': 40415,
#          'integer-value': 40415,
#          1: 20541,
#          'reals__lesseqp': 7884,
#          'notequal__notequal__1': 593,
#          0: 19473,
#          'booleans__IFF': 6001,
#          'reals__greatereqp': 5210,
#          'number_fields__divide': 6731,
#          'booleans__OR': 2562,
#          'reals__greaterp': 5429,
#          'number_fields__difference__1': 5890,
#          'number_fields__difference__2': 3712,
#          'number_fields__times': 12285,
#          'real_defs__abs': 2120,
#          'reals__real_pred': 141,
#          'orders__total_orderp': 12,
#          -1: 745,
#          'if': 2360,
#          'test': 2360,
#          'then': 2360,
#          'else': 2360,
#          'orders__strict_total_orderp': 18,
#          'exists': 9379,
#          'bounded_real_defs__upper_boundp__1': 799,
#          'bounded_real_defs__least_upper_boundp__1': 762,
#          'lambda': 8772,
#          'integers__integer_pred': 645,
#          'rationals__rational_pred': 328,
#          'sets__nonemptyp': 1448,
#          'bv__caret': 97,
#          'bv_bitwise__XOR': 31,
#          'xor_def__XOR': 2,
#          'bv_bitwise__AND': 29,
#          'bv_bitwise__IFF': 1,
#          'bv_bitwise__OR': 28,
#          'bv_bitwise__NOT': 28,
#          'function_image__inverse_image__1': 20,
#          'sets__union': 293,
#          'sets__subsetp': 611,
#          'function_image__image__1': 465,
#          'sets__intersection': 290,
#          'function_image__f!1': 6,
#          'sets__complement': 353,
#          'identity_props__S_pred': 3,
#          'identity__identity': 1,
#          'identity__id': 1,
#          'identity__I': 1,
#          'orders__well_orderedp': 3,
#          'restrict__restrict': 339,
#          'orders__strict_orderp': 28,
#          'relations__symmetricp': 242,
#          'restrict_order_props__R!1': 121,
#          'orders__preorderp': 18,
#          'relations__equivalencep': 410,
#          'orders__trichotomousp': 11,
#          'orders__dichotomousp': 11,
#          'relations__transitivep': 348,
#          'orders__partial_orderp': 15,
#          'relations__irreflexivep': 19,
#          'orders__well_foundedp': 35,
#          'restrict_order_props__p!1': 25,
#          'extend__extend': 1448,
#          'restrict_order_props__S_pred': 9,
#          'relations__reflexivep': 529,
#          'relations__antisymmetricp': 25,
#          'relations__connectedp': 2,
#          'KernelDefinition__PreservesEq': 981,
#          'QuotientDefinition__quotient_map': 3792,
#          'KernelDefinition__EquivalenceKernel': 682,
#          'sets__member': 1378,
#          'project': 9313,
#          'index': 9313,
#          2: 7236,
#          'QuotientDefinition__EquivClass': 5427,
#          'QuotientKernelProperties__S!1': 50,
#          'EquivalenceClosure__EquivClos': 360,
#          'list_adt__every__1': 345,
#          'list_props__append': 274,
#          'list_props__member': 78,
#          'list_props__nth': 1246,
#          'list_props__P!1': 136,
#          'list_props__Q!1': 30,
#          'list_props__reverse': 276,
#          'list_adt__reduce_nat': 2,
#          'cases': 241,
#          'expr': 1058,
#          'selections': 241,
#          'selection': 482,
#          'pattern': 482,
#          'backquote': 482,
#          'else-part': 241,
#          'list_adt__consp': 58,
#          '-1': 276,
#          'list_adt__nullp': 21,
#          'list_adt__cdr': 346,
#          'list_adt__every__2': 1,
#          'finite_sets__is_finite': 1130,
#          'sets__difference': 136,
#          'infinite_sets_def__f!1': 101,
#          'infinite_sets_def__f!2': 77,
#          'infinite_sets_def__Fin!1': 40,
#          'sets__add': 225,
#          'sets__remove': 196,
#          'sets__emptyp': 286,
#          'sets__rest': 287,
#          'sets__choose': 3559,
#          'functions__injectivep': 2254,
#          'infinite_sets_def__Inf!1': 8,
#          'relation_props__oh': 140,
#          'relation_props2__R1!1': 62,
#          'relation_props2__R2!1': 68,
#          'relation_props2__R3!1': 62,
#          'ordinals__lessp': 2772,
#          'lex3__lex3': 15,
#          'lex2__lex2': 22,
#          'ordstruct_adt__add': 5920,
#          'ordstruct_adt__coef': 1420,
#          'ordinals__ordinalp': 855,
#          'quantifier_props__p!1': 22,
#          'sets_lemmas__Complement': 92,
#          'sets__Union': 370,
#          'sets__some__1': 7,
#          'sets__every__1': 33,
#          'sets__powerset': 81,
#          'finite_sets_of_sets__f!1': 400,
#          'finite_sets_of_sets__a!1': 13,
#          'finite_sets_of_sets__a!2': 8,
#          'finite_sets_of_sets__b!1': 53,
#          'finite_sets_of_sets__f!3': 52,
#          'finite_sets_of_sets__f!2': 59,
#          'finite_sets_of_sets__B!1': 28,
#          'finite_sets_of_sets__powerset_natfun': 33,
#          'finite_sets_of_sets__powerset_natfun_rec': 850,
#          'function_inverse__inverse': 1342,
#          'finite_sets__card': 2726,
#          'finite_sets_of_sets__B1!1': 294,
#          'finite_sets_of_sets__B2!1': 296,
#          'finite_sets_of_sets__A!1': 44,
#          'finite_sets_of_sets__f': 237,
#          'functions__bijectivep': 1354,
#          'epsilons__epsilon': 1090,
#          'functions__surjectivep': 528,
#          'finite_sets__Card': 171,
#          'sets__Intersection': 143,
#          'finite_sets_of_sets__SS!1': 32,
#          'finite_sets_of_sets__x!1': 24,
#          'exp2__exp2': 1957,
#          'bounded_int_inductions__pf!1': 220,
#          'formal-constant': 2212,
#          'bounded_int_inductions__pa!1': 251,
#          'floor_ceil__floor': 1577,
#          'integers__integerp': 34,
#          'floor_ceil__ceiling': 110,
#          'floor_ceil__fractional': 116,
#          'mod__mod': 478,
#          'real_defs__sgn': 70,
#          'integers__evenp': 113,
#          'integers__oddp': 126,
#          'bv_caret__caret': 6,
#          'bv_caret__bv!1': 1,
#          'function_props__oh': 425,
#          'function_image_aux__inj!1': 200,
#          'function_image_aux__f!1': 464,
#          'function_image_aux__S!1': 62,
#          'function_image_aux__f!4': 269,
#          'function_image_aux__f!2': 69,
#          'length': 4685,
#          'functions_alt__inverts': 2,
#          'functions_alt__preserves': 1,
#          'character_adt__code': 869,
#          'functions__preserves__2': 2,
#          'functions__inverts__1': 4,
#          'functions__preserves__1': 5,
#          'function_props__f2!1': 2,
#          'function_props__f1!1': 1,
#          'ordinals__size': 12,
#          'ordstruct_adt__zerop': 498,
#          'ordstruct_adt__exp': 805,
#          'ordstruct_adt__rest': 270,
#          'ordinals__lesseqp': 8,
#          'ordinals__p!1': 42,
#          'ordinals__v1': 7,
#          'ordstruct_adt__reduce_nat': 12,
#          'list2finseq__list2finseq': 516,
#          'list_adt__car': 119,
#          'list2finseq__finseq2list': 30,
#          'seq': 1199,
#          'list2finseq__finseq2list_rec': 161,
#          'bounded_real_defs_alt__lower_boundp': 1,
#          'bounded_real_defs_alt__upper_boundp': 1,
#          'function_iterate__iterate': 1410,
#          'function_iterate__f!1': 105,
#          'list_adt_map__map__1': 398,
#          'map_props__f2!1': 19,
#          'map_props__f1!1': 25,
#          'seq_functions__map__1': 12,
#          'sequences__nth': 111,
#          'bv_nat__bv2nat': 506,
#          'bv_nat__bv2nat_rec': 616,
#          'bit__b2n': 106,
#          'update': 64,
#          'assignments': 64,
#          'bv_nat__bv1!1': 114,
#          'bv_nat__bv2!1': 117,
#          'bv_nat__x!1': 3,
#          'bv_nat__y!1': 3,
#          'bv_nat__nat2bv': 239,
#          'bv__fill': 32,
#          'bv_nat__bv!1': 78,
#          'gen_strings__strdiff': 426,
#          'real_defs__min': 1163,
#          'let': 335,
#          'let-binding': 335,
#          'id': 335,
#          'i': 330,
#          'declared-type': 335,
#          'body': 335,
#          'gen_strings__get': 737,
#          'gen_strings__strdiff_rec': 755,
#          'gen_strings__suffix': 14,
#          'gen_strings__unit': 6,
#          'gen_strings__strcmp': 11,
#          'finite_sequences__oh': 29,
#          'gen_strings__prefix': 10,
#          'sequences__insert': 3,
#          'sequences__delete': 25,
#          'sequences__seq!1': 51,
#          'sequences__add': 2,
#          'sequences__first': 12,
#          'sequences__rest': 12,
#          'sequences__suffix': 1,
#          'sequences__every__1': 11,
#          'sequences__p!1': 35,
#          'exponentiation__caret': 2173,
#          'modulo_arithmetic__ndiv': 239,
#          'stdio__fopenp': 2,
#          'stdio__eofp': 2,
#          'EquivalenceClosure__S!1': 164,
#          'EquivalenceClosure__R!1': 36,
#          'EquivalenceClosure__S!2': 31,
#          'bv_arith_nat_defs__difference': 1,
#          'bv_arith_nat_defs__plus__1': 8,
#          'sets_lemmas__a!1': 577,
#          'sets__emptyset': 26,
#          'sets__singleton': 136,
#          'sets_lemmas__b!1': 243,
#          'sets_lemmas__A!1': 231,
#          'sets_lemmas__B!1': 15,
#          'sets_lemmas__c!1': 63,
#          'sets_lemmas__y!1': 43,
#          'sets__fullp': 6,
#          'sets__disjointp': 61,
#          'sets_lemmas__z!1': 10,
#          'sets__strict_subsetp': 8,
#          'sets_lemmas__x!1': 25,
#          'sets__singletonp': 41,
#          'sets_lemmas__x!2': 5,
#          'nat_fun_props__f!1': 781,
#          'K_props__S_pred': 2,
#          'K_conversion__K_conversion': 2,
#          'exists1__exists1': 32,
#          'function_inverse_def__inversep__1': 152,
#          'exists1__uniquep': 30,
#          'function_inverse_def__f!1': 292,
#          'function_inverse_def__x!1': 35,
#          'function_inverse_def__y!1': 34,
#          'function_inverse_def__right_inversep__1': 37,
#          'function_inverse_def__left_inversep__1': 47,
#          'function_inverse_def__g!1': 16,
#          'extend_func_props__f!1': 14,
#          'charstrings__strdiff_rec': 761,
#          'charstrings__strdiff': 420,
#          'charstrings__cget': 738,
#          'charstrings__suffix': 5,
#          268435456: 8,
#          'charstrings__unit': 3,
#          'charstrings__strcmp': 11,
#          'charstrings__doubleplus': 2,
#          'charstrings__prefix': 4,
#          'real_defs__max': 80,
#          'mucalculus__monotonicp': 9,
#          'ctlops__EU': 1,
#          'ctlops__EX': 3,
#          'fairctlops__p1!1': 68,
#          'fairctlops__p2!1': 70,
#          'fairctlops__f!1': 137,
#          'fairctlops__Ff!1': 74,
#          'fairctlops__N!1': 163,
#          'fairctlops__p!1': 136,
#          'divides__divides__1': 400,
#          'divides__divides__2': 5,
#          'QuotientDistributive__EqualityExtension': 599,
#          'QuotientDistributive__S!1': 3029,
#          'QuotientDistributive__F!1': 6004,
#          'QuotientDistributive__x!1': 1069,
#          'QuotientDistributive__y!1': 1208,
#          'QuotientDistributive__z!1': 19,
#          'QuotientExtensionProperties__lift': 798,
#          'QuotientDistributive__RelExtension': 1015,
#          'QuotientDefinition__rep': 1094,
#          'QuotientDistributive__x1!1': 3,
#          'QuotientDistributive__x2!1': 5,
#          'QuotientDistributive__R!1': 1849,
#          'QuotientDistributive__FunExtension': 3246,
#          'QuotientDistributive__x!3': 586,
#          'QuotientDistributive__x!2': 1049,
#          'QuotientDistributive__ch1': 591,
#          'QuotientDistributive__ch2': 538,
#          'QuotientDistributive__x!6': 4,
#          'QuotientDistributive__ch': 134,
#          'bv_int_defs__bv2int': 122,
#          'sets__a!1': 167,
#          'sets__the': 54,
#          'sets__p!1': 40,
#          'sets__singleton_elt': 17,
#          'sets__x!1': 17,
#          'extend_set_props__S_pred': 73,
#          'extend_set_props__a!1': 79,
#          'extend_set_props__f!1': 109,
#          'lift_adt__upp': 3,
#          'PartialFunctionDefinitions__f!1': 7,
#          'lift_adt__up': 2,
#          'QuotientDefinition__repEC': 76,
#          'QuotientDefinition__S!1': 316,
#          'QuotientDefinition__P!1': 50,
#          'Fairctlops__CheckFair': 185,
#          'Fairctlops__p1!1': 26,
#          'Fairctlops__p2!1': 26,
#          'Fairctlops__f!1': 136,
#          'Fairctlops__cons1_var!1': 74,
#          'Fairctlops__N!1': 162,
#          'Fairctlops__p!1': 123,
#          3: 1012,
#          'ordstruct_adt__nonzerop': 962,
#          'lex4__lex4': 6,
#          'functions__f!1': 12,
#          'functions__g!1': 11,
#          'modulo_arithmetic__rem': 1712,
#          'exponentiation__expt': 5778,
#          'modulo_arithmetic__nrem': 253,
#          4: 7,
#          4294967296: 5,
#          'bytestrings__strdiff': 358,
#          'bytestrings__get': 490,
#          'bytestrings__strdiff_rec': 823,
#          'bytestrings__suffix': 5,
#          'bytestrings__unit': 3,
#          'bytestrings__strcmp': 11,
#          'bytestrings__doubleplus': 1,
#          'bytestrings__prefix': 4,
#          256: 1,
#          'min_nat__T_pred': 69,
#          'min_nat__S!1': 148,
#          'min_nat__min': 81,
#          'min_nat__minimump': 5,
#          'finite_sets__f!1': 1124,
#          'finite_sets__s!1': 77,
#          'finite_sets__A!1': 179,
#          'finite_sets__P1!1': 22,
#          'finite_sets__P2!1': 22,
#          'finite_sets__f!2': 112,
#          'finite_sets__B!1': 98,
#          'finite_sets__S!1': 209,
#          'finite_sets__g!1': 73,
#          'finite_sets__P1': 43,
#          'finite_sets__P2': 43,
#          'finite_sets__f': 2,
#          'sets__fullset': 4,
#          'finite_sets__S2!1': 15,
#          'finite_sets__inj_set': 44,
#          'finite_sets__bij': 46,
#          'finite_sets__ibij': 6,
#          'restrict_set_props__f!1': 87,
#          'restrict_set_props__S_pred': 14,
#          'restrict_set_props__a!1': 19,
#          'exists1__p!1': 52,
#          'exists1__q!1': 41,
#          'function_inverse_alt__f!1': 509,
#          'function_inverse_alt__inverse_alt': 166,
#          'function_inverse_alt__gg': 81,
#          'function_inverse_alt__g!1': 58,
#          'wf_induction__p!1': 71,
#          'QuotientSubDefinition__S!1': 7,
#          'QuotientSubDefinition__X1_pred': 3,
#          16: 206,
#          64: 173,
#          32: 174,
#          8: 133,
#          255: 1,
#          9223372036854775807: 1,
#          7: 2,
#          65535: 1,
#          4294967295: 1,
#          28: 2,
#          31: 2,
#          15: 2,
#          63: 2,
#          'measure_induction__p!1': 50,
#          'indexed_sets__IIntersection': 12,
#          'function_image__image__2': 2,
#          'indexed_sets__A!1': 80,
#          'indexed_sets__a!1': 2,
#          'indexed_sets__IUnion': 21,
#          'indexed_sets__S!1': 7,
#          'indexed_sets__B!1': 38,
#          'function_inverse__f!1': 1336,
#          'orders_alt__upper_boundp': 1,
#          'orders_alt__lower_boundp': 1,
#          'QuotientIteration__action': 658,
#          'QuotientIteration__R!1': 704,
#          'QuotientIteration__S!1': 630,
#          'QuotientIteration__ch1': 23,
#          'ctlops__p1!1': 14,
#          'ctlops__p2!1': 19,
#          'ctlops__f!1': 6,
#          'ctlops__N!1': 14,
#          'ctlops__g!1': 6,
#          'subrange_inductions__p!1': 261,
#          'more_map_props__f!1': 66,
#          'more_map_props__f!2': 6,
#          'more_map_props__P': 14,
#          'more_map_props__g': 2,
#          'more_map_props__f': 11,
#          'list_adt_map__map__2': 1,
#          'naturalnumbers__p!1': 217,
#          'mucalculus__lesseqp': 4,
#          'mucalculus__lfp': 1,
#          'mucalculus__pp!1': 28,
#          'mucalculus__p!1': 20,
#          'mucalculus__gfp': 1,
#          'relation_defs__converse': 22,
#          'relation_converse_props__R!1': 70,
#          'restrict__f!1': 2,
#          'bounded_real_defs__greatest_lower_boundp__1': 180,
#          'bounded_real_defs__lower_boundp__1': 113,
#          'bounded_real_defs__bounded_belowp': 6,
#          'bounded_real_defs__S!1': 88,
#          'bounded_real_defs__lub': 48,
#          'bounded_real_defs__glb': 44,
#          'bounded_real_defs__bounded_abovep': 10,
#          'bounded_nat_inductions__pt!1': 163,
#          'bounded_nat_inductions__pb!1': 189,
#          'QuotientExtensionProperties__X1_pred': 94,
#          'QuotientExtensionProperties__S!1': 259,
#          'QuotientExtensionProperties__g!1': 157,
#          'QuotientSubDefinition__quotient_sub_map': 36,
#          'QuotientExtensionProperties__h!1': 45,
#          'extend_order_props__R!1': 146,
#          'extend_order_props__S_pred': 132,
#          'list_adt__doublelessp': 1,
#          'pos': 31,
#          't2': 4,
#          'stdtokenizer__consume': 1,
#          'error': 8,
#          'stdtokenizer__accept_word__1': 1,
#          'stdtokenizer__accept_real__1': 1,
#          'stdtokenizer__eotp': 4,
#          'stdstr__numberp': 2,
#          'stream': 6,
#          'stdtokenizer__accept_int__1': 1,
#          'stdstr__intp': 1,
#          'stdstr__str2int': 1,
#          'stdio__fopenin__1': 2,
#          'n': 1,
#          'stdfmap__fmap__1': 1,
#          'stdtokenizer__read_token': 1,
#          'stdprog__prog': 4,
#          'stdio__fclose': 4,
#          'stdstr__str2real': 1,
#          'orders__strict_well_foundedp': 2,
#          'orders__x!1': 31,
#          'orders__linear_orderp': 4,
#          'relation_defs__ontop': 4,
#          'relation_defs__totalp': 4,
#          'integer_props__N!1': 129,
#          'integer_props__I!1': 236})

# %%
len(to_examine_json)
# Out:
# 3

# %%
JSON(to_examine_json[0])
