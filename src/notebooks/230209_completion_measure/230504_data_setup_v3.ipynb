# %%
"""
Implements the V3 of the data setup, using the same seed and splits as v1
(src/notebooks/230209_completion_measure/230209_data_setup.ipynb) except
start sequent is not included."""

from tqdm import tqdm

from coprover.lemmaret.vectorizers import *

# %%
sbv = SBertVectorizer()

# %%
sbv.vectorize("<ANT> <CONS> s-formula apply constant apply constant constant constant <HID>").shape
# Out:
# (768,)

# %%
tokenizer = sbv.model.tokenizer

# %%
from transformers import (
    T5ForConditionalGeneration,
    MT5ForConditionalGeneration,
    ByT5Tokenizer,
    PreTrainedTokenizer,
    T5TokenizerFast as T5Tokenizer,
    MT5TokenizerFast as MT5Tokenizer,
)

# %%
tokenizer.encode("<ANT> <CONS> s-formula apply constant apply constant constant constant <HID>")
# Out:
# [4,
#  38,
#  423,
#  62,
#  40,
#  1363,
#  45,
#  57,
#  56,
#  61,
#  40,
#  290,
#  23,
#  857,
#  339,
#  1983,
#  390,
#  418,
#  1983,
#  390,
#  418,
#  390,
#  418,
#  390,
#  418,
#  1363,
#  1385,
#  46,
#  40,
#  5]

# %%
# Now msuter the data
from pathlib import Path
import pandas as pd

from coprover import DATA_ROOT, RSC_ROOT

cmdpred_df = pd.read_csv(Path(RSC_ROOT, "pvs_cmd_pred", "data","cmdpred_N3.pvslib.tsv.gz"), sep='\t', names=['sequent', 'command', 'cmd_history', 'uri'])

# %%
cmdpred_df[0:22]
# Out:
#                                               sequent   command  \
# 0   <ANT> <CONS> s-formula forall ['variable'] ['v...  skosimp*
# 1   <ANT> <CONS> s-formula apply constant apply co...  typepred
# 2   <ANT> s-formula apply constant apply constant ...  typepred
# 3   <ANT> s-formula apply constant apply constant ...    expand
# 4   <ANT> s-formula apply constant apply constant ...    expand
# 5   <ANT> s-formula apply constant forall ['variab...  skosimp*
# 6   <ANT> s-formula apply constant forall ['variab...    expand
# 7   <ANT> s-formula apply constant forall ['variab...      inst
# 8   <ANT> s-formula apply constant apply constant ...      inst
# 9   <ANT> s-formula apply constant apply constant ...    expand
# 10  <ANT> s-formula apply constant forall ['variab...    expand
# 11  <ANT> s-formula apply constant forall ['variab...  skosimp*
# 12  <ANT> s-formula apply constant forall ['variab...      inst
# 13  <ANT> s-formula apply constant forall ['variab...  skosimp*
# 14  <ANT> s-formula apply constant forall ['variab...      inst
# 15  <ANT> s-formula apply constant exists ['variab...  skosimp*
# 16  <ANT> s-formula apply constant forall ['variab...      inst
# 17  <ANT> s-formula apply constant forall ['variab...  skosimp*
# 18  <ANT> s-formula apply constant forall ['variab...      inst
# 19  <ANT> s-formula apply constant forall ['variab...  simplify
# 20  <ANT> s-formula apply constant forall ['variab...      inst
# 21  <ANT> s-formula apply constant apply constant ...  simplify
#
#                    cmd_history                                        uri  \
# 0               NOOP,NOOP,NOOP   vect2_cont_comp-proofs/comp_rr_vr_cont#0
# 1           NOOP,NOOP,skosimp*   vect2_cont_comp-proofs/comp_rr_vr_cont#1
# 2       NOOP,skosimp*,typepred   vect2_cont_comp-proofs/comp_rr_vr_cont#2
# 3   skosimp*,typepred,typepred   vect2_cont_comp-proofs/comp_rr_vr_cont#3
# 4     typepred,typepred,expand   vect2_cont_comp-proofs/comp_rr_vr_cont#4
# 5       typepred,expand,expand   vect2_cont_comp-proofs/comp_rr_vr_cont#5
# 6       expand,expand,skosimp*   vect2_cont_comp-proofs/comp_rr_vr_cont#6
# 7       expand,skosimp*,expand   vect2_cont_comp-proofs/comp_rr_vr_cont#7
# 8         skosimp*,expand,inst   vect2_cont_comp-proofs/comp_rr_vr_cont#8
# 9             expand,inst,inst   vect2_cont_comp-proofs/comp_rr_vr_cont#9
# 10            inst,inst,expand  vect2_cont_comp-proofs/comp_rr_vr_cont#10
# 11          inst,expand,expand  vect2_cont_comp-proofs/comp_rr_vr_cont#11
# 12      expand,expand,skosimp*  vect2_cont_comp-proofs/comp_rr_vr_cont#12
# 13        expand,skosimp*,inst  vect2_cont_comp-proofs/comp_rr_vr_cont#13
# 14      skosimp*,inst,skosimp*  vect2_cont_comp-proofs/comp_rr_vr_cont#14
# 15          inst,skosimp*,inst  vect2_cont_comp-proofs/comp_rr_vr_cont#15
# 16      skosimp*,inst,skosimp*  vect2_cont_comp-proofs/comp_rr_vr_cont#16
# 17          inst,skosimp*,inst  vect2_cont_comp-proofs/comp_rr_vr_cont#17
# 18      skosimp*,inst,skosimp*  vect2_cont_comp-proofs/comp_rr_vr_cont#18
# 19          inst,skosimp*,inst  vect2_cont_comp-proofs/comp_rr_vr_cont#19
# 20      skosimp*,inst,simplify  vect2_cont_comp-proofs/comp_rr_vr_cont#21
# 21          inst,simplify,inst  vect2_cont_comp-proofs/comp_rr_vr_cont#22
#
#                                  proofname
# 0   vect2_cont_comp-proofs/comp_rr_vr_cont
# 1   vect2_cont_comp-proofs/comp_rr_vr_cont
# 2   vect2_cont_comp-proofs/comp_rr_vr_cont
# 3   vect2_cont_comp-proofs/comp_rr_vr_cont
# 4   vect2_cont_comp-proofs/comp_rr_vr_cont
# 5   vect2_cont_comp-proofs/comp_rr_vr_cont
# 6   vect2_cont_comp-proofs/comp_rr_vr_cont
# 7   vect2_cont_comp-proofs/comp_rr_vr_cont
# 8   vect2_cont_comp-proofs/comp_rr_vr_cont
# 9   vect2_cont_comp-proofs/comp_rr_vr_cont
# 10  vect2_cont_comp-proofs/comp_rr_vr_cont
# 11  vect2_cont_comp-proofs/comp_rr_vr_cont
# 12  vect2_cont_comp-proofs/comp_rr_vr_cont
# 13  vect2_cont_comp-proofs/comp_rr_vr_cont
# 14  vect2_cont_comp-proofs/comp_rr_vr_cont
# 15  vect2_cont_comp-proofs/comp_rr_vr_cont
# 16  vect2_cont_comp-proofs/comp_rr_vr_cont
# 17  vect2_cont_comp-proofs/comp_rr_vr_cont
# 18  vect2_cont_comp-proofs/comp_rr_vr_cont
# 19  vect2_cont_comp-proofs/comp_rr_vr_cont
# 20  vect2_cont_comp-proofs/comp_rr_vr_cont
# 21  vect2_cont_comp-proofs/comp_rr_vr_cont

# %%
start_state = None
last_state = None
last_proofname = None

def get_proofname(uri):
    return uri.split('#', 1)[0]


proofnames = [get_proofname(row.uri) for idx, row in cmdpred_df.iterrows()]

# %%
cmdpred_df['proofname'] = proofnames

# %%
grp_obj = cmdpred_df.groupby('proofname')

# %%
proofnames = list(grp_obj.groups.keys())
print(len(proofnames))
# Out:
# 7656

# %%
PROOFNAME = "proofname"
STATE = "source_text"
LABEL = "target_text"
POS = "pos"
NEG = "neg"
CMD_HISTORY = "cmd_history"

class MTuple:
    def __init__(self, proofname, start_row, end_row, label):
        self.proofname = proofname
        self.label = label
        self.start_row, self.end_row = start_row, end_row
        self.cmd_history = self.end_row.cmd_history
        assert str(self.start_row) != str(self.end_row)

    def __str__(self, str):
        return self.proofname
    
    def _statestr(self):
        cmdhist_str = self.end_row.cmd_history.replace(",", " ")
        return "{} {}".format(cmdhist_str, self.end_row.sequent)  # First naive formulation
    
    def as_row(self):
        return {
            PROOFNAME: self.proofname,
            STATE: self._statestr(),
            CMD_HISTORY: self.end_row.cmd_history.replace(",", " "),
            LABEL: self.label
        }

# %%
from random import Random

rnd = Random()
rnd.seed(1337)

pos_mtuples = []
neg_mtuples = []
hard_neg_mtuples = []

for proofname in tqdm(proofnames):
    rows = grp_obj.get_group(proofname)
    if len(rows) >= 3:
        start_row = rows.iloc[0]
        end_row = rows.iloc[len(rows)-1]
        hard_neg_row = rows.iloc[len(rows)-2]
        random_neg_row = rows.iloc[rnd.randint(1, len(rows) - 1)]
        pos_mtuples.append(MTuple(proofname, start_row, end_row, POS))
        neg_mtuples.append(MTuple(proofname, start_row, random_neg_row, NEG))
        hard_neg_mtuples.append(MTuple(proofname, start_row, hard_neg_row, NEG))
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 7656/7656 [00:15<00:00, 483.84it/s]

# %%
idx=0
print("Start")
print(pos_mtuples[idx].start_row.sequent, pos_mtuples[idx].start_row.cmd_history)
print("\n\nPositive")
print(pos_mtuples[idx].end_row.sequent, pos_mtuples[idx].end_row.cmd_history)

print("\n\nNegative")
print(neg_mtuples[idx].end_row.sequent, neg_mtuples[idx].end_row.cmd_history)

print("\n\nHard Negative")
print(hard_neg_mtuples[idx].end_row.sequent, hard_neg_mtuples[idx].end_row.cmd_history)
# Out:
# Start
# <ANT> <CONS> s-formula forall ['variable'] ['variable'] ['variable'] apply constant apply constant apply constant ['variable'] apply constant ['variable'] apply constant ['variable'] ['variable'] apply constant apply constant ['variable'] ['variable'] apply constant ['variable'] ['variable'] <HID>  NOOP,NOOP,NOOP
#
#
# Positive
# <ANT> s-formula apply constant apply constant type-actual apply constant integer constant apply constant constant apply constant apply constant constant constant apply constant constant constant s-formula apply constant apply constant type-actual apply constant constant constant integer s-formula apply constant forall ['variable'] apply constant apply constant apply constant type-actual ['variable'] integer apply constant type-actual ['variable'] constant apply constant apply constant ['variable'] constant s-formula apply constant apply constant constant integer s-formula apply constant apply constant type-actual apply constant constant constant apply constant constant constant <CONS> s-formula apply constant constant constant s-formula apply constant type-actual constant apply constant constant apply constant apply constant constant constant apply constant constant constant <HID> s-formula exists ['variable'] apply constant type-actual constant apply constant constant ['variable'] s-formula apply constant apply constant type-actual apply constant apply constant apply constant constant constant constant apply constant apply constant constant constant constant apply constant constant apply constant apply constant constant constant apply constant constant constant s-formula apply constant apply constant type-actual integer apply constant apply constant constant constant apply constant constant constant s-formula apply constant forall ['variable'] ['variable'] ['variable'] apply constant apply constant type-actual ['variable'] ['variable'] apply constant type-actual apply constant ['variable'] ['variable'] apply constant ['variable'] ['variable'] s-formula apply constant forall ['variable'] ['variable'] apply constant apply constant apply constant type-actual ['variable'] integer apply constant type-actual ['variable'] integer apply constant apply constant type-actual apply constant ['variable'] ['variable'] integer exists ['variable'] ['variable'] apply constant type-actual integer apply constant apply constant ['variable'] ['variable'] apply constant ['variable'] ['variable'] s-formula apply constant forall ['variable'] ['variable'] apply constant apply constant apply constant ['variable'] apply constant apply constant ['variable'] ['variable'] apply constant type-actual apply constant ['variable'] ['variable'] integer factor,expand,inst
#
#
# Negative
# <ANT> s-formula apply constant apply constant type-actual apply constant integer constant apply constant apply constant apply constant constant constant constant apply constant apply constant constant constant constant s-formula apply constant apply constant type-actual apply constant constant constant integer s-formula apply constant forall ['variable'] apply constant apply constant apply constant type-actual ['variable'] integer apply constant type-actual ['variable'] constant apply constant apply constant ['variable'] constant s-formula apply constant apply constant constant integer s-formula apply constant apply constant type-actual apply constant constant constant apply constant constant constant <CONS> s-formula apply constant constant constant s-formula apply constant constant constant <HID> s-formula apply constant apply constant type-actual integer apply constant apply constant constant constant apply constant constant constant s-formula apply constant forall ['variable'] ['variable'] ['variable'] apply constant apply constant type-actual ['variable'] ['variable'] apply constant type-actual apply constant ['variable'] ['variable'] apply constant ['variable'] ['variable'] s-formula apply constant forall ['variable'] ['variable'] apply constant apply constant apply constant type-actual ['variable'] integer apply constant type-actual ['variable'] integer apply constant apply constant type-actual apply constant ['variable'] ['variable'] integer exists ['variable'] ['variable'] apply constant type-actual integer apply constant apply constant ['variable'] ['variable'] apply constant ['variable'] ['variable'] s-formula apply constant forall ['variable'] ['variable'] apply constant apply constant apply constant ['variable'] apply constant apply constant ['variable'] ['variable'] apply constant type-actual apply constant ['variable'] ['variable'] integer skosimp*,mult-by,simplify
#
#
# Hard Negative
# <ANT> s-formula apply constant apply constant type-actual apply constant integer constant apply constant constant apply constant apply constant constant constant apply constant constant constant s-formula apply constant apply constant type-actual apply constant constant constant integer s-formula apply constant forall ['variable'] apply constant apply constant apply constant type-actual ['variable'] integer apply constant type-actual ['variable'] constant apply constant apply constant ['variable'] constant s-formula apply constant apply constant constant integer s-formula apply constant apply constant type-actual apply constant constant constant apply constant constant constant <CONS> s-formula apply constant constant constant s-formula exists ['variable'] apply constant type-actual constant apply constant constant ['variable'] <HID> s-formula apply constant apply constant type-actual apply constant apply constant apply constant constant constant constant apply constant apply constant constant constant constant apply constant constant apply constant apply constant constant constant apply constant constant constant s-formula apply constant apply constant type-actual integer apply constant apply constant constant constant apply constant constant constant s-formula apply constant forall ['variable'] ['variable'] ['variable'] apply constant apply constant type-actual ['variable'] ['variable'] apply constant type-actual apply constant ['variable'] ['variable'] apply constant ['variable'] ['variable'] s-formula apply constant forall ['variable'] ['variable'] apply constant apply constant apply constant type-actual ['variable'] integer apply constant type-actual ['variable'] integer apply constant apply constant type-actual apply constant ['variable'] ['variable'] integer exists ['variable'] ['variable'] apply constant type-actual integer apply constant apply constant ['variable'] ['variable'] apply constant ['variable'] ['variable'] s-formula apply constant forall ['variable'] ['variable'] apply constant apply constant apply constant ['variable'] apply constant apply constant ['variable'] ['variable'] apply constant type-actual apply constant ['variable'] ['variable'] integer simplify,factor,expand

# %%
# save as a dataframe and then feed into simple_t5
# setup so only tuples below max token lengths can be used

filtered_rows = []
total = 0
for mt in pos_mtuples + neg_mtuples:
    entry = mt.as_row()
    total += 1
    if len(entry[STATE].split()) <= 1000:
        filtered_rows.append(entry)

print("Filtered size={}/{}".format(len(filtered_rows), total))
inst_df = pd.DataFrame(filtered_rows)
inst_df.to_csv("laststep_pred.v3.csv", header=True)
# Out:
# Filtered size=12403/12434

# %%
inst_df
# Out:
#                                                proofname  \
# 0               .ipynb_checkpoints/Euclids_30-checkpoint
# 1        .ipynb_checkpoints/all_least_bounded-checkpoint
# 2      .ipynb_checkpoints/cartesian_product_n_add_is_...
# 3      .ipynb_checkpoints/cartesian_product_one_empty...
# 4          .ipynb_checkpoints/chain_rule_TCC1-checkpoint
# ...                                                  ...
# 12398                     zorn-proofs/tower_intersection
# 12399                                   zorn-proofs/zorn
# 12400                            zp_group-proofs/Zn_card
# 12401                          zp_group-proofs/Zn_finite
# 12402                           zp_group-proofs/Zn_group
#
#                                              source_text  \
# 0      factor expand inst S_<ANT> S_<CONS> S_s-formul...
# 1      flatten-disjunct flatten instantiate S_<ANT> S...
# 2      expand hide typepred S_<ANT> S_<CONS> S_s-form...
# 3      skolem! skosimp grind S_<ANT> S_<CONS> S_s-for...
# 4      lemma instantiate inst? S_<ANT> S_<CONS> S_s-f...
# ...                                                  ...
# 12398  expand* skolem skolem! S_<ANT> S_<CONS> S_s-fo...
# 12399  flatten lemma flatten-disjunct S_<ANT> S_<CONS...
# 12400  split prop expand S_<ANT> S_<CONS> S_s-formula...
# 12401  expand inst expand S_<ANT> S_<CONS> S_s-formul...
# 12402  simplify lemma rewrite S_<ANT> S_<CONS> S_s-fo...
#
#                                 cmd_history target_text
# 0                        factor expand inst         pos
# 1      flatten-disjunct flatten instantiate         pos
# 2                      expand hide typepred         pos
# 3                     skolem! skosimp grind         pos
# 4                   lemma instantiate inst?         pos
# ...                                     ...         ...
# 12398                expand* skolem skolem!         neg
# 12399        flatten lemma flatten-disjunct         neg
# 12400                     split prop expand         neg
# 12401                    expand inst expand         neg
# 12402                simplify lemma rewrite         neg
#
# [12403 rows x 4 columns]

# %%
toklens = []
for _, x in inst_df.iterrows(): 
    toklens.append(len(x.source_text.split()))

# %%
max(toklens)
# Out:
# 999

# %%
# See percentages of rows below different values of max token lengths
len([x for x in toklens if x <= 5000])
# Out:
# 12403
